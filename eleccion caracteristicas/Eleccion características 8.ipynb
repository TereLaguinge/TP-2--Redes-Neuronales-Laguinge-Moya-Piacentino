# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=0a56f6229e1e9c19fe97466d48f6b62e0ab76d916df889aa71b2db2ab63bc9f0
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 276

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion8.csv")
# Out:
# Cat vars chosen: ['CompetitionOpenSinceYear', 'Day', 'StateHoliday_bool_bw', 'Promo2', 'StateHoliday_bool_fw', 'PromoInterval', 'Month', 'Promo2SinceYear', 'Close_bool_bw', 'Week', 'Promo2SinceWeek', 'Events', 'StateHoliday', 'State', 'Year', 'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo_bw', 'Promo_fw', 'SchoolHoliday_fw', 'DayOfWeek', 'Store', 'SchoolHoliday_bw']
# Cont vars chosen: ['AfterPromo', 'Min_TemperatureC', 'Min_Humidity', 'BeforeClose_bool', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Max_Humidity', 'Precipitationmm', 'BeforePromo', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'trend_DE', 'StateHoliday_bool', 'CompetitionDistance', 'Mean_TemperatureC', 'Max_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-0.hdf5
# Epoch 6/10
# 3181/3181 - 102s - loss: 9.1365e-04 - Sales_loss: 5.5376e-04 - Customers_loss: 1.9432e-04 - Sales_mse: 5.5376e-04 - Sales_rmspe: 0.1732 - Customers_mse: 1.9432e-04 - Customers_rmspe: 0.1552 - val_loss: 0.0011 - val_Sales_loss: 6.7025e-04 - val_Customers_loss: 2.4044e-04 - val_Sales_mse: 6.7025e-04 - val_Sales_rmspe: 0.1584 - val_Customers_mse: 2.4044e-04 - val_Customers_rmspe: 0.1512
#
# Epoch 00006: val_Sales_mse did not improve from 0.00063
# Epoch 7/10
# 3181/3181 - 108s - loss: 8.8835e-04 - Sales_loss: 5.4400e-04 - Customers_loss: 1.9115e-04 - Sales_mse: 5.4400e-04 - Sales_rmspe: 0.1717 - Customers_mse: 1.9115e-04 - Customers_rmspe: 0.1536 - val_loss: 0.0011 - val_Sales_loss: 6.8958e-04 - val_Customers_loss: 2.2272e-04 - val_Sales_mse: 6.8958e-04 - val_Sales_rmspe: 0.1686 - val_Customers_mse: 2.2272e-04 - val_Customers_rmspe: 0.1452
#
# Epoch 00007: val_Sales_mse did not improve from 0.00063
# Epoch 8/10
# 3181/3181 - 112s - loss: 8.6938e-04 - Sales_loss: 5.3839e-04 - Customers_loss: 1.8667e-04 - Sales_mse: 5.3839e-04 - Sales_rmspe: 0.1705 - Customers_mse: 1.8667e-04 - Customers_rmspe: 0.1517 - val_loss: 9.9071e-04 - val_Sales_loss: 6.6248e-04 - val_Customers_loss: 1.8652e-04 - val_Sales_mse: 6.6248e-04 - val_Sales_rmspe: 0.1570 - val_Customers_mse: 1.8652e-04 - val_Customers_rmspe: 0.1330
#
# Epoch 00008: val_Sales_mse did not improve from 0.00063
# Epoch 9/10
# 3181/3181 - 109s - loss: 8.5509e-04 - Sales_loss: 5.3113e-04 - Customers_loss: 1.8490e-04 - Sales_mse: 5.3113e-04 - Sales_rmspe: 0.1693 - Customers_mse: 1.8490e-04 - Customers_rmspe: 0.1513 - val_loss: 9.6090e-04 - val_Sales_loss: 6.2233e-04 - val_Customers_loss: 2.0042e-04 - val_Sales_mse: 6.2233e-04 - val_Sales_rmspe: 0.1484 - val_Customers_mse: 2.0042e-04 - val_Customers_rmspe: 0.1364
#
# Epoch 00009: val_Sales_mse improved from 0.00063 to 0.00062, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-0.hdf5
# Epoch 10/10
# 3181/3181 - 120s - loss: 8.4435e-04 - Sales_loss: 5.2474e-04 - Customers_loss: 1.8374e-04 - Sales_mse: 5.2474e-04 - Sales_rmspe: 0.1679 - Customers_mse: 1.8374e-04 - Customers_rmspe: 0.1514 - val_loss: 0.0010 - val_Sales_loss: 6.5581e-04 - val_Customers_loss: 2.1067e-04 - val_Sales_mse: 6.5581e-04 - val_Sales_rmspe: 0.1464 - val_Customers_mse: 2.1067e-04 - val_Customers_rmspe: 0.1338
#
# Epoch 00010: val_Sales_mse did not improve from 0.00062
# Obtenemos las métricas
# 944/944 [==============================] - 9s 9ms/step - loss: 9.6090e-04 - Sales_loss: 6.2232e-04 - Customers_loss: 2.0042e-04 - Sales_mse: 6.2232e-04 - Sales_rmspe: 0.1444 - Customers_mse: 2.0042e-04 - Customers_rmspe: 0.1328
# Cont vars chosen: ['Min_TemperatureC', 'CloudCover', 'AfterPromo', 'Mean_TemperatureC', 'Max_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'AfterSchoolHoliday', 'Min_Humidity', 'AfterClose_bool', 'trend_DE', 'BeforeStateHoliday_bool', 'Max_Humidity', 'CompetitionDistance', 'Max_TemperatureC', 'BeforePromo', 'trend']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
#
# Epoch 00010: val_Sales_mse did not improve from 0.00058
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.4535e-04 - Sales_loss: 5.8171e-04 - Customers_loss: 1.7520e-04 - Sales_mse: 5.8171e-04 - Sales_rmspe: 0.1338 - Customers_mse: 1.7520e-04 - Customers_rmspe: 0.1193
# Cont vars chosen: ['Min_TemperatureC', 'BeforeClose_bool', 'BeforeStateHoliday_bool', 'BeforeSchoolHoliday', 'CompetitionDistance', 'trend', 'StateHoliday_bool', 'AfterSchoolHoliday', 'Precipitationmm', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'Mean_Humidity', 'Min_Humidity', 'AfterStateHoliday_bool', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'trend_DE', 'Max_Humidity', 'AfterClose_bool', 'Mean_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 97s - loss: 0.0213 - Sales_loss: 0.0011 - Customers_loss: 4.3539e-04 - Sales_mse: 0.0011 - Sales_rmspe: 0.1847 - Customers_mse: 4.3539e-04 - Customers_rmspe: 0.1727 - val_loss: 0.0012 - val_Sales_loss: 6.3419e-04 - val_Customers_loss: 2.2216e-04 - val_Sales_mse: 6.3419e-04 - val_Sales_rmspe: 0.1490 - val_Customers_mse: 2.2216e-04 - val_Customers_rmspe: 0.1299
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00063, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-2.hdf5
# Epoch 2/10
# 3181/3181 - 93s - loss: 0.0010 - Sales_loss: 5.5268e-04 - Customers_loss: 1.9744e-04 - Sales_mse: 5.5268e-04 - Sales_rmspe: 0.1686 - Customers_mse: 1.9744e-04 - Customers_rmspe: 0.1521 - val_loss: 0.0011 - val_Sales_loss: 6.1407e-04 - val_Customers_loss: 2.0170e-04 - val_Sales_mse: 6.1407e-04 - val_Sales_rmspe: 0.1466 - val_Customers_mse: 2.0170e-04 - val_Customers_rmspe: 0.1280
#
# Epoch 00002: val_Sales_mse improved from 0.00063 to 0.00061, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-2.hdf5
# Epoch 3/10
# 3181/3181 - 94s - loss: 9.3801e-04 - Sales_loss: 5.3372e-04 - Customers_loss: 1.8737e-04 - Sales_mse: 5.3372e-04 - Sales_rmspe: 0.1655 - Customers_mse: 1.8737e-04 - Customers_rmspe: 0.1479 - val_loss: 0.0010 - val_Sales_loss: 6.3309e-04 - val_Customers_loss: 2.1255e-04 - val_Sales_mse: 6.3309e-04 - val_Sales_rmspe: 0.1450 - val_Customers_mse: 2.1255e-04 - val_Customers_rmspe: 0.1336
#
# Epoch 00003: val_Sales_mse did not improve from 0.00061
# Epoch 4/10
#
# Epoch 00009: val_Sales_mse did not improve from 0.00056
# Epoch 10/10
# 3181/3181 - 94s - loss: 7.8998e-04 - Sales_loss: 4.9045e-04 - Customers_loss: 1.6832e-04 - Sales_mse: 4.9045e-04 - Sales_rmspe: 0.1575 - Customers_mse: 1.6832e-04 - Customers_rmspe: 0.1393 - val_loss: 0.0010 - val_Sales_loss: 6.7858e-04 - val_Customers_loss: 2.0510e-04 - val_Sales_mse: 6.7858e-04 - val_Sales_rmspe: 0.1509 - val_Customers_mse: 2.0510e-04 - val_Customers_rmspe: 0.1392
#
# Epoch 00010: val_Sales_mse did not improve from 0.00056
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.0805e-04 - Sales_loss: 5.6153e-04 - Customers_loss: 1.8707e-04 - Sales_mse: 5.6153e-04 - Sales_rmspe: 0.1419 - Customers_mse: 1.8707e-04 - Customers_rmspe: 0.1271
# Cat vars chosen: ['Week', 'CompetitionMonthsOpen', 'Year', 'SchoolHoliday', 'Assortment', 'State', 'PromoInterval', 'Promo2Weeks', 'Promo_bw', 'Promo2SinceWeek', 'Store', 'Month', 'StateHoliday', 'Promo2SinceYear', 'Promo', 'CompetitionOpenSinceYear', 'SchoolHoliday_fw', 'Day', 'Promo_fw', 'StateHoliday_bool_bw', 'Events', 'Close_bool_bw', 'StateHoliday_bool_fw', 'StoreType']
# Cont vars chosen: ['AfterPromo', 'Min_TemperatureC', 'Min_Humidity', 'BeforeClose_bool', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Max_Humidity', 'Precipitationmm', 'BeforePromo', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'trend_DE', 'StateHoliday_bool', 'CompetitionDistance', 'Mean_TemperatureC', 'Max_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 99s - loss: 0.0126 - Sales_loss: 0.0014 - Customers_loss: 6.0112e-04 - Sales_mse: 0.0014 - Sales_rmspe: 0.2749 - Customers_mse: 6.0112e-04 - Customers_rmspe: 0.2710 - val_loss: 0.0016 - val_Sales_loss: 9.0761e-04 - val_Customers_loss: 3.2788e-04 - val_Sales_mse: 9.0761e-04 - val_Sales_rmspe: 0.2041 - val_Customers_mse: 3.2788e-04 - val_Customers_rmspe: 0.1971
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00091, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00007: val_Sales_mse did not improve from 0.00072
# Epoch 8/10
# 3181/3181 - 94s - loss: 9.0198e-04 - Sales_loss: 5.5925e-04 - Customers_loss: 1.9181e-04 - Sales_mse: 5.5925e-04 - Sales_rmspe: 0.1678 - Customers_mse: 1.9181e-04 - Customers_rmspe: 0.1524 - val_loss: 0.0011 - val_Sales_loss: 6.9758e-04 - val_Customers_loss: 2.1245e-04 - val_Sales_mse: 6.9758e-04 - val_Sales_rmspe: 0.1638 - val_Customers_mse: 2.1245e-04 - val_Customers_rmspe: 0.1441
#
# Epoch 00008: val_Sales_mse improved from 0.00072 to 0.00070, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-3.hdf5
# Epoch 9/10
# 3181/3181 - 94s - loss: 8.9188e-04 - Sales_loss: 5.5592e-04 - Customers_loss: 1.9107e-04 - Sales_mse: 5.5592e-04 - Sales_rmspe: 0.1674 - Customers_mse: 1.9107e-04 - Customers_rmspe: 0.1520 - val_loss: 0.0010 - val_Sales_loss: 6.9185e-04 - val_Customers_loss: 2.0694e-04 - val_Sales_mse: 6.9185e-04 - val_Sales_rmspe: 0.1561 - val_Customers_mse: 2.0694e-04 - val_Customers_rmspe: 0.1353
#
# Epoch 00009: val_Sales_mse improved from 0.00070 to 0.00069, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-3.hdf5
# Epoch 10/10
# 3181/3181 - 93s - loss: 8.7659e-04 - Sales_loss: 5.4865e-04 - Customers_loss: 1.8738e-04 - Sales_mse: 5.4865e-04 - Sales_rmspe: 0.1662 - Customers_mse: 1.8738e-04 - Customers_rmspe: 0.1502 - val_loss: 0.0011 - val_Sales_loss: 7.1244e-04 - val_Customers_loss: 2.5142e-04 - val_Sales_mse: 7.1244e-04 - val_Sales_rmspe: 0.1560 - val_Customers_mse: 2.5142e-04 - val_Customers_rmspe: 0.1391
#
# Epoch 00010: val_Sales_mse did not improve from 0.00069
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0010 - Sales_loss: 6.9185e-04 - Customers_loss: 2.0694e-04 - Sales_mse: 6.9185e-04 - Sales_rmspe: 0.1521 - Customers_mse: 2.0694e-04 - Customers_rmspe: 0.1320
# Cont vars chosen: ['Min_TemperatureC', 'CloudCover', 'AfterPromo', 'Mean_TemperatureC', 'Max_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'AfterSchoolHoliday', 'Min_Humidity', 'AfterClose_bool', 'trend_DE', 'BeforeStateHoliday_bool', 'Max_Humidity', 'CompetitionDistance', 'Max_TemperatureC', 'BeforePromo', 'trend']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
#
# Epoch 00006: val_Sales_mse did not improve from 0.00064
# Epoch 7/10
# 3181/3181 - 93s - loss: 8.5730e-04 - Sales_loss: 5.2458e-04 - Customers_loss: 1.8389e-04 - Sales_mse: 5.2458e-04 - Sales_rmspe: 0.1637 - Customers_mse: 1.8389e-04 - Customers_rmspe: 0.1468 - val_loss: 0.0010 - val_Sales_loss: 6.5678e-04 - val_Customers_loss: 2.0771e-04 - val_Sales_mse: 6.5678e-04 - val_Sales_rmspe: 0.1548 - val_Customers_mse: 2.0771e-04 - val_Customers_rmspe: 0.1421
#
# Epoch 00007: val_Sales_mse did not improve from 0.00064
# Epoch 8/10
# 3181/3181 - 93s - loss: 8.4718e-04 - Sales_loss: 5.2212e-04 - Customers_loss: 1.8312e-04 - Sales_mse: 5.2212e-04 - Sales_rmspe: 0.1633 - Customers_mse: 1.8312e-04 - Customers_rmspe: 0.1464 - val_loss: 0.0010 - val_Sales_loss: 6.5219e-04 - val_Customers_loss: 2.0854e-04 - val_Sales_mse: 6.5219e-04 - val_Sales_rmspe: 0.1464 - val_Customers_mse: 2.0854e-04 - val_Customers_rmspe: 0.1289
#
# Epoch 00008: val_Sales_mse did not improve from 0.00064
# Epoch 9/10
# 3181/3181 - 93s - loss: 8.4324e-04 - Sales_loss: 5.2140e-04 - Customers_loss: 1.8345e-04 - Sales_mse: 5.2140e-04 - Sales_rmspe: 0.1635 - Customers_mse: 1.8345e-04 - Customers_rmspe: 0.1467 - val_loss: 0.0011 - val_Sales_loss: 6.8779e-04 - val_Customers_loss: 2.4598e-04 - val_Sales_mse: 6.8779e-04 - val_Sales_rmspe: 0.1600 - val_Customers_mse: 2.4598e-04 - val_Customers_rmspe: 0.1567
#
# Epoch 00009: val_Sales_mse did not improve from 0.00064
# Epoch 10/10
# 3181/3181 - 93s - loss: 8.3184e-04 - Sales_loss: 5.1590e-04 - Customers_loss: 1.8125e-04 - Sales_mse: 5.1590e-04 - Sales_rmspe: 0.1627 - Customers_mse: 1.8125e-04 - Customers_rmspe: 0.1460 - val_loss: 0.0010 - val_Sales_loss: 6.7556e-04 - val_Customers_loss: 2.2665e-04 - val_Sales_mse: 6.7556e-04 - val_Sales_rmspe: 0.1604 - val_Customers_mse: 2.2665e-04 - val_Customers_rmspe: 0.1399
#
# Epoch 00010: val_Sales_mse did not improve from 0.00064
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 0.0011 - Sales_loss: 6.4164e-04 - Customers_loss: 2.1589e-04 - Sales_mse: 6.4164e-04 - Sales_rmspe: 0.1525 - Customers_mse: 2.1589e-04 - Customers_rmspe: 0.1413
# Cont vars chosen: ['Min_TemperatureC', 'BeforeClose_bool', 'BeforeStateHoliday_bool', 'BeforeSchoolHoliday', 'CompetitionDistance', 'trend', 'StateHoliday_bool', 'AfterSchoolHoliday', 'Precipitationmm', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'Mean_Humidity', 'Min_Humidity', 'AfterStateHoliday_bool', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'trend_DE', 'Max_Humidity', 'AfterClose_bool', 'Mean_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
#
# Epoch 00010: val_Sales_mse did not improve from 0.00062
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 9.9012e-04 - Sales_loss: 6.2115e-04 - Customers_loss: 2.3245e-04 - Sales_mse: 6.2115e-04 - Sales_rmspe: 0.1480 - Customers_mse: 2.3245e-04 - Customers_rmspe: 0.1387
# Cat vars chosen: ['PromoInterval', 'Events', 'StateHoliday_bool_bw', 'SchoolHoliday_bw', 'Promo_bw', 'Promo_fw', 'Day', 'SchoolHoliday_fw', 'Promo2SinceYear', 'Promo2SinceWeek', 'SchoolHoliday', 'Year', 'Promo2', 'Close_bool_bw', 'StateHoliday', 'Assortment', 'State', 'Month']
# ...
#
# Epoch 00007: val_Sales_mse did not improve from 0.00320
# Epoch 8/10
# 3181/3181 - 84s - loss: 0.0051 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.4314 - Customers_mse: 0.0015 - Customers_rmspe: 0.4378 - val_loss: 0.0050 - val_Sales_loss: 0.0032 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0032 - val_Sales_rmspe: 0.4045 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4367
#
# Epoch 00008: val_Sales_mse did not improve from 0.00320
# Epoch 9/10
# 3181/3181 - 84s - loss: 0.0051 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.4304 - Customers_mse: 0.0015 - Customers_rmspe: 0.4368 - val_loss: 0.0050 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.4432 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4809
#
# Epoch 00009: val_Sales_mse did not improve from 0.00320
# Epoch 10/10
# 3181/3181 - 84s - loss: 0.0051 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4301 - Customers_mse: 0.0015 - Customers_rmspe: 0.4363 - val_loss: 0.0049 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3898 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3911
#
# Epoch 00010: val_Sales_mse improved from 0.00320 to 0.00312, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-6.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0049 - Sales_loss: 0.0031 - Customers_loss: 0.0014 - Sales_mse: 0.0031 - Sales_rmspe: 0.3792 - Customers_mse: 0.0014 - Customers_rmspe: 0.3810
# Cont vars chosen: ['Min_TemperatureC', 'CloudCover', 'AfterPromo', 'Mean_TemperatureC', 'Max_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'AfterSchoolHoliday', 'Min_Humidity', 'AfterClose_bool', 'trend_DE', 'BeforeStateHoliday_bool', 'Max_Humidity', 'CompetitionDistance', 'Max_TemperatureC', 'BeforePromo', 'trend']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 87s - loss: 0.0203 - Sales_loss: 0.0038 - Customers_loss: 0.0019 - Sales_mse: 0.0038 - Sales_rmspe: 0.4551 - Customers_mse: 0.0019 - Customers_rmspe: 0.4629 - val_loss: 0.0053 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.3862 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4373
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00331, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Epoch 2/10
# 3181/3181 - 82s - loss: 0.0054 - Sales_loss: 0.0033 - Customers_loss: 0.0016 - Sales_mse: 0.0033 - Sales_rmspe: 0.4302 - Customers_mse: 0.0016 - Customers_rmspe: 0.4374 - val_loss: 0.0050 - val_Sales_loss: 0.0032 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0032 - val_Sales_rmspe: 0.3380 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3904
#
# Epoch 00002: val_Sales_mse improved from 0.00331 to 0.00317, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Epoch 3/10
# 3181/3181 - 82s - loss: 0.0052 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4233 - Customers_mse: 0.0015 - Customers_rmspe: 0.4306 - val_loss: 0.0049 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3714 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3888
#
# Epoch 00003: val_Sales_mse improved from 0.00317 to 0.00309, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Epoch 4/10
# 3181/3181 - 82s - loss: 0.0051 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4198 - Customers_mse: 0.0015 - Customers_rmspe: 0.4263 - val_loss: 0.0048 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3826 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3858
#
# Epoch 00004: val_Sales_mse did not improve from 0.00309
# Epoch 5/10
# 3181/3181 - 82s - loss: 0.0051 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4176 - Customers_mse: 0.0015 - Customers_rmspe: 0.4244 - val_loss: 0.0048 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.4031 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4455
#
# Epoch 00005: val_Sales_mse did not improve from 0.00309
# Epoch 6/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4167 - Customers_mse: 0.0015 - Customers_rmspe: 0.4228 - val_loss: 0.0048 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3718 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3910
#
# Epoch 00006: val_Sales_mse did not improve from 0.00309
# Epoch 7/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4159 - Customers_mse: 0.0015 - Customers_rmspe: 0.4211 - val_loss: 0.0048 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3815 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3913
#
# Epoch 00007: val_Sales_mse improved from 0.00309 to 0.00307, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Epoch 8/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4159 - Customers_mse: 0.0015 - Customers_rmspe: 0.4215 - val_loss: 0.0049 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3836 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4750
#
# Epoch 00008: val_Sales_mse improved from 0.00307 to 0.00306, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Epoch 9/10
# 3181/3181 - 81s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4153 - Customers_mse: 0.0015 - Customers_rmspe: 0.4209 - val_loss: 0.0047 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3718 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4248
#
# Epoch 00009: val_Sales_mse improved from 0.00306 to 0.00303, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Epoch 10/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4155 - Customers_mse: 0.0015 - Customers_rmspe: 0.4209 - val_loss: 0.0047 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3951 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4365
#
# Epoch 00010: val_Sales_mse improved from 0.00303 to 0.00303, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-7.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0047 - Sales_loss: 0.0030 - Customers_loss: 0.0014 - Sales_mse: 0.0030 - Sales_rmspe: 0.3844 - Customers_mse: 0.0014 - Customers_rmspe: 0.4250
# Cont vars chosen: ['Min_TemperatureC', 'BeforeClose_bool', 'BeforeStateHoliday_bool', 'BeforeSchoolHoliday', 'CompetitionDistance', 'trend', 'StateHoliday_bool', 'AfterSchoolHoliday', 'Precipitationmm', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'Mean_Humidity', 'Min_Humidity', 'AfterStateHoliday_bool', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'trend_DE', 'Max_Humidity', 'AfterClose_bool', 'Mean_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 8
# Epoch 1/10
# 3181/3181 - 86s - loss: 0.0236 - Sales_loss: 0.0040 - Customers_loss: 0.0017 - Sales_mse: 0.0040 - Sales_rmspe: 0.4499 - Customers_mse: 0.0017 - Customers_rmspe: 0.4517 - val_loss: 0.0052 - val_Sales_loss: 0.0032 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0032 - val_Sales_rmspe: 0.3479 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.3706
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00320, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-8.hdf5
# Epoch 2/10
# 3181/3181 - 83s - loss: 0.0053 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.4258 - Customers_mse: 0.0015 - Customers_rmspe: 0.4295 - val_loss: 0.0050 - val_Sales_loss: 0.0032 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0032 - val_Sales_rmspe: 0.3752 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3927
#
# Epoch 00002: val_Sales_mse improved from 0.00320 to 0.00317, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-8.hdf5
# Epoch 3/10
# 3181/3181 - 82s - loss: 0.0052 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4194 - Customers_mse: 0.0015 - Customers_rmspe: 0.4243 - val_loss: 0.0048 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3852 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4202
#
# Epoch 00003: val_Sales_mse improved from 0.00317 to 0.00307, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-8.hdf5
# Epoch 4/10
# 3181/3181 - 82s - loss: 0.0051 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4169 - Customers_mse: 0.0015 - Customers_rmspe: 0.4222 - val_loss: 0.0048 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3691 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4302
#
# Epoch 00004: val_Sales_mse improved from 0.00307 to 0.00304, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-8.hdf5
# Epoch 5/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4142 - Customers_mse: 0.0015 - Customers_rmspe: 0.4200 - val_loss: 0.0053 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.4377 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4599
#
# Epoch 00005: val_Sales_mse did not improve from 0.00304
# Epoch 6/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4129 - Customers_mse: 0.0015 - Customers_rmspe: 0.4193 - val_loss: 0.0049 - val_Sales_loss: 0.0032 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0032 - val_Sales_rmspe: 0.3948 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4240
#
# Epoch 00006: val_Sales_mse did not improve from 0.00304
# Epoch 7/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4118 - Customers_mse: 0.0015 - Customers_rmspe: 0.4180 - val_loss: 0.0047 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0013 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3813 - val_Customers_mse: 0.0013 - val_Customers_rmspe: 0.3967
#
# Epoch 00007: val_Sales_mse did not improve from 0.00304
# Epoch 8/10
# 3181/3181 - 82s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4116 - Customers_mse: 0.0015 - Customers_rmspe: 0.4175 - val_loss: 0.0050 - val_Sales_loss: 0.0032 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0032 - val_Sales_rmspe: 0.4342 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4493
#
# Epoch 00008: val_Sales_mse did not improve from 0.00304
# Epoch 9/10
# 3181/3181 - 86s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0015 - Sales_mse: 0.0032 - Sales_rmspe: 0.4104 - Customers_mse: 0.0015 - Customers_rmspe: 0.4168 - val_loss: 0.0048 - val_Sales_loss: 0.0031 - val_Customers_loss: 0.0013 - val_Sales_mse: 0.0031 - val_Sales_rmspe: 0.3522 - val_Customers_mse: 0.0013 - val_Customers_rmspe: 0.3863
#
# Epoch 00009: val_Sales_mse did not improve from 0.00304
# Epoch 10/10
# 3181/3181 - 89s - loss: 0.0050 - Sales_loss: 0.0031 - Customers_loss: 0.0015 - Sales_mse: 0.0031 - Sales_rmspe: 0.4100 - Customers_mse: 0.0015 - Customers_rmspe: 0.4162 - val_loss: 0.0047 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0013 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3723 - val_Customers_mse: 0.0013 - val_Customers_rmspe: 0.3738
#
# Epoch 00010: val_Sales_mse improved from 0.00304 to 0.00298, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel8-8.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 8s 8ms/step - loss: 0.0047 - Sales_loss: 0.0030 - Customers_loss: 0.0013 - Sales_mse: 0.0030 - Sales_rmspe: 0.3618 - Customers_mse: 0.0013 - Customers_rmspe: 0.3617
