# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=026fcdf7967c679d4006f682314fe34273cadf38fb7bfffcc010517e196c114b
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 465

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion11.csv")
# Out:
# Cat vars chosen: ['StateHoliday', 'Close_bool_fw', 'StoreType', 'Month', 'Day', 'Promo_bw', 'StateHoliday_bool_bw', 'StateHoliday_bool_fw', 'Year', 'Promo', 'SchoolHoliday', 'Promo2SinceWeek', 'Promo2', 'Promo_fw', 'Close_bool_bw', 'Assortment', 'CompetitionMonthsOpen']
# Cont vars chosen: ['BeforeClose_bool', 'Min_Humidity', 'Mean_Humidity', 'Min_TemperatureC', 'Mean_TemperatureC', 'StateHoliday_bool', 'trend', 'CompetitionDistance', 'AfterSchoolHoliday', 'trend_DE', 'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Max_Humidity', 'AfterPromo', 'BeforeSchoolHoliday', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 85s - loss: 0.0161 - Sales_loss: 0.0043 - Customers_loss: 0.0020 - Sales_mse: 0.0043 - Sales_rmspe: 0.5008 - Customers_mse: 0.0020 - Customers_rmspe: 0.4980 - val_loss: 0.0063 - val_Sales_loss: 0.0040 - val_Customers_loss: 0.0019 - val_Sales_mse: 0.0040 - val_Sales_rmspe: 0.4590 - val_Customers_mse: 0.0019 - val_Customers_rmspe: 0.5051
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00399, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 80s - loss: 0.0055 - Sales_loss: 0.0036 - Customers_loss: 0.0016 - Sales_mse: 0.0036 - Sales_rmspe: 0.4467 - Customers_mse: 0.0016 - Customers_rmspe: 0.4437 - val_loss: 0.0054 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.4149 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4680
#
# Epoch 00008: val_Sales_mse did not improve from 0.00355
# Epoch 9/10
# 3181/3181 - 81s - loss: 0.0055 - Sales_loss: 0.0036 - Customers_loss: 0.0016 - Sales_mse: 0.0036 - Sales_rmspe: 0.4464 - Customers_mse: 0.0016 - Customers_rmspe: 0.4437 - val_loss: 0.0054 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.4168 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4516
#
# Epoch 00009: val_Sales_mse did not improve from 0.00355
# Epoch 10/10
# 3181/3181 - 81s - loss: 0.0055 - Sales_loss: 0.0036 - Customers_loss: 0.0016 - Sales_mse: 0.0036 - Sales_rmspe: 0.4467 - Customers_mse: 0.0016 - Customers_rmspe: 0.4432 - val_loss: 0.0054 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.3891 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4074
#
# Epoch 00010: val_Sales_mse did not improve from 0.00355
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0054 - Sales_loss: 0.0035 - Customers_loss: 0.0015 - Sales_mse: 0.0035 - Sales_rmspe: 0.3861 - Customers_mse: 0.0015 - Customers_rmspe: 0.4443
# Cont vars chosen: ['AfterSchoolHoliday', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Mean_TemperatureC', 'Min_TemperatureC', 'Min_Humidity', 'BeforePromo', 'StateHoliday_bool', 'trend_DE', 'Max_Wind_SpeedKm_h', 'CloudCover', 'BeforeStateHoliday_bool', 'BeforeClose_bool', 'Max_TemperatureC', 'AfterPromo', 'trend', 'Precipitationmm', 'Mean_Humidity', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 86s - loss: 0.0206 - Sales_loss: 0.0044 - Customers_loss: 0.0020 - Sales_mse: 0.0044 - Sales_rmspe: 0.4852 - Customers_mse: 0.0020 - Customers_rmspe: 0.4926 - val_loss: 0.0056 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.3982 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4279
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00362, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-1.hdf5
# Epoch 8/10
# 3181/3181 - 80s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4474 - Customers_mse: 0.0017 - Customers_rmspe: 0.4556 - val_loss: 0.0054 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.3717 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.3989
#
# Epoch 00008: val_Sales_mse did not improve from 0.00351
# Epoch 9/10
# 3181/3181 - 80s - loss: 0.0056 - Sales_loss: 0.0036 - Customers_loss: 0.0017 - Sales_mse: 0.0036 - Sales_rmspe: 0.4462 - Customers_mse: 0.0017 - Customers_rmspe: 0.4541 - val_loss: 0.0055 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.3730 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4093
#
# Epoch 00009: val_Sales_mse did not improve from 0.00351
# Epoch 10/10
# 3181/3181 - 81s - loss: 0.0056 - Sales_loss: 0.0036 - Customers_loss: 0.0017 - Sales_mse: 0.0036 - Sales_rmspe: 0.4460 - Customers_mse: 0.0017 - Customers_rmspe: 0.4534 - val_loss: 0.0054 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.3895 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4200
#
# Epoch 00010: val_Sales_mse did not improve from 0.00351
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0054 - Sales_loss: 0.0035 - Customers_loss: 0.0016 - Sales_mse: 0.0035 - Sales_rmspe: 0.3928 - Customers_mse: 0.0016 - Customers_rmspe: 0.4503
# Cont vars chosen: ['CompetitionDistance', 'AfterStateHoliday_bool', 'BeforePromo', 'Precipitationmm', 'Mean_TemperatureC', 'Max_TemperatureC', 'AfterClose_bool', 'BeforeSchoolHoliday', 'Mean_Humidity', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Min_TemperatureC', 'StateHoliday_bool', 'Max_Humidity', 'BeforeStateHoliday_bool', 'trend', 'trend_DE']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 82s - loss: 0.0282 - Sales_loss: 0.0040 - Customers_loss: 0.0023 - Sales_mse: 0.0040 - Sales_rmspe: 0.4591 - Customers_mse: 0.0023 - Customers_rmspe: 0.4725 - val_loss: 0.0055 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.4227 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4400
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00354, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-2.hdf5
# Epoch 2/10
# 3181/3181 - 79s - loss: 0.0057 - Sales_loss: 0.0036 - Customers_loss: 0.0017 - Sales_mse: 0.0036 - Sales_rmspe: 0.4433 - Customers_mse: 0.0017 - Customers_rmspe: 0.4440 - val_loss: 0.0053 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.4003 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4312
#
# Epoch 00002: val_Sales_mse improved from 0.00354 to 0.00346, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 81s - loss: 0.0052 - Sales_loss: 0.0034 - Customers_loss: 0.0015 - Sales_mse: 0.0034 - Sales_rmspe: 0.4270 - Customers_mse: 0.0015 - Customers_rmspe: 0.4238 - val_loss: 0.0052 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.3933 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4276
#
# Epoch 00008: val_Sales_mse did not improve from 0.00334
# Epoch 9/10
# 3181/3181 - 81s - loss: 0.0052 - Sales_loss: 0.0034 - Customers_loss: 0.0015 - Sales_mse: 0.0034 - Sales_rmspe: 0.4280 - Customers_mse: 0.0015 - Customers_rmspe: 0.4250 - val_loss: 0.0051 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.3906 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4401
#
# Epoch 00009: val_Sales_mse improved from 0.00334 to 0.00332, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-2.hdf5
# Epoch 10/10
# 3181/3181 - 79s - loss: 0.0052 - Sales_loss: 0.0034 - Customers_loss: 0.0015 - Sales_mse: 0.0034 - Sales_rmspe: 0.4271 - Customers_mse: 0.0015 - Customers_rmspe: 0.4242 - val_loss: 0.0051 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.3658 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4127
#
# Epoch 00010: val_Sales_mse did not improve from 0.00332
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0051 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.3805 - Customers_mse: 0.0015 - Customers_rmspe: 0.4298
# Cat vars chosen: ['CompetitionMonthsOpen', 'Week', 'StateHoliday', 'PromoInterval', 'StateHoliday_bool_fw', 'Promo_bw', 'Close_bool_fw', 'StoreType', 'DayOfWeek', 'Promo2', 'Close_bool_bw', 'SchoolHoliday_fw', 'Promo_fw', 'Promo2SinceWeek', 'Day', 'Events', 'Promo2Weeks', 'SchoolHoliday', 'SchoolHoliday_bw', 'State', 'CompetitionOpenSinceYear', 'Store', 'Promo', 'Month', 'Year']
# Cont vars chosen: ['BeforeClose_bool', 'Min_Humidity', 'Mean_Humidity', 'Min_TemperatureC', 'Mean_TemperatureC', 'StateHoliday_bool', 'trend', 'CompetitionDistance', 'AfterSchoolHoliday', 'trend_DE', 'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Max_Humidity', 'AfterPromo', 'BeforeSchoolHoliday', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
#
# Epoch 00006: val_Sales_mse did not improve from 0.00063
# Epoch 7/10
# 3181/3181 - 91s - loss: 8.6914e-04 - Sales_loss: 5.3435e-04 - Customers_loss: 1.7803e-04 - Sales_mse: 5.3435e-04 - Sales_rmspe: 0.1648 - Customers_mse: 1.7803e-04 - Customers_rmspe: 0.1485 - val_loss: 0.0012 - val_Sales_loss: 7.8895e-04 - val_Customers_loss: 2.3704e-04 - val_Sales_mse: 7.8895e-04 - val_Sales_rmspe: 0.1578 - val_Customers_mse: 2.3704e-04 - val_Customers_rmspe: 0.1426
#
# Epoch 00007: val_Sales_mse did not improve from 0.00063
# Epoch 8/10
# 3181/3181 - 91s - loss: 8.5185e-04 - Sales_loss: 5.2526e-04 - Customers_loss: 1.7659e-04 - Sales_mse: 5.2526e-04 - Sales_rmspe: 0.1630 - Customers_mse: 1.7659e-04 - Customers_rmspe: 0.1475 - val_loss: 0.0010 - val_Sales_loss: 6.6692e-04 - val_Customers_loss: 2.0634e-04 - val_Sales_mse: 6.6692e-04 - val_Sales_rmspe: 0.1593 - val_Customers_mse: 2.0634e-04 - val_Customers_rmspe: 0.1337
#
# Epoch 00008: val_Sales_mse did not improve from 0.00063
# Epoch 9/10
# 3181/3181 - 91s - loss: 8.4018e-04 - Sales_loss: 5.2018e-04 - Customers_loss: 1.7421e-04 - Sales_mse: 5.2018e-04 - Sales_rmspe: 0.1619 - Customers_mse: 1.7421e-04 - Customers_rmspe: 0.1461 - val_loss: 0.0010 - val_Sales_loss: 6.4880e-04 - val_Customers_loss: 2.1508e-04 - val_Sales_mse: 6.4880e-04 - val_Sales_rmspe: 0.1583 - val_Customers_mse: 2.1508e-04 - val_Customers_rmspe: 0.1465
#
# Epoch 00009: val_Sales_mse did not improve from 0.00063
# Epoch 10/10
# 3181/3181 - 90s - loss: 8.2762e-04 - Sales_loss: 5.1502e-04 - Customers_loss: 1.7174e-04 - Sales_mse: 5.1502e-04 - Sales_rmspe: 0.1612 - Customers_mse: 1.7174e-04 - Customers_rmspe: 0.1451 - val_loss: 9.6166e-04 - val_Sales_loss: 6.3836e-04 - val_Customers_loss: 1.8737e-04 - val_Sales_mse: 6.3836e-04 - val_Sales_rmspe: 0.1486 - val_Customers_mse: 1.8737e-04 - val_Customers_rmspe: 0.1279
#
# Epoch 00010: val_Sales_mse did not improve from 0.00063
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 0.0010 - Sales_loss: 6.3346e-04 - Customers_loss: 2.0735e-04 - Sales_mse: 6.3346e-04 - Sales_rmspe: 0.1428 - Customers_mse: 2.0735e-04 - Customers_rmspe: 0.1237
# Cont vars chosen: ['AfterSchoolHoliday', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Mean_TemperatureC', 'Min_TemperatureC', 'Min_Humidity', 'BeforePromo', 'StateHoliday_bool', 'trend_DE', 'Max_Wind_SpeedKm_h', 'CloudCover', 'BeforeStateHoliday_bool', 'BeforeClose_bool', 'Max_TemperatureC', 'AfterPromo', 'trend', 'Precipitationmm', 'Mean_Humidity', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
# 944/944 [==============================] - 6s 6ms/step - loss: 9.3411e-04 - Sales_loss: 5.9105e-04 - Customers_loss: 2.0342e-04 - Sales_mse: 5.9105e-04 - Sales_rmspe: 0.1421 - Customers_mse: 2.0342e-04 - Customers_rmspe: 0.1273
# Cont vars chosen: ['CompetitionDistance', 'AfterStateHoliday_bool', 'BeforePromo', 'Precipitationmm', 'Mean_TemperatureC', 'Max_TemperatureC', 'AfterClose_bool', 'BeforeSchoolHoliday', 'Mean_Humidity', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Min_TemperatureC', 'StateHoliday_bool', 'Max_Humidity', 'BeforeStateHoliday_bool', 'trend', 'trend_DE']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 96s - loss: 0.0202 - Sales_loss: 6.5625e-04 - Customers_loss: 7.2184e-04 - Sales_mse: 6.5625e-04 - Sales_rmspe: 0.1767 - Customers_mse: 7.2184e-04 - Customers_rmspe: 0.1747 - val_loss: 0.0011 - val_Sales_loss: 6.4301e-04 - val_Customers_loss: 2.2848e-04 - val_Sales_mse: 6.4301e-04 - val_Sales_rmspe: 0.1599 - val_Customers_mse: 2.2848e-04 - val_Customers_rmspe: 0.1499
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00064, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-5.hdf5
# Epoch 2/10
# 3181/3181 - 94s - loss: 9.7079e-04 - Sales_loss: 5.4036e-04 - Customers_loss: 1.9285e-04 - Sales_mse: 5.4036e-04 - Sales_rmspe: 0.1671 - Customers_mse: 1.9285e-04 - Customers_rmspe: 0.1506 - val_loss: 0.0010 - val_Sales_loss: 6.0508e-04 - val_Customers_loss: 2.2386e-04 - val_Sales_mse: 6.0508e-04 - val_Sales_rmspe: 0.1451 - val_Customers_mse: 2.2386e-04 - val_Customers_rmspe: 0.1412
#
# Epoch 00002: val_Sales_mse improved from 0.00064 to 0.00061, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-5.hdf5
# Epoch 3/10
# 3181/3181 - 94s - loss: 8.8860e-04 - Sales_loss: 5.1488e-04 - Customers_loss: 1.8474e-04 - Sales_mse: 5.1488e-04 - Sales_rmspe: 0.1630 - Customers_mse: 1.8474e-04 - Customers_rmspe: 0.1478 - val_loss: 9.9175e-04 - val_Sales_loss: 6.2382e-04 - val_Customers_loss: 1.9193e-04 - val_Sales_mse: 6.2382e-04 - val_Sales_rmspe: 0.1617 - val_Customers_mse: 1.9193e-04 - val_Customers_rmspe: 0.1333
#
# Epoch 00003: val_Sales_mse did not improve from 0.00061
# Epoch 4/10
# 3181/3181 - 94s - loss: 8.5002e-04 - Sales_loss: 5.0448e-04 - Customers_loss: 1.7938e-04 - Sales_mse: 5.0448e-04 - Sales_rmspe: 0.1608 - Customers_mse: 1.7938e-04 - Customers_rmspe: 0.1458 - val_loss: 9.6532e-04 - val_Sales_loss: 5.9008e-04 - val_Customers_loss: 2.1382e-04 - val_Sales_mse: 5.9008e-04 - val_Sales_rmspe: 0.1576 - val_Customers_mse: 2.1382e-04 - val_Customers_rmspe: 0.1463
#
# Epoch 00004: val_Sales_mse improved from 0.00061 to 0.00059, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 92s - loss: 7.8096e-04 - Sales_loss: 4.8434e-04 - Customers_loss: 1.6953e-04 - Sales_mse: 4.8434e-04 - Sales_rmspe: 0.1559 - Customers_mse: 1.6953e-04 - Customers_rmspe: 0.1400 - val_loss: 9.0925e-04 - val_Sales_loss: 5.6978e-04 - val_Customers_loss: 2.1624e-04 - val_Sales_mse: 5.6978e-04 - val_Sales_rmspe: 0.1424 - val_Customers_mse: 2.1624e-04 - val_Customers_rmspe: 0.1434
#
# Epoch 00010: val_Sales_mse did not improve from 0.00056
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.0450e-04 - Sales_loss: 5.5740e-04 - Customers_loss: 1.9606e-04 - Sales_mse: 5.5740e-04 - Sales_rmspe: 0.1381 - Customers_mse: 1.9606e-04 - Customers_rmspe: 0.1304
# Cat vars chosen: ['StateHoliday_bool_bw', 'Store', 'Close_bool_bw', 'Promo2SinceYear', 'Promo_fw', 'StoreType', 'CompetitionOpenSinceYear', 'Day', 'SchoolHoliday_fw', 'PromoInterval', 'SchoolHoliday_bw', 'SchoolHoliday', 'Week', 'Promo_bw', 'Events', 'Promo2Weeks', 'Month', 'StateHoliday_bool_fw', 'Promo2', 'Year', 'DayOfWeek', 'Promo', 'CompetitionMonthsOpen', 'StateHoliday', 'State']
# Cont vars chosen: ['BeforeClose_bool', 'Min_Humidity', 'Mean_Humidity', 'Min_TemperatureC', 'Mean_TemperatureC', 'StateHoliday_bool', 'trend', 'CompetitionDistance', 'AfterSchoolHoliday', 'trend_DE', 'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Max_Humidity', 'AfterPromo', 'BeforeSchoolHoliday', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# ...
# Cont vars chosen: ['AfterSchoolHoliday', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Mean_TemperatureC', 'Min_TemperatureC', 'Min_Humidity', 'BeforePromo', 'StateHoliday_bool', 'trend_DE', 'Max_Wind_SpeedKm_h', 'CloudCover', 'BeforeStateHoliday_bool', 'BeforeClose_bool', 'Max_TemperatureC', 'AfterPromo', 'trend', 'Precipitationmm', 'Mean_Humidity', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 97s - loss: 0.0180 - Sales_loss: 9.3367e-04 - Customers_loss: 4.0090e-04 - Sales_mse: 9.3367e-04 - Sales_rmspe: 0.1867 - Customers_mse: 4.0090e-04 - Customers_rmspe: 0.1804 - val_loss: 0.0012 - val_Sales_loss: 6.8011e-04 - val_Customers_loss: 2.4395e-04 - val_Sales_mse: 6.8011e-04 - val_Sales_rmspe: 0.1615 - val_Customers_mse: 2.4395e-04 - val_Customers_rmspe: 0.1557
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 94s - loss: 8.4089e-04 - Sales_loss: 5.1795e-04 - Customers_loss: 1.7941e-04 - Sales_mse: 5.1795e-04 - Sales_rmspe: 0.1660 - Customers_mse: 1.7941e-04 - Customers_rmspe: 0.1478 - val_loss: 0.0011 - val_Sales_loss: 6.6911e-04 - val_Customers_loss: 2.7504e-04 - val_Sales_mse: 6.6911e-04 - val_Sales_rmspe: 0.1616 - val_Customers_mse: 2.7504e-04 - val_Customers_rmspe: 0.1625
#
# Epoch 00007: val_Sales_mse did not improve from 0.00062
# Epoch 8/10
# 3181/3181 - 95s - loss: 8.2492e-04 - Sales_loss: 5.0982e-04 - Customers_loss: 1.7896e-04 - Sales_mse: 5.0982e-04 - Sales_rmspe: 0.1656 - Customers_mse: 1.7896e-04 - Customers_rmspe: 0.1476 - val_loss: 9.4940e-04 - val_Sales_loss: 6.1352e-04 - val_Customers_loss: 1.9973e-04 - val_Sales_mse: 6.1352e-04 - val_Sales_rmspe: 0.1480 - val_Customers_mse: 1.9973e-04 - val_Customers_rmspe: 0.1321
#
# Epoch 00008: val_Sales_mse improved from 0.00062 to 0.00061, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel11-7.hdf5
# Epoch 9/10
# 3181/3181 - 95s - loss: 8.2228e-04 - Sales_loss: 5.1008e-04 - Customers_loss: 1.7880e-04 - Sales_mse: 5.1008e-04 - Sales_rmspe: 0.1650 - Customers_mse: 1.7880e-04 - Customers_rmspe: 0.1475 - val_loss: 0.0010 - val_Sales_loss: 6.2688e-04 - val_Customers_loss: 2.7260e-04 - val_Sales_mse: 6.2688e-04 - val_Sales_rmspe: 0.1484 - val_Customers_mse: 2.7260e-04 - val_Customers_rmspe: 0.1500
#
# Epoch 00009: val_Sales_mse did not improve from 0.00061
# Epoch 10/10
# 3181/3181 - 94s - loss: 8.1242e-04 - Sales_loss: 5.0366e-04 - Customers_loss: 1.7651e-04 - Sales_mse: 5.0366e-04 - Sales_rmspe: 0.1634 - Customers_mse: 1.7651e-04 - Customers_rmspe: 0.1462 - val_loss: 9.6621e-04 - val_Sales_loss: 6.2339e-04 - val_Customers_loss: 2.1270e-04 - val_Sales_mse: 6.2339e-04 - val_Sales_rmspe: 0.1426 - val_Customers_mse: 2.1270e-04 - val_Customers_rmspe: 0.1438
#
# Epoch 00010: val_Sales_mse did not improve from 0.00061
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 9.4940e-04 - Sales_loss: 6.1352e-04 - Customers_loss: 1.9973e-04 - Sales_mse: 6.1352e-04 - Sales_rmspe: 0.1433 - Customers_mse: 1.9973e-04 - Customers_rmspe: 0.1278
# Cont vars chosen: ['CompetitionDistance', 'AfterStateHoliday_bool', 'BeforePromo', 'Precipitationmm', 'Mean_TemperatureC', 'Max_TemperatureC', 'AfterClose_bool', 'BeforeSchoolHoliday', 'Mean_Humidity', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Min_TemperatureC', 'StateHoliday_bool', 'Max_Humidity', 'BeforeStateHoliday_bool', 'trend', 'trend_DE']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 