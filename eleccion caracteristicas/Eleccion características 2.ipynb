# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=d4d6a2be090d6b1c3227a6f3dc594e727364029c07133ab09a41c86e153be504
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 622

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion2.csv")
# Out:
# Cat vars chosen: ['Store', 'Promo_bw', 'CompetitionMonthsOpen', 'Promo2SinceYear', 'Promo', 'StateHoliday', 'StateHoliday_bool_fw', 'Close_bool_fw', 'Assortment', 'Promo2SinceWeek', 'Promo_fw', 'Year', 'Day', 'Promo2', 'SchoolHoliday_fw', 'Promo2Weeks', 'State', 'Events', 'SchoolHoliday', 'PromoInterval']
# Cont vars chosen: ['trend_DE', 'Max_TemperatureC', 'BeforeSchoolHoliday', 'trend', 'Max_Humidity', 'AfterStateHoliday_bool', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'Min_Humidity', 'CloudCover', 'AfterClose_bool', 'Mean_TemperatureC', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-1.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0011 - Sales_loss: 7.4243e-04 - Customers_loss: 2.5913e-04 - Sales_mse: 7.4243e-04 - Sales_rmspe: 0.1619 - Customers_mse: 2.5913e-04 - Customers_rmspe: 0.1434
# Cont vars chosen: ['AfterSchoolHoliday', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'BeforeStateHoliday_bool', 'trend_DE', 'Mean_Humidity', 'Max_Humidity', 'Max_TemperatureC', 'Precipitationmm', 'trend', 'AfterPromo', 'Mean_TemperatureC', 'Min_Humidity', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'BeforeClose_bool', 'CompetitionDistance', 'AfterStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 78s - loss: 0.0252 - Sales_loss: 0.0012 - Customers_loss: 5.4256e-04 - Sales_mse: 0.0012 - Sales_rmspe: 0.1928 - Customers_mse: 5.4256e-04 - Customers_rmspe: 0.1847 - val_loss: 0.0015 - val_Sales_loss: 8.0977e-04 - val_Customers_loss: 3.4850e-04 - val_Sales_mse: 8.0977e-04 - val_Sales_rmspe: 0.1795 - val_Customers_mse: 3.4850e-04 - val_Customers_rmspe: 0.1742
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00081, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-2.hdf5
# Epoch 2/10
# 3181/3181 - 75s - loss: 0.0012 - Sales_loss: 6.4750e-04 - Customers_loss: 2.1704e-04 - Sales_mse: 6.4750e-04 - Sales_rmspe: 0.1781 - Customers_mse: 2.1704e-04 - Customers_rmspe: 0.1606 - val_loss: 0.0014 - val_Sales_loss: 7.4872e-04 - val_Customers_loss: 3.8707e-04 - val_Sales_mse: 7.4872e-04 - val_Sales_rmspe: 0.1687 - val_Customers_mse: 3.8707e-04 - val_Customers_rmspe: 0.1868
#
# Epoch 00002: val_Sales_mse improved from 0.00081 to 0.00075, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-2.hdf5
# Epoch 3/10
# 3181/3181 - 75s - loss: 0.0011 - Sales_loss: 6.1917e-04 - Customers_loss: 2.0555e-04 - Sales_mse: 6.1917e-04 - Sales_rmspe: 0.1743 - Customers_mse: 2.0555e-04 - Customers_rmspe: 0.1559 - val_loss: 0.0013 - val_Sales_loss: 8.0211e-04 - val_Customers_loss: 3.2103e-04 - val_Sales_mse: 8.0211e-04 - val_Sales_rmspe: 0.1634 - val_Customers_mse: 3.2103e-04 - val_Customers_rmspe: 0.1607
#
# Epoch 00003: val_Sales_mse did not improve from 0.00075
# Epoch 4/10
# 3181/3181 - 75s - loss: 0.0010 - Sales_loss: 6.0941e-04 - Customers_loss: 2.0203e-04 - Sales_mse: 6.0941e-04 - Sales_rmspe: 0.1733 - Customers_mse: 2.0203e-04 - Customers_rmspe: 0.1548 - val_loss: 0.0013 - val_Sales_loss: 7.4346e-04 - val_Customers_loss: 3.4138e-04 - val_Sales_mse: 7.4346e-04 - val_Sales_rmspe: 0.1684 - val_Customers_mse: 3.4138e-04 - val_Customers_rmspe: 0.1687
#
# Epoch 00004: val_Sales_mse improved from 0.00075 to 0.00074, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-2.hdf5
# Epoch 9/10
# 3181/3181 - 76s - loss: 9.2241e-04 - Sales_loss: 5.8344e-04 - Customers_loss: 1.9320e-04 - Sales_mse: 5.8344e-04 - Sales_rmspe: 0.1698 - Customers_mse: 1.9320e-04 - Customers_rmspe: 0.1517 - val_loss: 0.0013 - val_Sales_loss: 8.2085e-04 - val_Customers_loss: 3.3784e-04 - val_Sales_mse: 8.2085e-04 - val_Sales_rmspe: 0.1812 - val_Customers_mse: 3.3784e-04 - val_Customers_rmspe: 0.1717
#
# Epoch 00009: val_Sales_mse did not improve from 0.00068
# Epoch 10/10
# 3181/3181 - 81s - loss: 9.1595e-04 - Sales_loss: 5.8045e-04 - Customers_loss: 1.9243e-04 - Sales_mse: 5.8045e-04 - Sales_rmspe: 0.1693 - Customers_mse: 1.9243e-04 - Customers_rmspe: 0.1512 - val_loss: 0.0014 - val_Sales_loss: 8.5398e-04 - val_Customers_loss: 3.7365e-04 - val_Sales_mse: 8.5398e-04 - val_Sales_rmspe: 0.1794 - val_Customers_mse: 3.7365e-04 - val_Customers_rmspe: 0.1730
#
# Epoch 00010: val_Sales_mse did not improve from 0.00068
# Obtenemos las métricas
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0011 - Sales_loss: 6.8422e-04 - Customers_loss: 2.8021e-04 - Sales_mse: 6.8422e-04 - Sales_rmspe: 0.1441 - Customers_mse: 2.8021e-04 - Customers_rmspe: 0.1424
# Cat vars chosen: ['StateHoliday_bool_bw', 'PromoInterval', 'CompetitionMonthsOpen', 'Promo2SinceWeek', 'State', 'Promo_bw', 'SchoolHoliday_fw', 'Store', 'Week', 'Close_bool_bw', 'Promo2SinceYear', 'CompetitionOpenSinceYear', 'Day', 'Promo2', 'SchoolHoliday', 'DayOfWeek', 'Promo_fw', 'StateHoliday_bool_fw', 'StateHoliday']
# Cont vars chosen: ['trend_DE', 'Max_TemperatureC', 'BeforeSchoolHoliday', 'trend', 'Max_Humidity', 'AfterStateHoliday_bool', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'Min_Humidity', 'CloudCover', 'AfterClose_bool', 'Mean_TemperatureC', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 79s - loss: 0.0105 - Sales_loss: 0.0014 - Customers_loss: 6.1953e-04 - Sales_mse: 0.0014 - Sales_rmspe: 0.2854 - Customers_mse: 6.1953e-04 - Customers_rmspe: 0.2749 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 2.8042e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.1979 - val_Customers_mse: 2.8042e-04 - val_Customers_rmspe: 0.1710
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00138, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-3.hdf5
# Epoch 2/10
# 3181/3181 - 75s - loss: 0.0015 - Sales_loss: 9.3005e-04 - Customers_loss: 3.1141e-04 - Sales_mse: 9.3005e-04 - Sales_rmspe: 0.2363 - Customers_mse: 3.1141e-04 - Customers_rmspe: 0.2151 - val_loss: 0.0013 - val_Sales_loss: 8.3171e-04 - val_Customers_loss: 2.1188e-04 - val_Sales_mse: 8.3171e-04 - val_Sales_rmspe: 0.1605 - val_Customers_mse: 2.1188e-04 - val_Customers_rmspe: 0.1398
#
# Epoch 00002: val_Sales_mse improved from 0.00138 to 0.00083, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-3.hdf5
# Epoch 7/10
# 3181/3181 - 76s - loss: 9.3060e-04 - Sales_loss: 5.7533e-04 - Customers_loss: 1.9701e-04 - Sales_mse: 5.7533e-04 - Sales_rmspe: 0.1725 - Customers_mse: 1.9701e-04 - Customers_rmspe: 0.1543 - val_loss: 0.0011 - val_Sales_loss: 7.8758e-04 - val_Customers_loss: 2.0995e-04 - val_Sales_mse: 7.8758e-04 - val_Sales_rmspe: 0.1578 - val_Customers_mse: 2.0995e-04 - val_Customers_rmspe: 0.1420
#
# Epoch 00007: val_Sales_mse did not improve from 0.00072
# Epoch 8/10
# 3181/3181 - 75s - loss: 9.0870e-04 - Sales_loss: 5.6651e-04 - Customers_loss: 1.9168e-04 - Sales_mse: 5.6651e-04 - Sales_rmspe: 0.1701 - Customers_mse: 1.9168e-04 - Customers_rmspe: 0.1513 - val_loss: 0.0012 - val_Sales_loss: 8.0701e-04 - val_Customers_loss: 2.0001e-04 - val_Sales_mse: 8.0701e-04 - val_Sales_rmspe: 0.1506 - val_Customers_mse: 2.0001e-04 - val_Customers_rmspe: 0.1325
#
# Epoch 00008: val_Sales_mse did not improve from 0.00072
# Epoch 9/10
# 3181/3181 - 75s - loss: 8.8842e-04 - Sales_loss: 5.5459e-04 - Customers_loss: 1.8794e-04 - Sales_mse: 5.5459e-04 - Sales_rmspe: 0.1677 - Customers_mse: 1.8794e-04 - Customers_rmspe: 0.1491 - val_loss: 0.0011 - val_Sales_loss: 7.6369e-04 - val_Customers_loss: 1.9896e-04 - val_Sales_mse: 7.6369e-04 - val_Sales_rmspe: 0.1592 - val_Customers_mse: 1.9896e-04 - val_Customers_rmspe: 0.1354
#
# Epoch 00009: val_Sales_mse did not improve from 0.00072
# Epoch 10/10
# 3181/3181 - 75s - loss: 8.7439e-04 - Sales_loss: 5.4728e-04 - Customers_loss: 1.8580e-04 - Sales_mse: 5.4728e-04 - Sales_rmspe: 0.1666 - Customers_mse: 1.8580e-04 - Customers_rmspe: 0.1480 - val_loss: 0.0012 - val_Sales_loss: 8.3388e-04 - val_Customers_loss: 2.1275e-04 - val_Sales_mse: 8.3388e-04 - val_Sales_rmspe: 0.1520 - val_Customers_mse: 2.1275e-04 - val_Customers_rmspe: 0.1313
#
# Epoch 00010: val_Sales_mse did not improve from 0.00072
# Obtenemos las métricas
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0011 - Sales_loss: 7.1778e-04 - Customers_loss: 2.0272e-04 - Sales_mse: 7.1778e-04 - Sales_rmspe: 0.1561 - Customers_mse: 2.0272e-04 - Customers_rmspe: 0.1285
# Cont vars chosen: ['AfterSchoolHoliday', 'Mean_Humidity', 'CloudCover', 'BeforePromo', 'Min_Humidity', 'Max_Humidity', 'BeforeClose_bool', 'trend', 'CompetitionDistance', 'AfterPromo', 'BeforeSchoolHoliday', 'Mean_Wind_SpeedKm_h', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
# Cont vars chosen: ['AfterSchoolHoliday', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'BeforeStateHoliday_bool', 'trend_DE', 'Mean_Humidity', 'Max_Humidity', 'Max_TemperatureC', 'Precipitationmm', 'trend', 'AfterPromo', 'Mean_TemperatureC', 'Min_Humidity', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'BeforeClose_bool', 'CompetitionDistance', 'AfterStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 81s - loss: 0.0179 - Sales_loss: 9.1982e-04 - Customers_loss: 3.6527e-04 - Sales_mse: 9.1982e-04 - Sales_rmspe: 0.1843 - Customers_mse: 3.6527e-04 - Customers_rmspe: 0.1713 - val_loss: 0.0013 - val_Sales_loss: 6.9710e-04 - val_Customers_loss: 2.6215e-04 - val_Sales_mse: 6.9710e-04 - val_Sales_rmspe: 0.1679 - val_Customers_mse: 2.6215e-04 - val_Customers_rmspe: 0.1642
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00070, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-5.hdf5
# Epoch 2/10
# 3181/3181 - 78s - loss: 0.0010 - Sales_loss: 5.5780e-04 - Customers_loss: 2.0033e-04 - Sales_mse: 5.5780e-04 - Sales_rmspe: 0.1703 - Customers_mse: 2.0033e-04 - Customers_rmspe: 0.1537 - val_loss: 0.0011 - val_Sales_loss: 6.5973e-04 - val_Customers_loss: 2.2610e-04 - val_Sales_mse: 6.5973e-04 - val_Sales_rmspe: 0.1432 - val_Customers_mse: 2.2610e-04 - val_Customers_rmspe: 0.1334
#
# Epoch 00002: val_Sales_mse improved from 0.00070 to 0.00066, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-5.hdf5
# Epoch 3/10
# 3181/3181 - 78s - loss: 9.3998e-04 - Sales_loss: 5.3774e-04 - Customers_loss: 1.9097e-04 - Sales_mse: 5.3774e-04 - Sales_rmspe: 0.1665 - Customers_mse: 1.9097e-04 - Customers_rmspe: 0.1502 - val_loss: 0.0012 - val_Sales_loss: 6.9803e-04 - val_Customers_loss: 2.7551e-04 - val_Sales_mse: 6.9803e-04 - val_Sales_rmspe: 0.1742 - val_Customers_mse: 2.7551e-04 - val_Customers_rmspe: 0.1830
#
# Epoch 00003: val_Sales_mse did not improve from 0.00066
# Epoch 4/10
# 3181/3181 - 78s - loss: 8.9758e-04 - Sales_loss: 5.2886e-04 - Customers_loss: 1.8485e-04 - Sales_mse: 5.2886e-04 - Sales_rmspe: 0.1657 - Customers_mse: 1.8485e-04 - Customers_rmspe: 0.1480 - val_loss: 0.0010 - val_Sales_loss: 6.2912e-04 - val_Customers_loss: 2.2533e-04 - val_Sales_mse: 6.2912e-04 - val_Sales_rmspe: 0.1535 - val_Customers_mse: 2.2533e-04 - val_Customers_rmspe: 0.1358
#
# Epoch 00004: val_Sales_mse improved from 0.00066 to 0.00063, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 76s - loss: 8.1186e-04 - Sales_loss: 5.0471e-04 - Customers_loss: 1.7503e-04 - Sales_mse: 5.0471e-04 - Sales_rmspe: 0.1606 - Customers_mse: 1.7503e-04 - Customers_rmspe: 0.1429 - val_loss: 9.5768e-04 - val_Sales_loss: 6.0534e-04 - val_Customers_loss: 2.1600e-04 - val_Sales_mse: 6.0534e-04 - val_Sales_rmspe: 0.1494 - val_Customers_mse: 2.1600e-04 - val_Customers_rmspe: 0.1284
#
# Epoch 00010: val_Sales_mse did not improve from 0.00058
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 9.1385e-04 - Sales_loss: 5.7865e-04 - Customers_loss: 1.9634e-04 - Sales_mse: 5.7865e-04 - Sales_rmspe: 0.1410 - Customers_mse: 1.9634e-04 - Customers_rmspe: 0.1216
# Cat vars chosen: ['Year', 'PromoInterval', 'Promo', 'Week', 'StateHoliday', 'Promo_fw', 'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'Month', 'Promo2SinceYear', 'DayOfWeek', 'Close_bool_fw', 'Assortment', 'SchoolHoliday', 'SchoolHoliday_bw', 'State', 'Promo2SinceWeek', 'Day', 'Events', 'Promo2Weeks', 'CompetitionOpenSinceYear', 'StoreType', 'StateHoliday_bool_fw', 'Store', 'Promo2']
# Cont vars chosen: ['trend_DE', 'Max_TemperatureC', 'BeforeSchoolHoliday', 'trend', 'Max_Humidity', 'AfterStateHoliday_bool', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'Min_Humidity', 'CloudCover', 'AfterClose_bool', 'Mean_TemperatureC', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# ...
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 82s - loss: 0.0163 - Sales_loss: 0.0010 - Customers_loss: 2.4521e-04 - Sales_mse: 0.0010 - Sales_rmspe: 0.1884 - Customers_mse: 2.4521e-04 - Customers_rmspe: 0.1694 - val_loss: 0.0012 - val_Sales_loss: 6.9294e-04 - val_Customers_loss: 2.6177e-04 - val_Sales_mse: 6.9294e-04 - val_Sales_rmspe: 0.1508 - val_Customers_mse: 2.6177e-04 - val_Customers_rmspe: 0.1443
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00069, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-7.hdf5
# Epoch 2/10
# 3181/3181 - 78s - loss: 0.0010 - Sales_loss: 5.8378e-04 - Customers_loss: 2.0763e-04 - Sales_mse: 5.8378e-04 - Sales_rmspe: 0.1750 - Customers_mse: 2.0763e-04 - Customers_rmspe: 0.1590 - val_loss: 0.0013 - val_Sales_loss: 7.6277e-04 - val_Customers_loss: 2.8435e-04 - val_Sales_mse: 7.6277e-04 - val_Sales_rmspe: 0.1681 - val_Customers_mse: 2.8435e-04 - val_Customers_rmspe: 0.1723
# Epoch 8/10
# 3181/3181 - 79s - loss: 8.5325e-04 - Sales_loss: 5.3694e-04 - Customers_loss: 1.8695e-04 - Sales_mse: 5.3694e-04 - Sales_rmspe: 0.1668 - Customers_mse: 1.8695e-04 - Customers_rmspe: 0.1490 - val_loss: 9.7781e-04 - val_Sales_loss: 6.4759e-04 - val_Customers_loss: 2.0407e-04 - val_Sales_mse: 6.4759e-04 - val_Sales_rmspe: 0.1597 - val_Customers_mse: 2.0407e-04 - val_Customers_rmspe: 0.1328
#
# Epoch 00008: val_Sales_mse improved from 0.00067 to 0.00065, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-7.hdf5
# Epoch 9/10
# 3181/3181 - 78s - loss: 8.4368e-04 - Sales_loss: 5.3230e-04 - Customers_loss: 1.8427e-04 - Sales_mse: 5.3230e-04 - Sales_rmspe: 0.1649 - Customers_mse: 1.8427e-04 - Customers_rmspe: 0.1471 - val_loss: 9.5910e-04 - val_Sales_loss: 6.2163e-04 - val_Customers_loss: 2.1574e-04 - val_Sales_mse: 6.2163e-04 - val_Sales_rmspe: 0.1471 - val_Customers_mse: 2.1574e-04 - val_Customers_rmspe: 0.1369
#
# Epoch 00009: val_Sales_mse improved from 0.00065 to 0.00062, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel2-7.hdf5
# Epoch 10/10
# 3181/3181 - 78s - loss: 8.3645e-04 - Sales_loss: 5.2882e-04 - Customers_loss: 1.8288e-04 - Sales_mse: 5.2882e-04 - Sales_rmspe: 0.1643 - Customers_mse: 1.8288e-04 - Customers_rmspe: 0.1465 - val_loss: 0.0011 - val_Sales_loss: 7.1861e-04 - val_Customers_loss: 2.4874e-04 - val_Sales_mse: 7.1861e-04 - val_Sales_rmspe: 0.1570 - val_Customers_mse: 2.4874e-04 - val_Customers_rmspe: 0.1513
#
# Epoch 00010: val_Sales_mse did not improve from 0.00062
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 9.5910e-04 - Sales_loss: 6.2163e-04 - Customers_loss: 2.1574e-04 - Sales_mse: 6.2163e-04 - Sales_rmspe: 0.1436 - Customers_mse: 2.1574e-04 - Customers_rmspe: 0.1340
# Cont vars chosen: ['AfterSchoolHoliday', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'BeforeStateHoliday_bool', 'trend_DE', 'Mean_Humidity', 'Max_Humidity', 'Max_TemperatureC', 'Precipitationmm', 'trend', 'AfterPromo', 'Mean_TemperatureC', 'Min_Humidity', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'BeforeClose_bool', 'CompetitionDistance', 'AfterStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>]
# Normalizamos el dataset
# Entrenamos el modelo