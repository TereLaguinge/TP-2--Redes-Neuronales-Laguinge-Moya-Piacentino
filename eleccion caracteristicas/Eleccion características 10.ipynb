# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=6f16ef28d17cc0c6f88816230753079907e519b257d9ba8460658146f1c6c9a6
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 252

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion10.csv")
# Out:
# Cat vars chosen: ['Promo2SinceYear', 'StateHoliday_bool_fw', 'SchoolHoliday_fw', 'Assortment', 'Week', 'Promo2Weeks', 'Day', 'Year', 'Promo', 'Promo2SinceWeek', 'State', 'Month', 'CompetitionOpenSinceYear', 'Promo_fw', 'PromoInterval', 'DayOfWeek', 'Close_bool_fw', 'Promo_bw', 'SchoolHoliday', 'StateHoliday_bool_bw']
# Cont vars chosen: ['Min_Humidity', 'StateHoliday_bool', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo', 'Mean_Humidity', 'Max_Humidity', 'BeforeStateHoliday_bool', 'trend', 'Max_TemperatureC', 'BeforeSchoolHoliday', 'Precipitationmm', 'AfterPromo', 'BeforeClose_bool', 'Mean_TemperatureC', 'AfterSchoolHoliday', 'trend_DE', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 88s - loss: 0.0161 - Sales_loss: 0.0041 - Customers_loss: 0.0021 - Sales_mse: 0.0041 - Sales_rmspe: 0.4825 - Customers_mse: 0.0021 - Customers_rmspe: 0.4953 - val_loss: 0.0134 - val_Sales_loss: 0.0054 - val_Customers_loss: 0.0076 - val_Sales_mse: 0.0054 - val_Sales_rmspe: 0.4861 - val_Customers_mse: 0.0076 - val_Customers_rmspe: 0.7915
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 83s - loss: 0.0051 - Sales_loss: 0.0032 - Customers_loss: 0.0016 - Sales_mse: 0.0032 - Sales_rmspe: 0.4331 - Customers_mse: 0.0016 - Customers_rmspe: 0.4513 - val_loss: 0.0107 - val_Sales_loss: 0.0055 - val_Customers_loss: 0.0049 - val_Sales_mse: 0.0055 - val_Sales_rmspe: 0.4661 - val_Customers_mse: 0.0049 - val_Customers_rmspe: 0.6549
#
# Epoch 00007: val_Sales_mse did not improve from 0.00536
# Epoch 8/10
# 3181/3181 - 83s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0016 - Sales_mse: 0.0032 - Sales_rmspe: 0.4301 - Customers_mse: 0.0016 - Customers_rmspe: 0.4483 - val_loss: 0.0103 - val_Sales_loss: 0.0052 - val_Customers_loss: 0.0049 - val_Sales_mse: 0.0052 - val_Sales_rmspe: 0.4593 - val_Customers_mse: 0.0049 - val_Customers_rmspe: 0.6596
#
# Epoch 00008: val_Sales_mse improved from 0.00536 to 0.00520, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-0.hdf5
# Epoch 9/10
# 3181/3181 - 83s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0016 - Sales_mse: 0.0032 - Sales_rmspe: 0.4286 - Customers_mse: 0.0016 - Customers_rmspe: 0.4474 - val_loss: 0.0116 - val_Sales_loss: 0.0057 - val_Customers_loss: 0.0057 - val_Sales_mse: 0.0057 - val_Sales_rmspe: 0.4796 - val_Customers_mse: 0.0057 - val_Customers_rmspe: 0.6816
#
# Epoch 00009: val_Sales_mse did not improve from 0.00520
# Epoch 10/10
# 3181/3181 - 84s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0016 - Sales_mse: 0.0032 - Sales_rmspe: 0.4278 - Customers_mse: 0.0016 - Customers_rmspe: 0.4473 - val_loss: 0.0112 - val_Sales_loss: 0.0058 - val_Customers_loss: 0.0052 - val_Sales_mse: 0.0058 - val_Sales_rmspe: 0.5032 - val_Customers_mse: 0.0052 - val_Customers_rmspe: 0.6872
#
# Epoch 00010: val_Sales_mse did not improve from 0.00520
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0103 - Sales_loss: 0.0052 - Customers_loss: 0.0049 - Sales_mse: 0.0052 - Sales_rmspe: 0.4482 - Customers_mse: 0.0049 - Customers_rmspe: 0.6494
# Cont vars chosen: ['Mean_Humidity', 'Precipitationmm', 'AfterSchoolHoliday', 'BeforeSchoolHoliday', 'trend_DE', 'StateHoliday_bool', 'AfterPromo', 'BeforePromo', 'CompetitionDistance', 'Max_Wind_SpeedKm_h', 'Max_TemperatureC', 'Min_Humidity', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool', 'Mean_TemperatureC', 'CloudCover', 'Mean_Wind_SpeedKm_h', 'Max_Humidity']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-1.hdf5
# Epoch 7/10
# 3181/3181 - 83s - loss: 0.0043 - Sales_loss: 0.0025 - Customers_loss: 0.0012 - Sales_mse: 0.0025 - Sales_rmspe: 0.3687 - Customers_mse: 0.0012 - Customers_rmspe: 0.3724 - val_loss: 0.0098 - val_Sales_loss: 0.0050 - val_Customers_loss: 0.0043 - val_Sales_mse: 0.0050 - val_Sales_rmspe: 0.4364 - val_Customers_mse: 0.0043 - val_Customers_rmspe: 0.6007
#
# Epoch 00007: val_Sales_mse improved from 0.00532 to 0.00501, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-1.hdf5
# Epoch 8/10
# 3181/3181 - 84s - loss: 0.0042 - Sales_loss: 0.0025 - Customers_loss: 0.0012 - Sales_mse: 0.0025 - Sales_rmspe: 0.3670 - Customers_mse: 0.0012 - Customers_rmspe: 0.3697 - val_loss: 0.0105 - val_Sales_loss: 0.0054 - val_Customers_loss: 0.0046 - val_Sales_mse: 0.0054 - val_Sales_rmspe: 0.4191 - val_Customers_mse: 0.0046 - val_Customers_rmspe: 0.5620
#
# Epoch 00008: val_Sales_mse did not improve from 0.00501
# Epoch 9/10
# 3181/3181 - 83s - loss: 0.0042 - Sales_loss: 0.0025 - Customers_loss: 0.0012 - Sales_mse: 0.0025 - Sales_rmspe: 0.3660 - Customers_mse: 0.0012 - Customers_rmspe: 0.3694 - val_loss: 0.0085 - val_Sales_loss: 0.0043 - val_Customers_loss: 0.0037 - val_Sales_mse: 0.0043 - val_Sales_rmspe: 0.3999 - val_Customers_mse: 0.0037 - val_Customers_rmspe: 0.5348
#
# Epoch 00009: val_Sales_mse improved from 0.00501 to 0.00430, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-1.hdf5
# Epoch 10/10
# 3181/3181 - 83s - loss: 0.0042 - Sales_loss: 0.0025 - Customers_loss: 0.0012 - Sales_mse: 0.0025 - Sales_rmspe: 0.3653 - Customers_mse: 0.0012 - Customers_rmspe: 0.3674 - val_loss: 0.0093 - val_Sales_loss: 0.0046 - val_Customers_loss: 0.0042 - val_Sales_mse: 0.0046 - val_Sales_rmspe: 0.4092 - val_Customers_mse: 0.0042 - val_Customers_rmspe: 0.5662
#
# Epoch 00010: val_Sales_mse did not improve from 0.00430
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0085 - Sales_loss: 0.0043 - Customers_loss: 0.0037 - Sales_mse: 0.0043 - Sales_rmspe: 0.3886 - Customers_mse: 0.0037 - Customers_rmspe: 0.5228
# Cont vars chosen: ['AfterClose_bool', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'Mean_Humidity', 'BeforePromo', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'BeforeClose_bool', 'CloudCover', 'AfterSchoolHoliday', 'Min_TemperatureC', 'Min_Humidity', 'Mean_TemperatureC', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
# Epoch 00006: val_Sales_mse did not improve from 0.00452
# Epoch 7/10
# 3181/3181 - 82s - loss: 0.0043 - Sales_loss: 0.0026 - Customers_loss: 0.0013 - Sales_mse: 0.0026 - Sales_rmspe: 0.3654 - Customers_mse: 0.0013 - Customers_rmspe: 0.3820 - val_loss: 0.0117 - val_Sales_loss: 0.0057 - val_Customers_loss: 0.0056 - val_Sales_mse: 0.0057 - val_Sales_rmspe: 0.4268 - val_Customers_mse: 0.0056 - val_Customers_rmspe: 0.6061
#
# Epoch 00007: val_Sales_mse did not improve from 0.00452
# Epoch 8/10
# 3181/3181 - 82s - loss: 0.0043 - Sales_loss: 0.0025 - Customers_loss: 0.0013 - Sales_mse: 0.0025 - Sales_rmspe: 0.3637 - Customers_mse: 0.0013 - Customers_rmspe: 0.3812 - val_loss: 0.0134 - val_Sales_loss: 0.0069 - val_Customers_loss: 0.0060 - val_Sales_mse: 0.0069 - val_Sales_rmspe: 0.5029 - val_Customers_mse: 0.0060 - val_Customers_rmspe: 0.6973
#
# Epoch 00008: val_Sales_mse did not improve from 0.00452
# Epoch 9/10
# 3181/3181 - 83s - loss: 0.0043 - Sales_loss: 0.0025 - Customers_loss: 0.0013 - Sales_mse: 0.0025 - Sales_rmspe: 0.3619 - Customers_mse: 0.0013 - Customers_rmspe: 0.3803 - val_loss: 0.0115 - val_Sales_loss: 0.0059 - val_Customers_loss: 0.0052 - val_Sales_mse: 0.0059 - val_Sales_rmspe: 0.4328 - val_Customers_mse: 0.0052 - val_Customers_rmspe: 0.6174
#
# Epoch 00009: val_Sales_mse did not improve from 0.00452
# Epoch 10/10
# 3181/3181 - 84s - loss: 0.0042 - Sales_loss: 0.0025 - Customers_loss: 0.0013 - Sales_mse: 0.0025 - Sales_rmspe: 0.3603 - Customers_mse: 0.0013 - Customers_rmspe: 0.3790 - val_loss: 0.0111 - val_Sales_loss: 0.0058 - val_Customers_loss: 0.0049 - val_Sales_mse: 0.0058 - val_Sales_rmspe: 0.4314 - val_Customers_mse: 0.0049 - val_Customers_rmspe: 0.5929
#
# Epoch 00010: val_Sales_mse did not improve from 0.00452
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 0.0087 - Sales_loss: 0.0045 - Customers_loss: 0.0037 - Sales_mse: 0.0045 - Sales_rmspe: 0.3979 - Customers_mse: 0.0037 - Customers_rmspe: 0.5358
# Cat vars chosen: ['SchoolHoliday_bw', 'CompetitionMonthsOpen', 'PromoInterval', 'SchoolHoliday', 'Promo2SinceWeek', 'State', 'Year', 'StateHoliday_bool_fw', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'Store', 'Month', 'StateHoliday']
# Cont vars chosen: ['Min_Humidity', 'StateHoliday_bool', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo', 'Mean_Humidity', 'Max_Humidity', 'BeforeStateHoliday_bool', 'trend', 'Max_TemperatureC', 'BeforeSchoolHoliday', 'Precipitationmm', 'AfterPromo', 'BeforeClose_bool', 'Mean_TemperatureC', 'AfterSchoolHoliday', 'trend_DE', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
# Cont vars chosen: ['Mean_Humidity', 'Precipitationmm', 'AfterSchoolHoliday', 'BeforeSchoolHoliday', 'trend_DE', 'StateHoliday_bool', 'AfterPromo', 'BeforePromo', 'CompetitionDistance', 'Max_Wind_SpeedKm_h', 'Max_TemperatureC', 'Min_Humidity', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool', 'Mean_TemperatureC', 'CloudCover', 'Mean_Wind_SpeedKm_h', 'Max_Humidity']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 4
# Epoch 1/10
# 3181/3181 - 89s - loss: 0.0133 - Sales_loss: 0.0013 - Customers_loss: 4.9470e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2642 - Customers_mse: 4.9470e-04 - Customers_rmspe: 0.2504 - val_loss: 0.0016 - val_Sales_loss: 9.5812e-04 - val_Customers_loss: 3.2010e-04 - val_Sales_mse: 9.5812e-04 - val_Sales_rmspe: 0.1921 - val_Customers_mse: 3.2010e-04 - val_Customers_rmspe: 0.1828
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00096, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-4.hdf5
# Epoch 2/10
# 3181/3181 - 86s - loss: 0.0017 - Sales_loss: 0.0011 - Customers_loss: 3.4508e-04 - Sales_mse: 0.0011 - Sales_rmspe: 0.2473 - Customers_mse: 3.4508e-04 - Customers_rmspe: 0.2310 - val_loss: 0.0017 - val_Sales_loss: 0.0011 - val_Customers_loss: 3.6870e-04 - val_Sales_mse: 0.0011 - val_Sales_rmspe: 0.2102 - val_Customers_mse: 3.6870e-04 - val_Customers_rmspe: 0.2024
#
# Epoch 00002: val_Sales_mse did not improve from 0.00096
# Epoch 3/10
# 3181/3181 - 86s - loss: 0.0016 - Sales_loss: 0.0011 - Customers_loss: 3.3637e-04 - Sales_mse: 0.0011 - Sales_rmspe: 0.2421 - Customers_mse: 3.3637e-04 - Customers_rmspe: 0.2271 - val_loss: 0.0019 - val_Sales_loss: 0.0013 - val_Customers_loss: 4.1035e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2443 - val_Customers_mse: 4.1035e-04 - val_Customers_rmspe: 0.2229
#
# Epoch 00003: val_Sales_mse did not improve from 0.00096
# Epoch 4/10
# 3181/3181 - 86s - loss: 0.0016 - Sales_loss: 0.0010 - Customers_loss: 3.2924e-04 - Sales_mse: 0.0010 - Sales_rmspe: 0.2392 - Customers_mse: 3.2924e-04 - Customers_rmspe: 0.2241 - val_loss: 0.0014 - val_Sales_loss: 9.5215e-04 - val_Customers_loss: 2.9791e-04 - val_Sales_mse: 9.5215e-04 - val_Sales_rmspe: 0.2003 - val_Customers_mse: 2.9791e-04 - val_Customers_rmspe: 0.1749
#
# Epoch 00004: val_Sales_mse improved from 0.00096 to 0.00095, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00010: val_Sales_mse did not improve from 0.00095
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0015 - Sales_loss: 9.4853e-04 - Customers_loss: 3.3446e-04 - Sales_mse: 9.4853e-04 - Sales_rmspe: 0.1885 - Customers_mse: 3.3446e-04 - Customers_rmspe: 0.1891
# Cont vars chosen: ['AfterClose_bool', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'Mean_Humidity', 'BeforePromo', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'BeforeClose_bool', 'CloudCover', 'AfterSchoolHoliday', 'Min_TemperatureC', 'Min_Humidity', 'Mean_TemperatureC', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 87s - loss: 0.0138 - Sales_loss: 0.0014 - Customers_loss: 3.8836e-04 - Sales_mse: 0.0014 - Sales_rmspe: 0.2611 - Customers_mse: 3.8836e-04 - Customers_rmspe: 0.2419 - val_loss: 0.0018 - val_Sales_loss: 0.0011 - val_Customers_loss: 3.3916e-04 - val_Sales_mse: 0.0011 - val_Sales_rmspe: 0.2250 - val_Customers_mse: 3.3916e-04 - val_Customers_rmspe: 0.2037
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00109, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-5.hdf5
# Epoch 2/10
# 3181/3181 - 84s - loss: 0.0017 - Sales_loss: 0.0010 - Customers_loss: 3.2437e-04 - Sales_mse: 0.0010 - Sales_rmspe: 0.2341 - Customers_mse: 3.2437e-04 - Customers_rmspe: 0.2185 - val_loss: 0.0015 - val_Sales_loss: 9.5556e-04 - val_Customers_loss: 3.1103e-04 - val_Sales_mse: 9.5556e-04 - val_Sales_rmspe: 0.1687 - val_Customers_mse: 3.1103e-04 - val_Customers_rmspe: 0.1581
#
# Epoch 00002: val_Sales_mse improved from 0.00109 to 0.00096, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-5.hdf5
# Epoch 3/10
# 3181/3181 - 83s - loss: 0.0015 - Sales_loss: 9.8027e-04 - Customers_loss: 3.0826e-04 - Sales_mse: 9.8027e-04 - Sales_rmspe: 0.2271 - Customers_mse: 3.0826e-04 - Customers_rmspe: 0.2117 - val_loss: 0.0015 - val_Sales_loss: 9.9760e-04 - val_Customers_loss: 3.1500e-04 - val_Sales_mse: 9.9760e-04 - val_Sales_rmspe: 0.1738 - val_Customers_mse: 3.1500e-04 - val_Customers_rmspe: 0.1625
#
# Epoch 00003: val_Sales_mse did not improve from 0.00096
# Epoch 4/10
# 3181/3181 - 83s - loss: 0.0015 - Sales_loss: 9.5830e-04 - Customers_loss: 3.0328e-04 - Sales_mse: 9.5830e-04 - Sales_rmspe: 0.2240 - Customers_mse: 3.0328e-04 - Customers_rmspe: 0.2087 - val_loss: 0.0016 - val_Sales_loss: 0.0011 - val_Customers_loss: 3.0910e-04 - val_Sales_mse: 0.0011 - val_Sales_rmspe: 0.1748 - val_Customers_mse: 3.0910e-04 - val_Customers_rmspe: 0.1581
#
# Epoch 00009: val_Sales_mse did not improve from 0.00094
# Epoch 10/10
# 3181/3181 - 84s - loss: 0.0014 - Sales_loss: 9.2237e-04 - Customers_loss: 2.9195e-04 - Sales_mse: 9.2237e-04 - Sales_rmspe: 0.2206 - Customers_mse: 2.9195e-04 - Customers_rmspe: 0.2048 - val_loss: 0.0014 - val_Sales_loss: 9.2255e-04 - val_Customers_loss: 2.6781e-04 - val_Sales_mse: 9.2255e-04 - val_Sales_rmspe: 0.1746 - val_Customers_mse: 2.6781e-04 - val_Customers_rmspe: 0.1642
#
# Epoch 00010: val_Sales_mse improved from 0.00094 to 0.00092, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-5.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 0.0014 - Sales_loss: 9.2255e-04 - Customers_loss: 2.6781e-04 - Sales_mse: 9.2255e-04 - Sales_rmspe: 0.1701 - Customers_mse: 2.6781e-04 - Customers_rmspe: 0.1600
# Cat vars chosen: ['StateHoliday_bool_fw', 'Store', 'SchoolHoliday_fw', 'CompetitionMonthsOpen', 'Promo_bw', 'Promo2', 'Promo', 'State', 'Close_bool_fw', 'Promo2Weeks', 'PromoInterval', 'Week', 'Promo2SinceYear', 'StoreType', 'SchoolHoliday_bw']
# Cont vars chosen: ['Min_Humidity', 'StateHoliday_bool', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo', 'Mean_Humidity', 'Max_Humidity', 'BeforeStateHoliday_bool', 'trend', 'Max_TemperatureC', 'BeforeSchoolHoliday', 'Precipitationmm', 'AfterPromo', 'BeforeClose_bool', 'Mean_TemperatureC', 'AfterSchoolHoliday', 'trend_DE', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 6
# Epoch 1/10
# 3181/3181 - 90s - loss: 0.0106 - Sales_loss: 0.0014 - Customers_loss: 6.2715e-04 - Sales_mse: 0.0014 - Sales_rmspe: 0.2769 - Customers_mse: 6.2715e-04 - Customers_rmspe: 0.2752 - val_loss: 0.0016 - val_Sales_loss: 9.0104e-04 - val_Customers_loss: 3.8692e-04 - val_Sales_mse: 9.0104e-04 - val_Sales_rmspe: 0.1985 - val_Customers_mse: 3.8692e-04 - val_Customers_rmspe: 0.2143
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00090, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-6.hdf5
# Epoch 2/10
# 3181/3181 - 87s - loss: 0.0015 - Sales_loss: 9.3315e-04 - Customers_loss: 3.2508e-04 - Sales_mse: 9.3315e-04 - Sales_rmspe: 0.2347 - Customers_mse: 3.2508e-04 - Customers_rmspe: 0.2238 - val_loss: 0.0016 - val_Sales_loss: 8.7795e-04 - val_Customers_loss: 4.6322e-04 - val_Sales_mse: 8.7795e-04 - val_Sales_rmspe: 0.1865 - val_Customers_mse: 4.6322e-04 - val_Customers_rmspe: 0.2070
#
# Epoch 00002: val_Sales_mse improved from 0.00090 to 0.00088, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 89s - loss: 0.0011 - Sales_loss: 7.0062e-04 - Customers_loss: 2.4153e-04 - Sales_mse: 7.0062e-04 - Sales_rmspe: 0.1968 - Customers_mse: 2.4153e-04 - Customers_rmspe: 0.1809 - val_loss: 0.0013 - val_Sales_loss: 8.8356e-04 - val_Customers_loss: 3.1537e-04 - val_Sales_mse: 8.8356e-04 - val_Sales_rmspe: 0.1908 - val_Customers_mse: 3.1537e-04 - val_Customers_rmspe: 0.1804
#
# Epoch 00008: val_Sales_mse did not improve from 0.00068
# Epoch 9/10
# 3181/3181 - 89s - loss: 0.0011 - Sales_loss: 7.0027e-04 - Customers_loss: 2.4096e-04 - Sales_mse: 7.0027e-04 - Sales_rmspe: 0.1958 - Customers_mse: 2.4096e-04 - Customers_rmspe: 0.1798 - val_loss: 0.0011 - val_Sales_loss: 7.2509e-04 - val_Customers_loss: 2.5638e-04 - val_Sales_mse: 7.2509e-04 - val_Sales_rmspe: 0.1657 - val_Customers_mse: 2.5638e-04 - val_Customers_rmspe: 0.1512
#
# Epoch 00009: val_Sales_mse did not improve from 0.00068
# Epoch 10/10
# 3181/3181 - 88s - loss: 0.0011 - Sales_loss: 6.9908e-04 - Customers_loss: 2.4092e-04 - Sales_mse: 6.9908e-04 - Sales_rmspe: 0.1955 - Customers_mse: 2.4092e-04 - Customers_rmspe: 0.1800 - val_loss: 0.0012 - val_Sales_loss: 7.7367e-04 - val_Customers_loss: 2.7093e-04 - val_Sales_mse: 7.7367e-04 - val_Sales_rmspe: 0.1657 - val_Customers_mse: 2.7093e-04 - val_Customers_rmspe: 0.1570
#
# Epoch 00010: val_Sales_mse did not improve from 0.00068
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 0.0011 - Sales_loss: 6.8402e-04 - Customers_loss: 2.5750e-04 - Sales_mse: 6.8402e-04 - Sales_rmspe: 0.1531 - Customers_mse: 2.5750e-04 - Customers_rmspe: 0.1533
# Cont vars chosen: ['Mean_Humidity', 'Precipitationmm', 'AfterSchoolHoliday', 'BeforeSchoolHoliday', 'trend_DE', 'StateHoliday_bool', 'AfterPromo', 'BeforePromo', 'CompetitionDistance', 'Max_Wind_SpeedKm_h', 'Max_TemperatureC', 'Min_Humidity', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool', 'Mean_TemperatureC', 'CloudCover', 'Mean_Wind_SpeedKm_h', 'Max_Humidity']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 92s - loss: 0.0149 - Sales_loss: 0.0011 - Customers_loss: 3.1969e-04 - Sales_mse: 0.0011 - Sales_rmspe: 0.2205 - Customers_mse: 3.1969e-04 - Customers_rmspe: 0.2058 - val_loss: 0.0014 - val_Sales_loss: 8.4090e-04 - val_Customers_loss: 3.0928e-04 - val_Sales_mse: 8.4090e-04 - val_Sales_rmspe: 0.1848 - val_Customers_mse: 3.0928e-04 - val_Customers_rmspe: 0.1726
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 87s - loss: 0.0011 - Sales_loss: 6.9069e-04 - Customers_loss: 2.3756e-04 - Sales_mse: 6.9069e-04 - Sales_rmspe: 0.1934 - Customers_mse: 2.3756e-04 - Customers_rmspe: 0.1774 - val_loss: 0.0013 - val_Sales_loss: 8.2178e-04 - val_Customers_loss: 3.1307e-04 - val_Sales_mse: 8.2178e-04 - val_Sales_rmspe: 0.1784 - val_Customers_mse: 3.1307e-04 - val_Customers_rmspe: 0.1659
#
# Epoch 00007: val_Sales_mse did not improve from 0.00073
# Epoch 8/10
# 3181/3181 - 86s - loss: 0.0011 - Sales_loss: 6.8597e-04 - Customers_loss: 2.3565e-04 - Sales_mse: 6.8597e-04 - Sales_rmspe: 0.1922 - Customers_mse: 2.3565e-04 - Customers_rmspe: 0.1761 - val_loss: 0.0013 - val_Sales_loss: 7.5441e-04 - val_Customers_loss: 3.7395e-04 - val_Sales_mse: 7.5441e-04 - val_Sales_rmspe: 0.1634 - val_Customers_mse: 3.7395e-04 - val_Customers_rmspe: 0.1878
#
# Epoch 00008: val_Sales_mse did not improve from 0.00073
# Epoch 9/10
# 3181/3181 - 87s - loss: 0.0010 - Sales_loss: 6.8077e-04 - Customers_loss: 2.3523e-04 - Sales_mse: 6.8077e-04 - Sales_rmspe: 0.1920 - Customers_mse: 2.3523e-04 - Customers_rmspe: 0.1766 - val_loss: 0.0011 - val_Sales_loss: 6.8380e-04 - val_Customers_loss: 2.7699e-04 - val_Sales_mse: 6.8380e-04 - val_Sales_rmspe: 0.1569 - val_Customers_mse: 2.7699e-04 - val_Customers_rmspe: 0.1522
#
# Epoch 00009: val_Sales_mse improved from 0.00073 to 0.00068, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel10-7.hdf5
# Epoch 10/10
# 3181/3181 - 87s - loss: 0.0010 - Sales_loss: 6.7799e-04 - Customers_loss: 2.3372e-04 - Sales_mse: 6.7799e-04 - Sales_rmspe: 0.1911 - Customers_mse: 2.3372e-04 - Customers_rmspe: 0.1756 - val_loss: 0.0012 - val_Sales_loss: 7.6083e-04 - val_Customers_loss: 2.9391e-04 - val_Sales_mse: 7.6083e-04 - val_Sales_rmspe: 0.1656 - val_Customers_mse: 2.9391e-04 - val_Customers_rmspe: 0.1540
#
# Epoch 00010: val_Sales_mse did not improve from 0.00068
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0011 - Sales_loss: 6.8380e-04 - Customers_loss: 2.7699e-04 - Sales_mse: 6.8380e-04 - Sales_rmspe: 0.1530 - Customers_mse: 2.7699e-04 - Customers_rmspe: 0.1494
# Cont vars chosen: ['AfterClose_bool', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'Mean_Humidity', 'BeforePromo', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'BeforeClose_bool', 'CloudCover', 'AfterSchoolHoliday', 'Min_TemperatureC', 'Min_Humidity', 'Mean_TemperatureC', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 