# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=ad6fe63d1df85daa888d1f362e018bd0763efa309f58c57c69105b53fa236f23
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 594

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion3.csv")
# Out:
# Cat vars chosen: ['SchoolHoliday', 'Promo2Weeks', 'StateHoliday_bool_fw', 'Promo', 'Promo2', 'DayOfWeek', 'Close_bool_fw', 'StateHoliday', 'Month', 'Year', 'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'StoreType', 'Promo_bw', 'Assortment', 'Day', 'PromoInterval', 'CompetitionMonthsOpen', 'Promo2SinceWeek', 'CompetitionOpenSinceYear', 'SchoolHoliday_bw', 'Week']
# Cont vars chosen: ['trend', 'BeforeSchoolHoliday', 'Max_Humidity', 'Mean_Wind_SpeedKm_h', 'Precipitationmm', 'AfterPromo', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Min_TemperatureC', 'BeforePromo', 'CompetitionDistance', 'Max_TemperatureC', 'BeforeClose_bool', 'Mean_TemperatureC', 'BeforeStateHoliday_bool', 'StateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 75s - loss: 0.0141 - Sales_loss: 0.0041 - Customers_loss: 0.0019 - Sales_mse: 0.0041 - Sales_rmspe: 0.4872 - Customers_mse: 0.0019 - Customers_rmspe: 0.4872 - val_loss: 0.0058 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4387 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4711
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00369, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 71s - loss: 0.0050 - Sales_loss: 0.0033 - Customers_loss: 0.0014 - Sales_mse: 0.0033 - Sales_rmspe: 0.4184 - Customers_mse: 0.0014 - Customers_rmspe: 0.4129 - val_loss: 0.0055 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.4056 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4667
#
# Epoch 00008: val_Sales_mse improved from 0.00357 to 0.00346, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-0.hdf5
# Epoch 9/10
# 3181/3181 - 71s - loss: 0.0050 - Sales_loss: 0.0032 - Customers_loss: 0.0014 - Sales_mse: 0.0032 - Sales_rmspe: 0.4170 - Customers_mse: 0.0014 - Customers_rmspe: 0.4105 - val_loss: 0.0056 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.3806 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4296
#
# Epoch 00009: val_Sales_mse did not improve from 0.00346
# Epoch 10/10
# 3181/3181 - 71s - loss: 0.0049 - Sales_loss: 0.0032 - Customers_loss: 0.0014 - Sales_mse: 0.0032 - Sales_rmspe: 0.4157 - Customers_mse: 0.0014 - Customers_rmspe: 0.4087 - val_loss: 0.0053 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.3921 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4487
#
# Epoch 00010: val_Sales_mse improved from 0.00346 to 0.00337, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-0.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0053 - Sales_loss: 0.0034 - Customers_loss: 0.0017 - Sales_mse: 0.0034 - Sales_rmspe: 0.3816 - Customers_mse: 0.0017 - Customers_rmspe: 0.4388
# Cont vars chosen: ['trend_DE', 'Min_TemperatureC', 'CompetitionDistance', 'Precipitationmm', 'BeforeStateHoliday_bool', 'StateHoliday_bool', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Min_Humidity', 'BeforePromo', 'CloudCover', 'Mean_Humidity', 'BeforeSchoolHoliday', 'Mean_Wind_SpeedKm_h', 'BeforeClose_bool', 'Max_Humidity', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 75s - loss: 0.0208 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4336 - Customers_mse: 0.0017 - Customers_rmspe: 0.4354 - val_loss: 0.0059 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.4318 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4761
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00350, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 70s - loss: 0.0046 - Sales_loss: 0.0029 - Customers_loss: 0.0013 - Sales_mse: 0.0029 - Sales_rmspe: 0.3904 - Customers_mse: 0.0013 - Customers_rmspe: 0.3868 - val_loss: 0.0066 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0024 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4095 - val_Customers_mse: 0.0024 - val_Customers_rmspe: 0.5266
#
# Epoch 00008: val_Sales_mse did not improve from 0.00350
# Epoch 9/10
# 3181/3181 - 70s - loss: 0.0046 - Sales_loss: 0.0029 - Customers_loss: 0.0013 - Sales_mse: 0.0029 - Sales_rmspe: 0.3899 - Customers_mse: 0.0013 - Customers_rmspe: 0.3868 - val_loss: 0.0058 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.3970 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4299
#
# Epoch 00009: val_Sales_mse did not improve from 0.00350
# Epoch 10/10
# 3181/3181 - 70s - loss: 0.0046 - Sales_loss: 0.0029 - Customers_loss: 0.0013 - Sales_mse: 0.0029 - Sales_rmspe: 0.3887 - Customers_mse: 0.0013 - Customers_rmspe: 0.3864 - val_loss: 0.0054 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.3762 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4406
#
# Epoch 00010: val_Sales_mse improved from 0.00350 to 0.00333, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-1.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0054 - Sales_loss: 0.0033 - Customers_loss: 0.0017 - Sales_mse: 0.0033 - Sales_rmspe: 0.3671 - Customers_mse: 0.0017 - Customers_rmspe: 0.4311
# Cont vars chosen: ['AfterSchoolHoliday', 'AfterPromo', 'trend_DE', 'trend', 'BeforeClose_bool', 'Mean_Humidity', 'StateHoliday_bool', 'CompetitionDistance', 'Max_Humidity', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo', 'BeforeStateHoliday_bool', 'AfterClose_bool', 'CloudCover', 'Max_TemperatureC', 'Min_Humidity', 'BeforeSchoolHoliday', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 76s - loss: 0.0266 - Sales_loss: 0.0037 - Customers_loss: 0.0019 - Sales_mse: 0.0037 - Sales_rmspe: 0.4243 - Customers_mse: 0.0019 - Customers_rmspe: 0.4323 - val_loss: 0.0061 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0020 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.3840 - val_Customers_mse: 0.0020 - val_Customers_rmspe: 0.4732
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00353, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-2.hdf5
# Epoch 8/10
# 3181/3181 - 72s - loss: 0.0045 - Sales_loss: 0.0028 - Customers_loss: 0.0012 - Sales_mse: 0.0028 - Sales_rmspe: 0.3815 - Customers_mse: 0.0012 - Customers_rmspe: 0.3774 - val_loss: 0.0056 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.4249 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4953
#
# Epoch 00008: val_Sales_mse did not improve from 0.00312
# Epoch 9/10
# 3181/3181 - 72s - loss: 0.0045 - Sales_loss: 0.0028 - Customers_loss: 0.0012 - Sales_mse: 0.0028 - Sales_rmspe: 0.3803 - Customers_mse: 0.0012 - Customers_rmspe: 0.3757 - val_loss: 0.0048 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3381 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3742
#
# Epoch 00009: val_Sales_mse improved from 0.00312 to 0.00298, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-2.hdf5
# Epoch 10/10
# 3181/3181 - 73s - loss: 0.0045 - Sales_loss: 0.0028 - Customers_loss: 0.0012 - Sales_mse: 0.0028 - Sales_rmspe: 0.3787 - Customers_mse: 0.0012 - Customers_rmspe: 0.3741 - val_loss: 0.0049 - val_Sales_loss: 0.0030 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0030 - val_Sales_rmspe: 0.3430 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.3997
#
# Epoch 00010: val_Sales_mse did not improve from 0.00298
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0048 - Sales_loss: 0.0030 - Customers_loss: 0.0014 - Sales_mse: 0.0030 - Sales_rmspe: 0.3308 - Customers_mse: 0.0014 - Customers_rmspe: 0.3663
# Cat vars chosen: ['DayOfWeek', 'Month', 'StateHoliday', 'Promo_fw', 'Close_bool_bw', 'State', 'Promo2Weeks', 'Store', 'SchoolHoliday_bw', 'CompetitionMonthsOpen']
# Cont vars chosen: ['trend', 'BeforeSchoolHoliday', 'Max_Humidity', 'Mean_Wind_SpeedKm_h', 'Precipitationmm', 'AfterPromo', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Min_TemperatureC', 'BeforePromo', 'CompetitionDistance', 'Max_TemperatureC', 'BeforeClose_bool', 'Mean_TemperatureC', 'BeforeStateHoliday_bool', 'StateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 72s - loss: 0.0110 - Sales_loss: 0.0015 - Customers_loss: 5.7807e-04 - Sales_mse: 0.0015 - Sales_rmspe: 0.2808 - Customers_mse: 5.7807e-04 - Customers_rmspe: 0.2715 - val_loss: 0.0015 - val_Sales_loss: 8.7432e-04 - val_Customers_loss: 3.2409e-04 - val_Sales_mse: 8.7432e-04 - val_Sales_rmspe: 0.1904 - val_Customers_mse: 3.2409e-04 - val_Customers_rmspe: 0.1731
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 69s - loss: 0.0011 - Sales_loss: 6.6756e-04 - Customers_loss: 2.1019e-04 - Sales_mse: 6.6756e-04 - Sales_rmspe: 0.1782 - Customers_mse: 2.1019e-04 - Customers_rmspe: 0.1565 - val_loss: 0.0011 - val_Sales_loss: 7.0385e-04 - val_Customers_loss: 2.3231e-04 - val_Sales_mse: 7.0385e-04 - val_Sales_rmspe: 0.1554 - val_Customers_mse: 2.3231e-04 - val_Customers_rmspe: 0.1415
#
# Epoch 00007: val_Sales_mse improved from 0.00072 to 0.00070, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-3.hdf5
# Epoch 8/10
# 3181/3181 - 69s - loss: 0.0010 - Sales_loss: 6.6103e-04 - Customers_loss: 2.0768e-04 - Sales_mse: 6.6103e-04 - Sales_rmspe: 0.1771 - Customers_mse: 2.0768e-04 - Customers_rmspe: 0.1553 - val_loss: 0.0015 - val_Sales_loss: 0.0010 - val_Customers_loss: 2.9513e-04 - val_Sales_mse: 0.0010 - val_Sales_rmspe: 0.1942 - val_Customers_mse: 2.9513e-04 - val_Customers_rmspe: 0.1521
#
# Epoch 00008: val_Sales_mse did not improve from 0.00070
# Epoch 9/10
# 3181/3181 - 69s - loss: 0.0010 - Sales_loss: 6.5137e-04 - Customers_loss: 2.0596e-04 - Sales_mse: 6.5137e-04 - Sales_rmspe: 0.1759 - Customers_mse: 2.0596e-04 - Customers_rmspe: 0.1545 - val_loss: 0.0014 - val_Sales_loss: 0.0010 - val_Customers_loss: 2.6353e-04 - val_Sales_mse: 0.0010 - val_Sales_rmspe: 0.1920 - val_Customers_mse: 2.6353e-04 - val_Customers_rmspe: 0.1545
#
# Epoch 00009: val_Sales_mse did not improve from 0.00070
# Epoch 10/10
# 3181/3181 - 69s - loss: 0.0010 - Sales_loss: 6.4957e-04 - Customers_loss: 2.0468e-04 - Sales_mse: 6.4957e-04 - Sales_rmspe: 0.1760 - Customers_mse: 2.0468e-04 - Customers_rmspe: 0.1542 - val_loss: 0.0012 - val_Sales_loss: 7.7659e-04 - val_Customers_loss: 2.5726e-04 - val_Sales_mse: 7.7659e-04 - val_Sales_rmspe: 0.1579 - val_Customers_mse: 2.5726e-04 - val_Customers_rmspe: 0.1431
#
# Epoch 00010: val_Sales_mse did not improve from 0.00070
# Obtenemos las métricas
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0011 - Sales_loss: 7.0385e-04 - Customers_loss: 2.3231e-04 - Sales_mse: 7.0385e-04 - Sales_rmspe: 0.1522 - Customers_mse: 2.3231e-04 - Customers_rmspe: 0.1392
# Cont vars chosen: ['trend_DE', 'Min_TemperatureC', 'CompetitionDistance', 'Precipitationmm', 'BeforeStateHoliday_bool', 'StateHoliday_bool', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Min_Humidity', 'BeforePromo', 'CloudCover', 'Mean_Humidity', 'BeforeSchoolHoliday', 'Mean_Wind_SpeedKm_h', 'BeforeClose_bool', 'Max_Humidity', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
#
# Epoch 00006: val_Sales_mse did not improve from 0.00066
# Epoch 7/10
# 3181/3181 - 69s - loss: 0.0010 - Sales_loss: 6.3755e-04 - Customers_loss: 2.1225e-04 - Sales_mse: 6.3755e-04 - Sales_rmspe: 0.1753 - Customers_mse: 2.1225e-04 - Customers_rmspe: 0.1557 - val_loss: 0.0012 - val_Sales_loss: 7.2055e-04 - val_Customers_loss: 2.8502e-04 - val_Sales_mse: 7.2055e-04 - val_Sales_rmspe: 0.1620 - val_Customers_mse: 2.8502e-04 - val_Customers_rmspe: 0.1708
#
# Epoch 00007: val_Sales_mse did not improve from 0.00066
# Epoch 8/10
# 3181/3181 - 69s - loss: 0.0010 - Sales_loss: 6.3203e-04 - Customers_loss: 2.0974e-04 - Sales_mse: 6.3203e-04 - Sales_rmspe: 0.1740 - Customers_mse: 2.0974e-04 - Customers_rmspe: 0.1545 - val_loss: 0.0013 - val_Sales_loss: 8.2086e-04 - val_Customers_loss: 2.9135e-04 - val_Sales_mse: 8.2086e-04 - val_Sales_rmspe: 0.1874 - val_Customers_mse: 2.9135e-04 - val_Customers_rmspe: 0.1771
#
# Epoch 00008: val_Sales_mse did not improve from 0.00066
# Epoch 9/10
# 3181/3181 - 70s - loss: 0.0010 - Sales_loss: 6.3295e-04 - Customers_loss: 2.1087e-04 - Sales_mse: 6.3295e-04 - Sales_rmspe: 0.1740 - Customers_mse: 2.1087e-04 - Customers_rmspe: 0.1544 - val_loss: 0.0015 - val_Sales_loss: 0.0010 - val_Customers_loss: 2.8916e-04 - val_Sales_mse: 0.0010 - val_Sales_rmspe: 0.1822 - val_Customers_mse: 2.8916e-04 - val_Customers_rmspe: 0.1536
#
# Epoch 00009: val_Sales_mse did not improve from 0.00066
# Epoch 10/10
# 3181/3181 - 70s - loss: 9.9042e-04 - Sales_loss: 6.2476e-04 - Customers_loss: 2.0677e-04 - Sales_mse: 6.2476e-04 - Sales_rmspe: 0.1731 - Customers_mse: 2.0677e-04 - Customers_rmspe: 0.1531 - val_loss: 0.0013 - val_Sales_loss: 8.4602e-04 - val_Customers_loss: 2.9381e-04 - val_Sales_mse: 8.4602e-04 - val_Sales_rmspe: 0.1764 - val_Customers_mse: 2.9381e-04 - val_Customers_rmspe: 0.1641
#
# Epoch 00010: val_Sales_mse did not improve from 0.00066
# Obtenemos las métricas
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0012 - Sales_loss: 6.6357e-04 - Customers_loss: 2.2189e-04 - Sales_mse: 6.6357e-04 - Sales_rmspe: 0.1423 - Customers_mse: 2.2189e-04 - Customers_rmspe: 0.1335
# Cont vars chosen: ['AfterSchoolHoliday', 'AfterPromo', 'trend_DE', 'trend', 'BeforeClose_bool', 'Mean_Humidity', 'StateHoliday_bool', 'CompetitionDistance', 'Max_Humidity', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo', 'BeforeStateHoliday_bool', 'AfterClose_bool', 'CloudCover', 'Max_TemperatureC', 'Min_Humidity', 'BeforeSchoolHoliday', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0010 - Sales_loss: 6.3613e-04 - Customers_loss: 1.8864e-04 - Sales_mse: 6.3613e-04 - Sales_rmspe: 0.1467 - Customers_mse: 1.8864e-04 - Customers_rmspe: 0.1200
# Cat vars chosen: ['Assortment', 'State', 'Promo_fw', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'Store', 'StateHoliday_bool_bw', 'SchoolHoliday', 'StateHoliday', 'CompetitionMonthsOpen', 'Promo_bw', 'Events', 'StoreType', 'DayOfWeek', 'Close_bool_fw', 'Week', 'StateHoliday_bool_fw', 'Promo2', 'Promo2Weeks', 'Day', 'PromoInterval', 'Close_bool_bw', 'Month', 'Year']
# Cont vars chosen: ['trend', 'BeforeSchoolHoliday', 'Max_Humidity', 'Mean_Wind_SpeedKm_h', 'Precipitationmm', 'AfterPromo', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Min_TemperatureC', 'BeforePromo', 'CompetitionDistance', 'Max_TemperatureC', 'BeforeClose_bool', 'Mean_TemperatureC', 'BeforeStateHoliday_bool', 'StateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 6
# Epoch 1/10
# 3181/3181 - 84s - loss: 0.0106 - Sales_loss: 0.0013 - Customers_loss: 6.0950e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2683 - Customers_mse: 6.0950e-04 - Customers_rmspe: 0.2632 - val_loss: 0.0015 - val_Sales_loss: 8.3863e-04 - val_Customers_loss: 3.2167e-04 - val_Sales_mse: 8.3863e-04 - val_Sales_rmspe: 0.1965 - val_Customers_mse: 3.2167e-04 - val_Customers_rmspe: 0.1916
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00084, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-6.hdf5
# Epoch 2/10
# 3181/3181 - 81s - loss: 0.0014 - Sales_loss: 8.2021e-04 - Customers_loss: 2.9748e-04 - Sales_mse: 8.2021e-04 - Sales_rmspe: 0.2244 - Customers_mse: 2.9748e-04 - Customers_rmspe: 0.2064 - val_loss: 0.0014 - val_Sales_loss: 8.0067e-04 - val_Customers_loss: 3.1007e-04 - val_Sales_mse: 8.0067e-04 - val_Sales_rmspe: 0.1655 - val_Customers_mse: 3.1007e-04 - val_Customers_rmspe: 0.1601
#
# Epoch 00002: val_Sales_mse improved from 0.00084 to 0.00080, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-6.hdf5
# Epoch 3/10
# 3181/3181 - 81s - loss: 0.0011 - Sales_loss: 6.3994e-04 - Customers_loss: 2.3261e-04 - Sales_mse: 6.3994e-04 - Sales_rmspe: 0.1860 - Customers_mse: 2.3261e-04 - Customers_rmspe: 0.1695 - val_loss: 0.0012 - val_Sales_loss: 7.5122e-04 - val_Customers_loss: 2.3879e-04 - val_Sales_mse: 7.5122e-04 - val_Sales_rmspe: 0.1571 - val_Customers_mse: 2.3879e-04 - val_Customers_rmspe: 0.1404
#
# Epoch 00003: val_Sales_mse improved from 0.00080 to 0.00075, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel3-6.hdf5
# Epoch 4/10
# 3181/3181 - 81s - loss: 9.9650e-04 - Sales_loss: 5.8999e-04 - Customers_loss: 2.1171e-04 - Sales_mse: 5.8999e-04 - Sales_rmspe: 0.1780 - Customers_mse: 2.1171e-04 - Customers_rmspe: 0.1613 - val_loss: 0.0012 - val_Sales_loss: 7.5185e-04 - val_Customers_loss: 2.7369e-04 - val_Sales_mse: 7.5185e-04 - val_Sales_rmspe: 0.1728 - val_Customers_mse: 2.7369e-04 - val_Customers_rmspe: 0.1474
#
# Epoch 00004: val_Sales_mse did not improve from 0.00075
# Epoch 5/10
# 3181/3181 - 81s - loss: 9.3368e-04 - Sales_loss: 5.5916e-04 - Customers_loss: 1.9857e-04 - Sales_mse: 5.5916e-04 - Sales_rmspe: 0.1718 - Customers_mse: 1.9857e-04 - Customers_rmspe: 0.1553 - val_loss: 0.0015 - val_Sales_loss: 8.9591e-04 - val_Customers_loss: 4.0707e-04 - val_Sales_mse: 8.9591e-04 - val_Sales_rmspe: 0.1776 - val_Customers_mse: 4.0707e-04 - val_Customers_rmspe: 0.1812
#
# Epoch 00005: val_Sales_mse did not improve from 0.00075
# Epoch 6/10
# 3181/3181 - 80s - loss: 9.0207e-04 - Sales_loss: 5.4646e-04 - Customers_loss: 1.9355e-04 - Sales_mse: 5.4646e-04 - Sales_rmspe: 0.1683 - Customers_mse: 1.9355e-04 - Customers_rmspe: 0.1521 - val_loss: 0.0010 - val_Sales_loss: 6.3907e-04 - val_Customers_loss: 2.2765e-04 - val_Sales_mse: 6.3907e-04 - val_Sales_rmspe: 0.1441 - val_Customers_mse: 2.2765e-04 - val_Customers_rmspe: 0.1350
#
# ...
#
# Epoch 00010: val_Sales_mse did not improve from 0.00062
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 9.8775e-04 - Sales_loss: 6.2086e-04 - Customers_loss: 2.2085e-04 - Sales_mse: 6.2086e-04 - Sales_rmspe: 0.1476 - Customers_mse: 2.2085e-04 - Customers_rmspe: 0.1258
# Cont vars chosen: ['trend_DE', 'Min_TemperatureC', 'CompetitionDistance', 'Precipitationmm', 'BeforeStateHoliday_bool', 'StateHoliday_bool', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Min_Humidity', 'BeforePromo', 'CloudCover', 'Mean_Humidity', 'BeforeSchoolHoliday', 'Mean_Wind_SpeedKm_h', 'BeforeClose_bool', 'Max_Humidity', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 84s - loss: 0.0174 - Sales_loss: 7.0861e-04 - Customers_loss: 6.0157e-04 - Sales_mse: 7.0861e-04 - Sales_rmspe: 0.1833 - Customers_mse: 6.0157e-04 - Customers_rmspe: 0.1772 - val_loss: 0.0012 - val_Sales_loss: 6.5467e-04 - val_Customers_loss: 2.2095e-04 - val_Sales_mse: 6.5467e-04 - val_Sales_rmspe: 0.1447 - val_Customers_mse: 2.2095e-04 - val_Customers_rmspe: 0.1363
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 79s - loss: 8.3146e-04 - Sales_loss: 5.0483e-04 - Customers_loss: 1.8115e-04 - Sales_mse: 5.0483e-04 - Sales_rmspe: 0.1599 - Customers_mse: 1.8115e-04 - Customers_rmspe: 0.1465 - val_loss: 9.5432e-04 - val_Sales_loss: 5.9248e-04 - val_Customers_loss: 2.1660e-04 - val_Sales_mse: 5.9248e-04 - val_Sales_rmspe: 0.1489 - val_Customers_mse: 2.1660e-04 - val_Customers_rmspe: 0.1440
#
# Epoch 00007: val_Sales_mse did not improve from 0.00058
# Epoch 8/10
# 3181/3181 - 79s - loss: 8.2122e-04 - Sales_loss: 5.0169e-04 - Customers_loss: 1.7917e-04 - Sales_mse: 5.0169e-04 - Sales_rmspe: 0.1600 - Customers_mse: 1.7917e-04 - Customers_rmspe: 0.1454 - val_loss: 0.0011 - val_Sales_loss: 6.2161e-04 - val_Customers_loss: 2.9970e-04 - val_Sales_mse: 6.2161e-04 - val_Sales_rmspe: 0.1533 - val_Customers_mse: 2.9970e-04 - val_Customers_rmspe: 0.1948
#
# Epoch 00008: val_Sales_mse did not improve from 0.00058
# Epoch 9/10
# 3181/3181 - 79s - loss: 8.1535e-04 - Sales_loss: 5.0067e-04 - Customers_loss: 1.7833e-04 - Sales_mse: 5.0067e-04 - Sales_rmspe: 0.1594 - Customers_mse: 1.7833e-04 - Customers_rmspe: 0.1445 - val_loss: 9.5494e-04 - val_Sales_loss: 6.0823e-04 - val_Customers_loss: 2.0822e-04 - val_Sales_mse: 6.0823e-04 - val_Sales_rmspe: 0.1416 - val_Customers_mse: 2.0822e-04 - val_Customers_rmspe: 0.1449
#
# Epoch 00009: val_Sales_mse did not improve from 0.00058
# Epoch 10/10
# 3181/3181 - 79s - loss: 8.0353e-04 - Sales_loss: 4.9482e-04 - Customers_loss: 1.7510e-04 - Sales_mse: 4.9482e-04 - Sales_rmspe: 0.1586 - Customers_mse: 1.7510e-04 - Customers_rmspe: 0.1433 - val_loss: 9.5336e-04 - val_Sales_loss: 6.0892e-04 - val_Customers_loss: 2.0994e-04 - val_Sales_mse: 6.0892e-04 - val_Sales_rmspe: 0.1391 - val_Customers_mse: 2.0994e-04 - val_Customers_rmspe: 0.1362
#
# Epoch 00010: val_Sales_mse did not improve from 0.00058
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 9.4362e-04 - Sales_loss: 5.8234e-04 - Customers_loss: 1.9128e-04 - Sales_mse: 5.8234e-04 - Sales_rmspe: 0.1360 - Customers_mse: 1.9128e-04 - Customers_rmspe: 0.1231
# Cont vars chosen: ['AfterSchoolHoliday', 'AfterPromo', 'trend_DE', 'trend', 'BeforeClose_bool', 'Mean_Humidity', 'StateHoliday_bool', 'CompetitionDistance', 'Max_Humidity', 'Precipitationmm', 'Mean_Wind_SpeedKm_h', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'BeforePromo', 'BeforeStateHoliday_bool', 'AfterClose_bool', 'CloudCover', 'Max_TemperatureC', 'Min_Humidity', 'BeforeSchoolHoliday', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer '