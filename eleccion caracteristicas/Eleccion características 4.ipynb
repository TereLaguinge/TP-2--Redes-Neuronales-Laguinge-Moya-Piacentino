# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=cba6b443713dc3d63b829533b72fce77cccdbc063c304b7530504824e1b1f9ee
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 474

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion4.csv")
# Out:
# Cat vars chosen: ['Day', 'Assortment', 'Promo_fw', 'SchoolHoliday', 'Week', 'PromoInterval', 'Close_bool_fw', 'Month', 'CompetitionOpenSinceYear', 'Promo2Weeks', 'Events', 'Promo2SinceWeek', 'SchoolHoliday_fw', 'Close_bool_bw', 'StateHoliday_bool_bw', 'State', 'Promo2', 'CompetitionMonthsOpen', 'Promo_bw', 'StoreType', 'Year', 'SchoolHoliday_bw', 'DayOfWeek', 'Promo', 'Promo2SinceYear']
# Cont vars chosen: ['Max_TemperatureC', 'trend_DE', 'Mean_TemperatureC', 'AfterPromo', 'CompetitionDistance', 'StateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'Mean_Wind_SpeedKm_h', 'trend', 'BeforeSchoolHoliday', 'AfterClose_bool', 'BeforePromo', 'Precipitationmm', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 99s - loss: 0.0144 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4734 - Customers_mse: 0.0018 - Customers_rmspe: 0.4737 - val_loss: 0.0058 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.4338 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4863
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 96s - loss: 0.0042 - Sales_loss: 0.0026 - Customers_loss: 0.0012 - Sales_mse: 0.0026 - Sales_rmspe: 0.3725 - Customers_mse: 0.0012 - Customers_rmspe: 0.3754 - val_loss: 0.0042 - val_Sales_loss: 0.0027 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0027 - val_Sales_rmspe: 0.3701 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3816
#
# Epoch 00007: val_Sales_mse did not improve from 0.00255
# Epoch 8/10
# 3181/3181 - 98s - loss: 0.0041 - Sales_loss: 0.0026 - Customers_loss: 0.0012 - Sales_mse: 0.0026 - Sales_rmspe: 0.3698 - Customers_mse: 0.0012 - Customers_rmspe: 0.3729 - val_loss: 0.0041 - val_Sales_loss: 0.0026 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0026 - val_Sales_rmspe: 0.3194 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3797
#
# Epoch 00008: val_Sales_mse did not improve from 0.00255
# Epoch 9/10
# 3181/3181 - 97s - loss: 0.0041 - Sales_loss: 0.0025 - Customers_loss: 0.0012 - Sales_mse: 0.0025 - Sales_rmspe: 0.3658 - Customers_mse: 0.0012 - Customers_rmspe: 0.3689 - val_loss: 0.0042 - val_Sales_loss: 0.0027 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0027 - val_Sales_rmspe: 0.3009 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3238
#
# Epoch 00009: val_Sales_mse did not improve from 0.00255
# Epoch 10/10
# 3181/3181 - 95s - loss: 0.0041 - Sales_loss: 0.0025 - Customers_loss: 0.0012 - Sales_mse: 0.0025 - Sales_rmspe: 0.3646 - Customers_mse: 0.0012 - Customers_rmspe: 0.3666 - val_loss: 0.0041 - val_Sales_loss: 0.0026 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0026 - val_Sales_rmspe: 0.3045 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3204
#
# Epoch 00010: val_Sales_mse did not improve from 0.00255
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 0.0041 - Sales_loss: 0.0025 - Customers_loss: 0.0011 - Sales_mse: 0.0025 - Sales_rmspe: 0.3139 - Customers_mse: 0.0011 - Customers_rmspe: 0.3765
# Cont vars chosen: ['AfterClose_bool', 'trend_DE', 'BeforePromo', 'Min_TemperatureC', 'Min_Humidity', 'trend', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'CompetitionDistance', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 98s - loss: 0.0180 - Sales_loss: 0.0033 - Customers_loss: 0.0014 - Sales_mse: 0.0033 - Sales_rmspe: 0.4039 - Customers_mse: 0.0014 - Customers_rmspe: 0.4041 - val_loss: 0.0044 - val_Sales_loss: 0.0026 - val_Customers_loss: 0.0012 - val_Sales_mse: 0.0026 - val_Sales_rmspe: 0.3308 - val_Customers_mse: 0.0012 - val_Customers_rmspe: 0.3362
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-1.hdf5
# Epoch 7/10
# 3181/3181 - 85s - loss: 0.0037 - Sales_loss: 0.0021 - Customers_loss: 9.7157e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3270 - Customers_mse: 9.7157e-04 - Customers_rmspe: 0.3272 - val_loss: 0.0035 - val_Sales_loss: 0.0021 - val_Customers_loss: 9.1619e-04 - val_Sales_mse: 0.0021 - val_Sales_rmspe: 0.2947 - val_Customers_mse: 9.1619e-04 - val_Customers_rmspe: 0.3281
#
# Epoch 00007: val_Sales_mse improved from 0.00210 to 0.00206, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-1.hdf5
# Epoch 8/10
# 3181/3181 - 85s - loss: 0.0036 - Sales_loss: 0.0021 - Customers_loss: 9.6764e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3260 - Customers_mse: 9.6764e-04 - Customers_rmspe: 0.3260 - val_loss: 0.0036 - val_Sales_loss: 0.0021 - val_Customers_loss: 9.3808e-04 - val_Sales_mse: 0.0021 - val_Sales_rmspe: 0.3028 - val_Customers_mse: 9.3808e-04 - val_Customers_rmspe: 0.3069
#
# Epoch 00008: val_Sales_mse did not improve from 0.00206
# Epoch 9/10
# 3181/3181 - 86s - loss: 0.0036 - Sales_loss: 0.0021 - Customers_loss: 9.5941e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3249 - Customers_mse: 9.5941e-04 - Customers_rmspe: 0.3249 - val_loss: 0.0034 - val_Sales_loss: 0.0020 - val_Customers_loss: 8.7598e-04 - val_Sales_mse: 0.0020 - val_Sales_rmspe: 0.2903 - val_Customers_mse: 8.7598e-04 - val_Customers_rmspe: 0.2846
#
# Epoch 00009: val_Sales_mse improved from 0.00206 to 0.00202, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-1.hdf5
# Epoch 10/10
# 3181/3181 - 86s - loss: 0.0036 - Sales_loss: 0.0021 - Customers_loss: 9.5460e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3240 - Customers_mse: 9.5460e-04 - Customers_rmspe: 0.3244 - val_loss: 0.0036 - val_Sales_loss: 0.0021 - val_Customers_loss: 0.0010 - val_Sales_mse: 0.0021 - val_Sales_rmspe: 0.3175 - val_Customers_mse: 0.0010 - val_Customers_rmspe: 0.3415
#
# Epoch 00010: val_Sales_mse did not improve from 0.00202
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 0.0034 - Sales_loss: 0.0020 - Customers_loss: 8.7598e-04 - Sales_mse: 0.0020 - Sales_rmspe: 0.2828 - Customers_mse: 8.7598e-04 - Customers_rmspe: 0.2782
# Cont vars chosen: ['AfterSchoolHoliday', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'AfterPromo', 'Max_TemperatureC', 'Mean_Humidity', 'BeforeStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'trend', 'CompetitionDistance', 'AfterClose_bool', 'trend_DE', 'Precipitationmm', 'CloudCover', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
# Epoch 00006: val_Sales_mse did not improve from 0.00202
# Epoch 7/10
# 3181/3181 - 87s - loss: 0.0036 - Sales_loss: 0.0021 - Customers_loss: 9.6306e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3212 - Customers_mse: 9.6306e-04 - Customers_rmspe: 0.3235 - val_loss: 0.0035 - val_Sales_loss: 0.0021 - val_Customers_loss: 8.7042e-04 - val_Sales_mse: 0.0021 - val_Sales_rmspe: 0.2700 - val_Customers_mse: 8.7042e-04 - val_Customers_rmspe: 0.2697
#
# Epoch 00007: val_Sales_mse did not improve from 0.00202
# Epoch 8/10
# 3181/3181 - 87s - loss: 0.0036 - Sales_loss: 0.0021 - Customers_loss: 9.5956e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3203 - Customers_mse: 9.5956e-04 - Customers_rmspe: 0.3222 - val_loss: 0.0037 - val_Sales_loss: 0.0022 - val_Customers_loss: 9.7456e-04 - val_Sales_mse: 0.0022 - val_Sales_rmspe: 0.3366 - val_Customers_mse: 9.7456e-04 - val_Customers_rmspe: 0.3429
#
# Epoch 00008: val_Sales_mse did not improve from 0.00202
# Epoch 9/10
# 3181/3181 - 87s - loss: 0.0035 - Sales_loss: 0.0021 - Customers_loss: 9.5550e-04 - Sales_mse: 0.0021 - Sales_rmspe: 0.3188 - Customers_mse: 9.5550e-04 - Customers_rmspe: 0.3212 - val_loss: 0.0037 - val_Sales_loss: 0.0022 - val_Customers_loss: 0.0010 - val_Sales_mse: 0.0022 - val_Sales_rmspe: 0.3331 - val_Customers_mse: 0.0010 - val_Customers_rmspe: 0.3718
#
# Epoch 00009: val_Sales_mse did not improve from 0.00202
# Epoch 10/10
# 3181/3181 - 87s - loss: 0.0035 - Sales_loss: 0.0020 - Customers_loss: 9.5228e-04 - Sales_mse: 0.0020 - Sales_rmspe: 0.3187 - Customers_mse: 9.5228e-04 - Customers_rmspe: 0.3206 - val_loss: 0.0034 - val_Sales_loss: 0.0020 - val_Customers_loss: 8.7927e-04 - val_Sales_mse: 0.0020 - val_Sales_rmspe: 0.3098 - val_Customers_mse: 8.7927e-04 - val_Customers_rmspe: 0.3171
#
# Epoch 00010: val_Sales_mse improved from 0.00202 to 0.00199, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-2.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0034 - Sales_loss: 0.0020 - Customers_loss: 8.7927e-04 - Sales_mse: 0.0020 - Sales_rmspe: 0.3008 - Customers_mse: 8.7927e-04 - Customers_rmspe: 0.3098
# Cat vars chosen: ['Week', 'CompetitionMonthsOpen', 'Store', 'Promo2Weeks', 'SchoolHoliday_bw', 'Promo_fw', 'StateHoliday', 'Promo2SinceYear', 'StateHoliday_bool_fw', 'SchoolHoliday', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'PromoInterval', 'Day', 'Promo_bw']
# Cont vars chosen: ['Max_TemperatureC', 'trend_DE', 'Mean_TemperatureC', 'AfterPromo', 'CompetitionDistance', 'StateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'Mean_Wind_SpeedKm_h', 'trend', 'BeforeSchoolHoliday', 'AfterClose_bool', 'BeforePromo', 'Precipitationmm', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
#
# Epoch 00010: val_Sales_mse did not improve from 0.00063
# Obtenemos las métricas
# 944/944 [==============================] - 7s 7ms/step - loss: 9.9271e-04 - Sales_loss: 6.2939e-04 - Customers_loss: 2.0474e-04 - Sales_mse: 6.2939e-04 - Sales_rmspe: 0.1454 - Customers_mse: 2.0474e-04 - Customers_rmspe: 0.1244
# Cont vars chosen: ['AfterSchoolHoliday', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'AfterPromo', 'Max_TemperatureC', 'Mean_Humidity', 'BeforeStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'trend', 'CompetitionDistance', 'AfterClose_bool', 'trend_DE', 'Precipitationmm', 'CloudCover', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 91s - loss: 0.0197 - Sales_loss: 0.0013 - Customers_loss: 2.7897e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2031 - Customers_mse: 2.7897e-04 - Customers_rmspe: 0.1829 - val_loss: 0.0016 - val_Sales_loss: 8.6176e-04 - val_Customers_loss: 3.5974e-04 - val_Sales_mse: 8.6176e-04 - val_Sales_rmspe: 0.1862 - val_Customers_mse: 3.5974e-04 - val_Customers_rmspe: 0.2063
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00086, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-5.hdf5
# Epoch 2/10
# 3181/3181 - 87s - loss: 0.0012 - Sales_loss: 6.4142e-04 - Customers_loss: 2.2429e-04 - Sales_mse: 6.4142e-04 - Sales_rmspe: 0.1830 - Customers_mse: 2.2429e-04 - Customers_rmspe: 0.1668 - val_loss: 0.0011 - val_Sales_loss: 6.4250e-04 - val_Customers_loss: 2.0859e-04 - val_Sales_mse: 6.4250e-04 - val_Sales_rmspe: 0.1485 - val_Customers_mse: 2.0859e-04 - val_Customers_rmspe: 0.1364
#
# Epoch 00002: val_Sales_mse improved from 0.00086 to 0.00064, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-5.hdf5
# Epoch 3/10
# 3181/3181 - 87s - loss: 0.0011 - Sales_loss: 6.1555e-04 - Customers_loss: 2.1175e-04 - Sales_mse: 6.1555e-04 - Sales_rmspe: 0.1795 - Customers_mse: 2.1175e-04 - Customers_rmspe: 0.1621 - val_loss: 0.0012 - val_Sales_loss: 7.2955e-04 - val_Customers_loss: 2.5760e-04 - val_Sales_mse: 7.2955e-04 - val_Sales_rmspe: 0.1611 - val_Customers_mse: 2.5760e-04 - val_Customers_rmspe: 0.1365
#
# Epoch 00003: val_Sales_mse did not improve from 0.00064
# Epoch 4/10
#
# Epoch 00009: val_Sales_mse did not improve from 0.00064
# Epoch 10/10
# 3181/3181 - 84s - loss: 9.1264e-04 - Sales_loss: 5.6848e-04 - Customers_loss: 1.9685e-04 - Sales_mse: 5.6848e-04 - Sales_rmspe: 0.1731 - Customers_mse: 1.9685e-04 - Customers_rmspe: 0.1543 - val_loss: 0.0011 - val_Sales_loss: 6.8775e-04 - val_Customers_loss: 2.1501e-04 - val_Sales_mse: 6.8775e-04 - val_Sales_rmspe: 0.1663 - val_Customers_mse: 2.1501e-04 - val_Customers_rmspe: 0.1422
#
# Epoch 00010: val_Sales_mse did not improve from 0.00064
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 0.0011 - Sales_loss: 6.4250e-04 - Customers_loss: 2.0859e-04 - Sales_mse: 6.4250e-04 - Sales_rmspe: 0.1447 - Customers_mse: 2.0859e-04 - Customers_rmspe: 0.1331
# Cat vars chosen: ['Close_bool_bw', 'Assortment', 'CompetitionOpenSinceYear', 'DayOfWeek', 'StateHoliday_bool_fw', 'State', 'SchoolHoliday', 'Year', 'Week', 'Promo_bw', 'Promo_fw', 'SchoolHoliday_bw', 'StoreType', 'Promo2Weeks', 'Events', 'Day', 'Month', 'Close_bool_fw', 'CompetitionMonthsOpen', 'StateHoliday', 'Promo', 'Promo2', 'PromoInterval', 'Promo2SinceWeek', 'StateHoliday_bool_bw', 'Store', 'Promo2SinceYear']
# Cont vars chosen: ['Max_TemperatureC', 'trend_DE', 'Mean_TemperatureC', 'AfterPromo', 'CompetitionDistance', 'StateHoliday_bool', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'Mean_Wind_SpeedKm_h', 'trend', 'BeforeSchoolHoliday', 'AfterClose_bool', 'BeforePromo', 'Precipitationmm', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 6
# Epoch 1/10
# ...
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 96s - loss: 0.0145 - Sales_loss: 9.3560e-04 - Customers_loss: 2.5538e-04 - Sales_mse: 9.3560e-04 - Sales_rmspe: 0.1856 - Customers_mse: 2.5538e-04 - Customers_rmspe: 0.1702 - val_loss: 0.0012 - val_Sales_loss: 7.1455e-04 - val_Customers_loss: 2.5740e-04 - val_Sales_mse: 7.1455e-04 - val_Sales_rmspe: 0.1652 - val_Customers_mse: 2.5740e-04 - val_Customers_rmspe: 0.1761
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00071, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel4-7.hdf5
# Epoch 7/10
# 3181/3181 - 93s - loss: 8.3522e-04 - Sales_loss: 5.1627e-04 - Customers_loss: 1.7423e-04 - Sales_mse: 5.1627e-04 - Sales_rmspe: 0.1619 - Customers_mse: 1.7423e-04 - Customers_rmspe: 0.1456 - val_loss: 0.0011 - val_Sales_loss: 6.9574e-04 - val_Customers_loss: 2.2505e-04 - val_Sales_mse: 6.9574e-04 - val_Sales_rmspe: 0.1572 - val_Customers_mse: 2.2505e-04 - val_Customers_rmspe: 0.1467
#
# Epoch 00007: val_Sales_mse did not improve from 0.00061
# Epoch 8/10
# 3181/3181 - 94s - loss: 8.2275e-04 - Sales_loss: 5.0869e-04 - Customers_loss: 1.7246e-04 - Sales_mse: 5.0869e-04 - Sales_rmspe: 0.1609 - Customers_mse: 1.7246e-04 - Customers_rmspe: 0.1453 - val_loss: 9.5102e-04 - val_Sales_loss: 6.2461e-04 - val_Customers_loss: 1.8742e-04 - val_Sales_mse: 6.2461e-04 - val_Sales_rmspe: 0.1505 - val_Customers_mse: 1.8742e-04 - val_Customers_rmspe: 0.1289
#
# Epoch 00008: val_Sales_mse did not improve from 0.00061
# Epoch 9/10
# 3181/3181 - 94s - loss: 8.1376e-04 - Sales_loss: 5.0665e-04 - Customers_loss: 1.7035e-04 - Sales_mse: 5.0665e-04 - Sales_rmspe: 0.1601 - Customers_mse: 1.7035e-04 - Customers_rmspe: 0.1442 - val_loss: 0.0011 - val_Sales_loss: 7.0038e-04 - val_Customers_loss: 2.1362e-04 - val_Sales_mse: 7.0038e-04 - val_Sales_rmspe: 0.1687 - val_Customers_mse: 2.1362e-04 - val_Customers_rmspe: 0.1447
#
# Epoch 00009: val_Sales_mse did not improve from 0.00061
# Epoch 10/10
# 3181/3181 - 93s - loss: 8.0542e-04 - Sales_loss: 5.0198e-04 - Customers_loss: 1.6962e-04 - Sales_mse: 5.0198e-04 - Sales_rmspe: 0.1591 - Customers_mse: 1.6962e-04 - Customers_rmspe: 0.1439 - val_loss: 9.5685e-04 - val_Sales_loss: 6.2858e-04 - val_Customers_loss: 1.9516e-04 - val_Sales_mse: 6.2858e-04 - val_Sales_rmspe: 0.1440 - val_Customers_mse: 1.9516e-04 - val_Customers_rmspe: 0.1343
#
# Epoch 00010: val_Sales_mse did not improve from 0.00061
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 9.5330e-04 - Sales_loss: 6.1474e-04 - Customers_loss: 1.9100e-04 - Sales_mse: 6.1474e-04 - Sales_rmspe: 0.1388 - Customers_mse: 1.9100e-04 - Customers_rmspe: 0.1235
# Cont vars chosen: ['AfterSchoolHoliday', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'AfterPromo', 'Max_TemperatureC', 'Mean_Humidity', 'BeforeStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'trend', 'CompetitionDistance', 'AfterClose_bool', 'trend_DE', 'Precipitationmm', 'CloudCover', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo