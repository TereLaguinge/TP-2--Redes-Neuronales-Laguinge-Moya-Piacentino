# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=f71c15821f885baaa4c272532d8b91d9fae128dc4864ad14e610186a246a249e
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 908

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion5.csv")
# Out:
# Cat vars chosen: ['DayOfWeek', 'Promo2Weeks', 'SchoolHoliday', 'Week', 'Assortment', 'SchoolHoliday_bw', 'Promo', 'Day', 'StateHoliday_bool_fw', 'StoreType', 'Close_bool_fw', 'Promo2SinceYear', 'Promo2', 'Year', 'CompetitionOpenSinceYear', 'Events', 'StateHoliday_bool_bw', 'StateHoliday', 'CompetitionMonthsOpen']
# Cont vars chosen: ['Mean_TemperatureC', 'trend', 'Mean_Humidity', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'Precipitationmm', 'AfterStateHoliday_bool', 'Max_Humidity', 'CompetitionDistance', 'BeforeSchoolHoliday', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 84s - loss: 0.0126 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4874 - Customers_mse: 0.0020 - Customers_rmspe: 0.4862 - val_loss: 0.0058 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4028 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4895
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00365, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00008: val_Sales_mse did not improve from 0.00350
# Epoch 9/10
# 3181/3181 - 81s - loss: 0.0051 - Sales_loss: 0.0034 - Customers_loss: 0.0015 - Sales_mse: 0.0034 - Sales_rmspe: 0.4292 - Customers_mse: 0.0015 - Customers_rmspe: 0.4242 - val_loss: 0.0057 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0019 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.4306 - val_Customers_mse: 0.0019 - val_Customers_rmspe: 0.5145
#
# Epoch 00009: val_Sales_mse improved from 0.00350 to 0.00350, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-0.hdf5
# Epoch 10/10
# 3181/3181 - 81s - loss: 0.0051 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.4289 - Customers_mse: 0.0015 - Customers_rmspe: 0.4240 - val_loss: 0.0054 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.3678 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4013
#
# Epoch 00010: val_Sales_mse improved from 0.00350 to 0.00346, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-0.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0054 - Sales_loss: 0.0035 - Customers_loss: 0.0016 - Sales_mse: 0.0035 - Sales_rmspe: 0.3596 - Customers_mse: 0.0016 - Customers_rmspe: 0.3927
# Cont vars chosen: ['BeforeClose_bool', 'Max_TemperatureC', 'trend', 'Min_TemperatureC', 'CompetitionDistance', 'Max_Humidity', 'Precipitationmm', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'CloudCover', 'AfterStateHoliday_bool', 'trend_DE', 'BeforePromo', 'StateHoliday_bool', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 85s - loss: 0.0197 - Sales_loss: 0.0039 - Customers_loss: 0.0016 - Sales_mse: 0.0039 - Sales_rmspe: 0.4428 - Customers_mse: 0.0016 - Customers_rmspe: 0.4414 - val_loss: 0.0056 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.4020 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4575
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00340, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-1.hdf5
# Epoch 2/10
# 3181/3181 - 81s - loss: 0.0053 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.4238 - Customers_mse: 0.0015 - Customers_rmspe: 0.4232 - val_loss: 0.0061 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0019 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4595 - val_Customers_mse: 0.0019 - val_Customers_rmspe: 0.4912
#
# Epoch 00008: val_Sales_mse did not improve from 0.00340
# Epoch 9/10
# 3181/3181 - 81s - loss: 0.0047 - Sales_loss: 0.0030 - Customers_loss: 0.0013 - Sales_mse: 0.0030 - Sales_rmspe: 0.3964 - Customers_mse: 0.0013 - Customers_rmspe: 0.3952 - val_loss: 0.0054 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.3624 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4108
#
# Epoch 00009: val_Sales_mse improved from 0.00340 to 0.00330, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-1.hdf5
# Epoch 10/10
# 3181/3181 - 81s - loss: 0.0047 - Sales_loss: 0.0030 - Customers_loss: 0.0013 - Sales_mse: 0.0030 - Sales_rmspe: 0.3952 - Customers_mse: 0.0013 - Customers_rmspe: 0.3936 - val_loss: 0.0059 - val_Sales_loss: 0.0035 - val_Customers_loss: 0.0020 - val_Sales_mse: 0.0035 - val_Sales_rmspe: 0.3990 - val_Customers_mse: 0.0020 - val_Customers_rmspe: 0.4889
#
# Epoch 00010: val_Sales_mse did not improve from 0.00330
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0054 - Sales_loss: 0.0033 - Customers_loss: 0.0017 - Sales_mse: 0.0033 - Sales_rmspe: 0.3547 - Customers_mse: 0.0017 - Customers_rmspe: 0.4023
# Cont vars chosen: ['Mean_Humidity', 'trend_DE', 'CloudCover', 'Max_Wind_SpeedKm_h', 'Mean_TemperatureC', 'trend', 'AfterPromo', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Max_TemperatureC', 'Min_TemperatureC', 'BeforeStateHoliday_bool', 'CompetitionDistance', 'Min_Humidity', 'Max_Humidity', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 84s - loss: 0.0247 - Sales_loss: 0.0039 - Customers_loss: 0.0017 - Sales_mse: 0.0039 - Sales_rmspe: 0.4375 - Customers_mse: 0.0017 - Customers_rmspe: 0.4387 - val_loss: 0.0063 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0020 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4369 - val_Customers_mse: 0.0020 - val_Customers_rmspe: 0.5351
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00368, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-2.hdf5
# Epoch 2/10
# 3181/3181 - 80s - loss: 0.0052 - Sales_loss: 0.0032 - Customers_loss: 0.0014 - Sales_mse: 0.0032 - Sales_rmspe: 0.4145 - Customers_mse: 0.0014 - Customers_rmspe: 0.4120 - val_loss: 0.0061 - val_Sales_loss: 0.0036 - val_Customers_loss: 0.0020 - val_Sales_mse: 0.0036 - val_Sales_rmspe: 0.3806 - val_Customers_mse: 0.0020 - val_Customers_rmspe: 0.4636
#
# Epoch 00002: val_Sales_mse improved from 0.00368 to 0.00362, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00008: val_Sales_mse did not improve from 0.00322
# Epoch 9/10
# 3181/3181 - 80s - loss: 0.0047 - Sales_loss: 0.0030 - Customers_loss: 0.0013 - Sales_mse: 0.0030 - Sales_rmspe: 0.3944 - Customers_mse: 0.0013 - Customers_rmspe: 0.3954 - val_loss: 0.0054 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.3649 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4037
#
# Epoch 00009: val_Sales_mse did not improve from 0.00322
# Epoch 10/10
# 3181/3181 - 81s - loss: 0.0047 - Sales_loss: 0.0030 - Customers_loss: 0.0013 - Sales_mse: 0.0030 - Sales_rmspe: 0.3935 - Customers_mse: 0.0013 - Customers_rmspe: 0.3945 - val_loss: 0.0054 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.4026 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4373
#
# Epoch 00010: val_Sales_mse did not improve from 0.00322
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0052 - Sales_loss: 0.0032 - Customers_loss: 0.0016 - Sales_mse: 0.0032 - Sales_rmspe: 0.3619 - Customers_mse: 0.0016 - Customers_rmspe: 0.4040
# Cat vars chosen: ['CompetitionMonthsOpen', 'SchoolHoliday_bw', 'Week', 'StoreType', 'Store', 'StateHoliday_bool_fw', 'StateHoliday_bool_bw', 'Month', 'DayOfWeek', 'Promo_fw', 'StateHoliday', 'Promo2', 'Promo']
# Cont vars chosen: ['Mean_TemperatureC', 'trend', 'Mean_Humidity', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'Precipitationmm', 'AfterStateHoliday_bool', 'Max_Humidity', 'CompetitionDistance', 'BeforeSchoolHoliday', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 84s - loss: 0.0087 - Sales_loss: 0.0013 - Customers_loss: 5.5654e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2689 - Customers_mse: 5.5654e-04 - Customers_rmspe: 0.2596 - val_loss: 0.0014 - val_Sales_loss: 8.2509e-04 - val_Customers_loss: 3.1490e-04 - val_Sales_mse: 8.2509e-04 - val_Sales_rmspe: 0.1932 - val_Customers_mse: 3.1490e-04 - val_Customers_rmspe: 0.1878
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00083, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-3.hdf5
# Epoch 2/10
# 3181/3181 - 81s - loss: 0.0015 - Sales_loss: 9.0090e-04 - Customers_loss: 3.1069e-04 - Sales_mse: 9.0090e-04 - Sales_rmspe: 0.2293 - Customers_mse: 3.1069e-04 - Customers_rmspe: 0.2098 - val_loss: 0.0015 - val_Sales_loss: 9.0580e-04 - val_Customers_loss: 3.2342e-04 - val_Sales_mse: 9.0580e-04 - val_Sales_rmspe: 0.1945 - val_Customers_mse: 3.2342e-04 - val_Customers_rmspe: 0.1899
#
# 3181/3181 - 82s - loss: 0.0010 - Sales_loss: 6.5113e-04 - Customers_loss: 2.1783e-04 - Sales_mse: 6.5113e-04 - Sales_rmspe: 0.1856 - Customers_mse: 2.1783e-04 - Customers_rmspe: 0.1656 - val_loss: 0.0012 - val_Sales_loss: 7.6323e-04 - val_Customers_loss: 2.9121e-04 - val_Sales_mse: 7.6323e-04 - val_Sales_rmspe: 0.1677 - val_Customers_mse: 2.9121e-04 - val_Customers_rmspe: 0.1659
#
# Epoch 00008: val_Sales_mse did not improve from 0.00069
# Epoch 9/10
# 3181/3181 - 81s - loss: 9.8798e-04 - Sales_loss: 6.4485e-04 - Customers_loss: 2.1593e-04 - Sales_mse: 6.4485e-04 - Sales_rmspe: 0.1847 - Customers_mse: 2.1593e-04 - Customers_rmspe: 0.1656 - val_loss: 0.0011 - val_Sales_loss: 7.0851e-04 - val_Customers_loss: 2.3462e-04 - val_Sales_mse: 7.0851e-04 - val_Sales_rmspe: 0.1588 - val_Customers_mse: 2.3462e-04 - val_Customers_rmspe: 0.1391
#
# Epoch 00009: val_Sales_mse did not improve from 0.00069
# Epoch 10/10
# 3181/3181 - 81s - loss: 9.8069e-04 - Sales_loss: 6.4262e-04 - Customers_loss: 2.1549e-04 - Sales_mse: 6.4262e-04 - Sales_rmspe: 0.1848 - Customers_mse: 2.1549e-04 - Customers_rmspe: 0.1664 - val_loss: 0.0011 - val_Sales_loss: 7.1401e-04 - val_Customers_loss: 2.3388e-04 - val_Sales_mse: 7.1401e-04 - val_Sales_rmspe: 0.1698 - val_Customers_mse: 2.3388e-04 - val_Customers_rmspe: 0.1599
#
# Epoch 00010: val_Sales_mse did not improve from 0.00069
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0011 - Sales_loss: 6.8666e-04 - Customers_loss: 2.5935e-04 - Sales_mse: 6.8666e-04 - Sales_rmspe: 0.1476 - Customers_mse: 2.5935e-04 - Customers_rmspe: 0.1546
# Cont vars chosen: ['BeforeClose_bool', 'Max_TemperatureC', 'trend', 'Min_TemperatureC', 'CompetitionDistance', 'Max_Humidity', 'Precipitationmm', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'CloudCover', 'AfterStateHoliday_bool', 'trend_DE', 'BeforePromo', 'StateHoliday_bool', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 4
# Epoch 1/10
# 3181/3181 - 85s - loss: 0.0131 - Sales_loss: 8.6120e-04 - Customers_loss: 4.7864e-04 - Sales_mse: 8.6120e-04 - Sales_rmspe: 0.2038 - Customers_mse: 4.7864e-04 - Customers_rmspe: 0.1921 - val_loss: 0.0013 - val_Sales_loss: 7.1593e-04 - val_Customers_loss: 2.9746e-04 - val_Sales_mse: 7.1593e-04 - val_Sales_rmspe: 0.1711 - val_Customers_mse: 2.9746e-04 - val_Customers_rmspe: 0.1790
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00072, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00007: val_Sales_mse did not improve from 0.00063
# Epoch 8/10
# 3181/3181 - 82s - loss: 9.2345e-04 - Sales_loss: 5.8763e-04 - Customers_loss: 2.0242e-04 - Sales_mse: 5.8763e-04 - Sales_rmspe: 0.1749 - Customers_mse: 2.0242e-04 - Customers_rmspe: 0.1571 - val_loss: 0.0011 - val_Sales_loss: 6.6093e-04 - val_Customers_loss: 2.5354e-04 - val_Sales_mse: 6.6093e-04 - val_Sales_rmspe: 0.1541 - val_Customers_mse: 2.5354e-04 - val_Customers_rmspe: 0.1465
#
# Epoch 00008: val_Sales_mse did not improve from 0.00063
# Epoch 9/10
# 3181/3181 - 82s - loss: 9.1091e-04 - Sales_loss: 5.8043e-04 - Customers_loss: 1.9977e-04 - Sales_mse: 5.8043e-04 - Sales_rmspe: 0.1739 - Customers_mse: 1.9977e-04 - Customers_rmspe: 0.1559 - val_loss: 0.0011 - val_Sales_loss: 6.9020e-04 - val_Customers_loss: 2.6152e-04 - val_Sales_mse: 6.9020e-04 - val_Sales_rmspe: 0.1513 - val_Customers_mse: 2.6152e-04 - val_Customers_rmspe: 0.1474
#
# Epoch 00009: val_Sales_mse did not improve from 0.00063
# Epoch 10/10
# 3181/3181 - 82s - loss: 9.0537e-04 - Sales_loss: 5.7765e-04 - Customers_loss: 1.9892e-04 - Sales_mse: 5.7765e-04 - Sales_rmspe: 0.1734 - Customers_mse: 1.9892e-04 - Customers_rmspe: 0.1557 - val_loss: 9.6492e-04 - val_Sales_loss: 6.2320e-04 - val_Customers_loss: 2.1555e-04 - val_Sales_mse: 6.2320e-04 - val_Sales_rmspe: 0.1477 - val_Customers_mse: 2.1555e-04 - val_Customers_rmspe: 0.1351
#
# Epoch 00010: val_Sales_mse improved from 0.00063 to 0.00062, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-4.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 9.6492e-04 - Sales_loss: 6.2320e-04 - Customers_loss: 2.1555e-04 - Sales_mse: 6.2320e-04 - Sales_rmspe: 0.1429 - Customers_mse: 2.1555e-04 - Customers_rmspe: 0.1309
# Cont vars chosen: ['Mean_Humidity', 'trend_DE', 'CloudCover', 'Max_Wind_SpeedKm_h', 'Mean_TemperatureC', 'trend', 'AfterPromo', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Max_TemperatureC', 'Min_TemperatureC', 'BeforeStateHoliday_bool', 'CompetitionDistance', 'Min_Humidity', 'Max_Humidity', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 86s - loss: 0.0194 - Sales_loss: 0.0011 - Customers_loss: 3.5324e-04 - Sales_mse: 0.0011 - Sales_rmspe: 0.1927 - Customers_mse: 3.5324e-04 - Customers_rmspe: 0.1745 - val_loss: 0.0012 - val_Sales_loss: 6.3849e-04 - val_Customers_loss: 2.2708e-04 - val_Sales_mse: 6.3849e-04 - val_Sales_rmspe: 0.1500 - val_Customers_mse: 2.2708e-04 - val_Customers_rmspe: 0.1440
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# Epoch 7/10
# 3181/3181 - 82s - loss: 8.9811e-04 - Sales_loss: 5.6930e-04 - Customers_loss: 1.9511e-04 - Sales_mse: 5.6930e-04 - Sales_rmspe: 0.1713 - Customers_mse: 1.9511e-04 - Customers_rmspe: 0.1528 - val_loss: 9.7096e-04 - val_Sales_loss: 6.2940e-04 - val_Customers_loss: 2.0928e-04 - val_Sales_mse: 6.2940e-04 - val_Sales_rmspe: 0.1528 - val_Customers_mse: 2.0928e-04 - val_Customers_rmspe: 0.1314
#
# Epoch 00007: val_Sales_mse did not improve from 0.00063
# Epoch 8/10
# 3181/3181 - 82s - loss: 8.8878e-04 - Sales_loss: 5.6555e-04 - Customers_loss: 1.9525e-04 - Sales_mse: 5.6555e-04 - Sales_rmspe: 0.1703 - Customers_mse: 1.9525e-04 - Customers_rmspe: 0.1524 - val_loss: 9.7856e-04 - val_Sales_loss: 6.3711e-04 - val_Customers_loss: 2.1726e-04 - val_Sales_mse: 6.3711e-04 - val_Sales_rmspe: 0.1518 - val_Customers_mse: 2.1726e-04 - val_Customers_rmspe: 0.1349
#
# Epoch 00008: val_Sales_mse did not improve from 0.00063
# Epoch 9/10
# 3181/3181 - 82s - loss: 8.8642e-04 - Sales_loss: 5.6595e-04 - Customers_loss: 1.9495e-04 - Sales_mse: 5.6595e-04 - Sales_rmspe: 0.1699 - Customers_mse: 1.9495e-04 - Customers_rmspe: 0.1519 - val_loss: 9.7700e-04 - val_Sales_loss: 6.2981e-04 - val_Customers_loss: 2.2660e-04 - val_Sales_mse: 6.2981e-04 - val_Sales_rmspe: 0.1412 - val_Customers_mse: 2.2660e-04 - val_Customers_rmspe: 0.1236
#
# Epoch 00009: val_Sales_mse did not improve from 0.00063
# Epoch 10/10
# 3181/3181 - 82s - loss: 8.7907e-04 - Sales_loss: 5.6339e-04 - Customers_loss: 1.9392e-04 - Sales_mse: 5.6339e-04 - Sales_rmspe: 0.1697 - Customers_mse: 1.9392e-04 - Customers_rmspe: 0.1516 - val_loss: 0.0010 - val_Sales_loss: 6.7680e-04 - val_Customers_loss: 2.2713e-04 - val_Sales_mse: 6.7680e-04 - val_Sales_rmspe: 0.1588 - val_Customers_mse: 2.2713e-04 - val_Customers_rmspe: 0.1405
#
# Epoch 00010: val_Sales_mse did not improve from 0.00063
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0010 - Sales_loss: 6.2826e-04 - Customers_loss: 2.1968e-04 - Sales_mse: 6.2826e-04 - Sales_rmspe: 0.1419 - Customers_mse: 2.1968e-04 - Customers_rmspe: 0.1421
# Cat vars chosen: ['CompetitionOpenSinceYear', 'Store', 'Events', 'Promo_fw', 'Promo_bw', 'Promo', 'Promo2SinceYear', 'StateHoliday_bool_fw', 'Month', 'StoreType', 'Close_bool_bw', 'SchoolHoliday_fw', 'Week', 'Close_bool_fw', 'SchoolHoliday_bw', 'StateHoliday', 'DayOfWeek', 'Promo2', 'Year', 'Promo2Weeks', 'StateHoliday_bool_bw', 'SchoolHoliday']
# Cont vars chosen: ['Mean_TemperatureC', 'trend', 'Mean_Humidity', 'BeforePromo', 'Mean_Wind_SpeedKm_h', 'Precipitationmm', 'AfterStateHoliday_bool', 'Max_Humidity', 'CompetitionDistance', 'BeforeSchoolHoliday', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-6.hdf5
# Epoch 6/10
# 3181/3181 - 88s - loss: 0.0010 - Sales_loss: 6.3660e-04 - Customers_loss: 2.1819e-04 - Sales_mse: 6.3660e-04 - Sales_rmspe: 0.1822 - Customers_mse: 2.1819e-04 - Customers_rmspe: 0.1645 - val_loss: 0.0012 - val_Sales_loss: 7.4219e-04 - val_Customers_loss: 3.1664e-04 - val_Sales_mse: 7.4219e-04 - val_Sales_rmspe: 0.1612 - val_Customers_mse: 3.1664e-04 - val_Customers_rmspe: 0.1707
#
# Epoch 00006: val_Sales_mse did not improve from 0.00072
# Epoch 7/10
# 3181/3181 - 88s - loss: 9.8370e-04 - Sales_loss: 6.2661e-04 - Customers_loss: 2.1430e-04 - Sales_mse: 6.2661e-04 - Sales_rmspe: 0.1810 - Customers_mse: 2.1430e-04 - Customers_rmspe: 0.1625 - val_loss: 0.0010 - val_Sales_loss: 6.5706e-04 - val_Customers_loss: 2.3326e-04 - val_Sales_mse: 6.5706e-04 - val_Sales_rmspe: 0.1507 - val_Customers_mse: 2.3326e-04 - val_Customers_rmspe: 0.1434
#
# Epoch 00007: val_Sales_mse improved from 0.00072 to 0.00066, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-6.hdf5
# Epoch 8/10
# ...
#
# Epoch 00009: val_Sales_mse did not improve from 0.00066
# Epoch 10/10
# 3181/3181 - 87s - loss: 9.4040e-04 - Sales_loss: 6.0804e-04 - Customers_loss: 2.0898e-04 - Sales_mse: 6.0804e-04 - Sales_rmspe: 0.1778 - Customers_mse: 2.0898e-04 - Customers_rmspe: 0.1604 - val_loss: 0.0012 - val_Sales_loss: 7.9258e-04 - val_Customers_loss: 3.2769e-04 - val_Sales_mse: 7.9258e-04 - val_Sales_rmspe: 0.1707 - val_Customers_mse: 3.2769e-04 - val_Customers_rmspe: 0.1804
#
# Epoch 00010: val_Sales_mse did not improve from 0.00066
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0010 - Sales_loss: 6.5706e-04 - Customers_loss: 2.3326e-04 - Sales_mse: 6.5706e-04 - Sales_rmspe: 0.1458 - Customers_mse: 2.3326e-04 - Customers_rmspe: 0.1387
# Cont vars chosen: ['BeforeClose_bool', 'Max_TemperatureC', 'trend', 'Min_TemperatureC', 'CompetitionDistance', 'Max_Humidity', 'Precipitationmm', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'CloudCover', 'AfterStateHoliday_bool', 'trend_DE', 'BeforePromo', 'StateHoliday_bool', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
#
# Epoch 00006: val_Sales_mse did not improve from 0.00065
# Epoch 7/10
# 3181/3181 - 90s - loss: 9.0875e-04 - Sales_loss: 5.7143e-04 - Customers_loss: 1.9632e-04 - Sales_mse: 5.7143e-04 - Sales_rmspe: 0.1708 - Customers_mse: 1.9632e-04 - Customers_rmspe: 0.1520 - val_loss: 0.0010 - val_Sales_loss: 6.4577e-04 - val_Customers_loss: 2.4621e-04 - val_Sales_mse: 6.4577e-04 - val_Sales_rmspe: 0.1513 - val_Customers_mse: 2.4621e-04 - val_Customers_rmspe: 0.1476
#
# Epoch 00007: val_Sales_mse improved from 0.00065 to 0.00065, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel5-7.hdf5
# Epoch 8/10
# 3181/3181 - 89s - loss: 8.9855e-04 - Sales_loss: 5.6740e-04 - Customers_loss: 1.9491e-04 - Sales_mse: 5.6740e-04 - Sales_rmspe: 0.1700 - Customers_mse: 1.9491e-04 - Customers_rmspe: 0.1514 - val_loss: 0.0011 - val_Sales_loss: 7.6279e-04 - val_Customers_loss: 2.4521e-04 - val_Sales_mse: 7.6279e-04 - val_Sales_rmspe: 0.1625 - val_Customers_mse: 2.4521e-04 - val_Customers_rmspe: 0.1418
#
# Epoch 00008: val_Sales_mse did not improve from 0.00065
# Epoch 9/10
# 3181/3181 - 89s - loss: 8.9190e-04 - Sales_loss: 5.6431e-04 - Customers_loss: 1.9427e-04 - Sales_mse: 5.6431e-04 - Sales_rmspe: 0.1691 - Customers_mse: 1.9427e-04 - Customers_rmspe: 0.1505 - val_loss: 0.0010 - val_Sales_loss: 6.7734e-04 - val_Customers_loss: 2.3354e-04 - val_Sales_mse: 6.7734e-04 - val_Sales_rmspe: 0.1558 - val_Customers_mse: 2.3354e-04 - val_Customers_rmspe: 0.1403
#
# Epoch 00009: val_Sales_mse did not improve from 0.00065
# Epoch 10/10
# 3181/3181 - 90s - loss: 8.8399e-04 - Sales_loss: 5.5951e-04 - Customers_loss: 1.9346e-04 - Sales_mse: 5.5951e-04 - Sales_rmspe: 0.1682 - Customers_mse: 1.9346e-04 - Customers_rmspe: 0.1500 - val_loss: 9.9282e-04 - val_Sales_loss: 6.5280e-04 - val_Customers_loss: 2.1293e-04 - val_Sales_mse: 6.5280e-04 - val_Sales_rmspe: 0.1460 - val_Customers_mse: 2.1293e-04 - val_Customers_rmspe: 0.1298
#
# Epoch 00010: val_Sales_mse did not improve from 0.00065
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 0.0010 - Sales_loss: 6.4577e-04 - Customers_loss: 2.4621e-04 - Sales_mse: 6.4577e-04 - Sales_rmspe: 0.1469 - Customers_mse: 2.4621e-04 - Customers_rmspe: 0.1440
# Cont vars chosen: ['Mean_Humidity', 'trend_DE', 'CloudCover', 'Max_Wind_SpeedKm_h', 'Mean_TemperatureC', 'trend', 'AfterPromo', 'AfterStateHoliday_bool', 'BeforeSchoolHoliday', 'Max_TemperatureC', 'Min_TemperatureC', 'BeforeStateHoliday_bool', 'CompetitionDistance', 'Min_Humidity', 'Max_Humidity', 'BeforeClose_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation