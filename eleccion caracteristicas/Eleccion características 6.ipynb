# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=2a92d69f951788dcbbe9c6a661bcb52884f3dc7860b0d0b9d0e4a99223c6cadb
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 325

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion6.csv")
# Out:
# Cat vars chosen: ['Week', 'Promo_bw', 'Events', 'Close_bool_fw', 'Month', 'CompetitionOpenSinceYear', 'Promo', 'SchoolHoliday_fw', 'Close_bool_bw', 'StateHoliday', 'Promo2Weeks', 'Store', 'SchoolHoliday_bw', 'Promo_fw', 'StateHoliday_bool_bw', 'CompetitionMonthsOpen', 'Day', 'StoreType', 'Year', 'StateHoliday_bool_fw', 'PromoInterval', 'Assortment', 'Promo2SinceYear']
# Cont vars chosen: ['AfterClose_bool', 'AfterSchoolHoliday', 'Max_Humidity', 'Mean_TemperatureC', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'CompetitionDistance', 'BeforePromo', 'BeforeClose_bool', 'trend', 'AfterPromo', 'CloudCover', 'Mean_Humidity', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'StateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
# Cont vars chosen: ['Max_Wind_SpeedKm_h', 'Max_TemperatureC', 'BeforeClose_bool', 'AfterPromo', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'Mean_TemperatureC', 'AfterClose_bool', 'AfterSchoolHoliday', 'trend_DE', 'CloudCover', 'trend', 'Min_Humidity', 'Precipitationmm', 'BeforePromo', 'Max_Humidity', 'Mean_Humidity', 'CompetitionDistance', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 94s - loss: 0.0179 - Sales_loss: 8.5059e-04 - Customers_loss: 5.2544e-04 - Sales_mse: 8.5059e-04 - Sales_rmspe: 0.1886 - Customers_mse: 5.2544e-04 - Customers_rmspe: 0.1836 - val_loss: 0.0012 - val_Sales_loss: 6.7495e-04 - val_Customers_loss: 2.1082e-04 - val_Sales_mse: 6.7495e-04 - val_Sales_rmspe: 0.1566 - val_Customers_mse: 2.1082e-04 - val_Customers_rmspe: 0.1347
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00067, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-1.hdf5
# Epoch 2/10
# 3181/3181 - 91s - loss: 0.0011 - Sales_loss: 5.8207e-04 - Customers_loss: 2.0379e-04 - Sales_mse: 5.8207e-04 - Sales_rmspe: 0.1730 - Customers_mse: 2.0379e-04 - Customers_rmspe: 0.1560 - val_loss: 0.0011 - val_Sales_loss: 6.3241e-04 - val_Customers_loss: 2.1073e-04 - val_Sales_mse: 6.3241e-04 - val_Sales_rmspe: 0.1458 - val_Customers_mse: 2.1073e-04 - val_Customers_rmspe: 0.1359
#
# Epoch 00002: val_Sales_mse improved from 0.00067 to 0.00063, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-1.hdf5
# Epoch 3/10
# 3181/3181 - 90s - loss: 9.6401e-04 - Sales_loss: 5.6028e-04 - Customers_loss: 1.9406e-04 - Sales_mse: 5.6028e-04 - Sales_rmspe: 0.1690 - Customers_mse: 1.9406e-04 - Customers_rmspe: 0.1517 - val_loss: 0.0010 - val_Sales_loss: 6.1866e-04 - val_Customers_loss: 2.0016e-04 - val_Sales_mse: 6.1866e-04 - val_Sales_rmspe: 0.1469 - val_Customers_mse: 2.0016e-04 - val_Customers_rmspe: 0.1276
#
# Epoch 00003: val_Sales_mse improved from 0.00063 to 0.00062, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-1.hdf5
# Epoch 4/10
# 3181/3181 - 91s - loss: 9.1441e-04 - Sales_loss: 5.4754e-04 - Customers_loss: 1.8953e-04 - Sales_mse: 5.4754e-04 - Sales_rmspe: 0.1668 - Customers_mse: 1.8953e-04 - Customers_rmspe: 0.1502 - val_loss: 9.7419e-04 - val_Sales_loss: 6.1124e-04 - val_Customers_loss: 1.9289e-04 - val_Sales_mse: 6.1124e-04 - val_Sales_rmspe: 0.1525 - val_Customers_mse: 1.9289e-04 - val_Customers_rmspe: 0.1332
#
# Epoch 00004: val_Sales_mse improved from 0.00062 to 0.00061, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# Epoch 10/10
# 3181/3181 - 91s - loss: 8.3402e-04 - Sales_loss: 5.1943e-04 - Customers_loss: 1.8169e-04 - Sales_mse: 5.1943e-04 - Sales_rmspe: 0.1634 - Customers_mse: 1.8169e-04 - Customers_rmspe: 0.1466 - val_loss: 0.0010 - val_Sales_loss: 6.9600e-04 - val_Customers_loss: 2.0641e-04 - val_Sales_mse: 6.9600e-04 - val_Sales_rmspe: 0.1635 - val_Customers_mse: 2.0641e-04 - val_Customers_rmspe: 0.1367
#
# Epoch 00010: val_Sales_mse did not improve from 0.00061
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 9.8097e-04 - Sales_loss: 6.0834e-04 - Customers_loss: 2.3392e-04 - Sales_mse: 6.0834e-04 - Sales_rmspe: 0.1447 - Customers_mse: 2.3392e-04 - Customers_rmspe: 0.1464
# Cont vars chosen: ['Min_Humidity', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'Max_TemperatureC', 'AfterStateHoliday_bool', 'trend_DE', 'CompetitionDistance', 'BeforePromo', 'AfterPromo', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'BeforeClose_bool', 'Max_Humidity', 'AfterClose_bool', 'CloudCover', 'trend']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 94s - loss: 0.0249 - Sales_loss: 9.8542e-04 - Customers_loss: 7.2089e-04 - Sales_mse: 9.8542e-04 - Sales_rmspe: 0.1847 - Customers_mse: 7.2089e-04 - Customers_rmspe: 0.1804 - val_loss: 0.0012 - val_Sales_loss: 6.5988e-04 - val_Customers_loss: 2.3059e-04 - val_Sales_mse: 6.5988e-04 - val_Sales_rmspe: 0.1475 - val_Customers_mse: 2.3059e-04 - val_Customers_rmspe: 0.1358
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00066, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-2.hdf5
# Epoch 2/10
# 3181/3181 - 90s - loss: 0.0011 - Sales_loss: 5.7398e-04 - Customers_loss: 2.0469e-04 - Sales_mse: 5.7398e-04 - Sales_rmspe: 0.1717 - Customers_mse: 2.0469e-04 - Customers_rmspe: 0.1557 - val_loss: 0.0011 - val_Sales_loss: 6.4107e-04 - val_Customers_loss: 2.4070e-04 - val_Sales_mse: 6.4107e-04 - val_Sales_rmspe: 0.1485 - val_Customers_mse: 2.4070e-04 - val_Customers_rmspe: 0.1426
#
# Epoch 00002: val_Sales_mse improved from 0.00066 to 0.00064, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-2.hdf5
# Epoch 3/10
# 3181/3181 - 90s - loss: 9.5799e-04 - Sales_loss: 5.4822e-04 - Customers_loss: 1.9475e-04 - Sales_mse: 5.4822e-04 - Sales_rmspe: 0.1678 - Customers_mse: 1.9475e-04 - Customers_rmspe: 0.1515 - val_loss: 0.0011 - val_Sales_loss: 7.0015e-04 - val_Customers_loss: 2.0944e-04 - val_Sales_mse: 7.0015e-04 - val_Sales_rmspe: 0.1662 - val_Customers_mse: 2.0944e-04 - val_Customers_rmspe: 0.1380
#
# Epoch 00008: val_Sales_mse did not improve from 0.00063
# Epoch 9/10
# 3181/3181 - 90s - loss: 8.2792e-04 - Sales_loss: 5.1699e-04 - Customers_loss: 1.8172e-04 - Sales_mse: 5.1699e-04 - Sales_rmspe: 0.1631 - Customers_mse: 1.8172e-04 - Customers_rmspe: 0.1465 - val_loss: 9.7069e-04 - val_Sales_loss: 6.3597e-04 - val_Customers_loss: 2.0437e-04 - val_Sales_mse: 6.3597e-04 - val_Sales_rmspe: 0.1452 - val_Customers_mse: 2.0437e-04 - val_Customers_rmspe: 0.1316
#
# Epoch 00009: val_Sales_mse did not improve from 0.00063
# Epoch 10/10
# 3181/3181 - 90s - loss: 8.2439e-04 - Sales_loss: 5.1632e-04 - Customers_loss: 1.8190e-04 - Sales_mse: 5.1632e-04 - Sales_rmspe: 0.1630 - Customers_mse: 1.8190e-04 - Customers_rmspe: 0.1467 - val_loss: 9.3549e-04 - val_Sales_loss: 6.1155e-04 - val_Customers_loss: 1.9787e-04 - val_Sales_mse: 6.1155e-04 - val_Sales_rmspe: 0.1400 - val_Customers_mse: 1.9787e-04 - val_Customers_rmspe: 0.1212
#
# Epoch 00010: val_Sales_mse improved from 0.00063 to 0.00061, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-2.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.3549e-04 - Sales_loss: 6.1155e-04 - Customers_loss: 1.9787e-04 - Sales_mse: 6.1155e-04 - Sales_rmspe: 0.1364 - Customers_mse: 1.9787e-04 - Customers_rmspe: 0.1185
# Cat vars chosen: ['CompetitionMonthsOpen', 'SchoolHoliday_bw', 'Promo2', 'SchoolHoliday', 'Promo2Weeks', 'PromoInterval', 'Week', 'Month', 'SchoolHoliday_fw', 'Promo', 'StateHoliday_bool_bw']
# Cont vars chosen: ['AfterClose_bool', 'AfterSchoolHoliday', 'Max_Humidity', 'Mean_TemperatureC', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'CompetitionDistance', 'BeforePromo', 'BeforeClose_bool', 'trend', 'AfterPromo', 'CloudCover', 'Mean_Humidity', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'StateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 79s - loss: 0.0160 - Sales_loss: 0.0047 - Customers_loss: 0.0025 - Sales_mse: 0.0047 - Sales_rmspe: 0.5196 - Customers_mse: 0.0025 - Customers_rmspe: 0.5271 - val_loss: 0.0071 - val_Sales_loss: 0.0045 - val_Customers_loss: 0.0024 - val_Sales_mse: 0.0045 - val_Sales_rmspe: 0.5254 - val_Customers_mse: 0.0024 - val_Customers_rmspe: 0.5506
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00452, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00007: val_Sales_mse did not improve from 0.00415
# Epoch 8/10
# 3181/3181 - 75s - loss: 0.0065 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4944 - Customers_mse: 0.0020 - Customers_rmspe: 0.5008 - val_loss: 0.0070 - val_Sales_loss: 0.0041 - val_Customers_loss: 0.0025 - val_Sales_mse: 0.0041 - val_Sales_rmspe: 0.4427 - val_Customers_mse: 0.0025 - val_Customers_rmspe: 0.5087
#
# Epoch 00008: val_Sales_mse improved from 0.00415 to 0.00414, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-3.hdf5
# Epoch 9/10
# 3181/3181 - 76s - loss: 0.0065 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4944 - Customers_mse: 0.0020 - Customers_rmspe: 0.5006 - val_loss: 0.0071 - val_Sales_loss: 0.0042 - val_Customers_loss: 0.0026 - val_Sales_mse: 0.0042 - val_Sales_rmspe: 0.4362 - val_Customers_mse: 0.0026 - val_Customers_rmspe: 0.5734
#
# Epoch 00009: val_Sales_mse did not improve from 0.00414
# Epoch 10/10
# 3181/3181 - 76s - loss: 0.0064 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4945 - Customers_mse: 0.0020 - Customers_rmspe: 0.4995 - val_loss: 0.0078 - val_Sales_loss: 0.0044 - val_Customers_loss: 0.0031 - val_Sales_mse: 0.0044 - val_Sales_rmspe: 0.4971 - val_Customers_mse: 0.0031 - val_Customers_rmspe: 0.6379
#
# Epoch 00010: val_Sales_mse did not improve from 0.00414
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0070 - Sales_loss: 0.0041 - Customers_loss: 0.0025 - Sales_mse: 0.0041 - Sales_rmspe: 0.4305 - Customers_mse: 0.0025 - Customers_rmspe: 0.4933
# Cont vars chosen: ['Max_Wind_SpeedKm_h', 'Max_TemperatureC', 'BeforeClose_bool', 'AfterPromo', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'Mean_TemperatureC', 'AfterClose_bool', 'AfterSchoolHoliday', 'trend_DE', 'CloudCover', 'trend', 'Min_Humidity', 'Precipitationmm', 'BeforePromo', 'Max_Humidity', 'Mean_Humidity', 'CompetitionDistance', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 4
# Epoch 1/10
# 3181/3181 - 80s - loss: 0.0171 - Sales_loss: 0.0046 - Customers_loss: 0.0025 - Sales_mse: 0.0046 - Sales_rmspe: 0.5100 - Customers_mse: 0.0025 - Customers_rmspe: 0.5231 - val_loss: 0.0066 - val_Sales_loss: 0.0042 - val_Customers_loss: 0.0022 - val_Sales_mse: 0.0042 - val_Sales_rmspe: 0.4154 - val_Customers_mse: 0.0022 - val_Customers_rmspe: 0.4752
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
#
# Epoch 00007: val_Sales_mse did not improve from 0.00419
# Epoch 8/10
# 3181/3181 - 78s - loss: 0.0065 - Sales_loss: 0.0042 - Customers_loss: 0.0020 - Sales_mse: 0.0042 - Sales_rmspe: 0.4967 - Customers_mse: 0.0020 - Customers_rmspe: 0.5047 - val_loss: 0.0102 - val_Sales_loss: 0.0054 - val_Customers_loss: 0.0045 - val_Sales_mse: 0.0054 - val_Sales_rmspe: 0.5126 - val_Customers_mse: 0.0045 - val_Customers_rmspe: 0.6926
#
# Epoch 00008: val_Sales_mse did not improve from 0.00419
# Epoch 9/10
# 3181/3181 - 77s - loss: 0.0065 - Sales_loss: 0.0042 - Customers_loss: 0.0020 - Sales_mse: 0.0042 - Sales_rmspe: 0.4962 - Customers_mse: 0.0020 - Customers_rmspe: 0.5039 - val_loss: 0.0117 - val_Sales_loss: 0.0060 - val_Customers_loss: 0.0053 - val_Sales_mse: 0.0060 - val_Sales_rmspe: 0.5633 - val_Customers_mse: 0.0053 - val_Customers_rmspe: 0.7440
#
# Epoch 00009: val_Sales_mse did not improve from 0.00419
# Epoch 10/10
# 3181/3181 - 77s - loss: 0.0065 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4951 - Customers_mse: 0.0020 - Customers_rmspe: 0.5033 - val_loss: 0.0074 - val_Sales_loss: 0.0044 - val_Customers_loss: 0.0027 - val_Sales_mse: 0.0044 - val_Sales_rmspe: 0.4410 - val_Customers_mse: 0.0027 - val_Customers_rmspe: 0.5520
#
# Epoch 00010: val_Sales_mse did not improve from 0.00419
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0066 - Sales_loss: 0.0042 - Customers_loss: 0.0022 - Sales_mse: 0.0042 - Sales_rmspe: 0.4055 - Customers_mse: 0.0022 - Customers_rmspe: 0.4645
# Cont vars chosen: ['Min_Humidity', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'Max_TemperatureC', 'AfterStateHoliday_bool', 'trend_DE', 'CompetitionDistance', 'BeforePromo', 'AfterPromo', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'BeforeClose_bool', 'Max_Humidity', 'AfterClose_bool', 'CloudCover', 'trend']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 78s - loss: 0.0177 - Sales_loss: 0.0046 - Customers_loss: 0.0026 - Sales_mse: 0.0046 - Sales_rmspe: 0.5103 - Customers_mse: 0.0026 - Customers_rmspe: 0.5238 - val_loss: 0.0067 - val_Sales_loss: 0.0043 - val_Customers_loss: 0.0023 - val_Sales_mse: 0.0043 - val_Sales_rmspe: 0.4173 - val_Customers_mse: 0.0023 - val_Customers_rmspe: 0.4287
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
#
# Epoch 00007: val_Sales_mse did not improve from 0.00418
# Epoch 8/10
# 3181/3181 - 75s - loss: 0.0067 - Sales_loss: 0.0042 - Customers_loss: 0.0023 - Sales_mse: 0.0042 - Sales_rmspe: 0.4991 - Customers_mse: 0.0023 - Customers_rmspe: 0.5159 - val_loss: 0.0069 - val_Sales_loss: 0.0043 - val_Customers_loss: 0.0023 - val_Sales_mse: 0.0043 - val_Sales_rmspe: 0.4996 - val_Customers_mse: 0.0023 - val_Customers_rmspe: 0.5304
#
# Epoch 00008: val_Sales_mse did not improve from 0.00418
# Epoch 9/10
# 3181/3181 - 75s - loss: 0.0066 - Sales_loss: 0.0042 - Customers_loss: 0.0021 - Sales_mse: 0.0042 - Sales_rmspe: 0.4982 - Customers_mse: 0.0021 - Customers_rmspe: 0.5114 - val_loss: 0.0078 - val_Sales_loss: 0.0045 - val_Customers_loss: 0.0030 - val_Sales_mse: 0.0045 - val_Sales_rmspe: 0.4848 - val_Customers_mse: 0.0030 - val_Customers_rmspe: 0.5765
#
# Epoch 00009: val_Sales_mse did not improve from 0.00418
# Epoch 10/10
# 3181/3181 - 75s - loss: 0.0065 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4960 - Customers_mse: 0.0020 - Customers_rmspe: 0.5057 - val_loss: 0.0078 - val_Sales_loss: 0.0044 - val_Customers_loss: 0.0030 - val_Sales_mse: 0.0044 - val_Sales_rmspe: 0.4912 - val_Customers_mse: 0.0030 - val_Customers_rmspe: 0.6068
#
# Epoch 00010: val_Sales_mse did not improve from 0.00418
# Obtenemos las métricas
# 944/944 [==============================] - 5s 4ms/step - loss: 0.0066 - Sales_loss: 0.0042 - Customers_loss: 0.0022 - Sales_mse: 0.0042 - Sales_rmspe: 0.4294 - Customers_mse: 0.0022 - Customers_rmspe: 0.4584
# Cat vars chosen: ['Events', 'Promo2SinceYear', 'SchoolHoliday', 'DayOfWeek', 'Month', 'Year', 'Close_bool_bw', 'Week', 'Close_bool_fw', 'Promo', 'Promo2Weeks', 'StoreType', 'StateHoliday_bool_fw', 'PromoInterval']
# Cont vars chosen: ['AfterClose_bool', 'AfterSchoolHoliday', 'Max_Humidity', 'Mean_TemperatureC', 'BeforeStateHoliday_bool', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'CompetitionDistance', 'BeforePromo', 'BeforeClose_bool', 'trend', 'AfterPromo', 'CloudCover', 'Mean_Humidity', 'Min_TemperatureC', 'Max_Wind_SpeedKm_h', 'StateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-6.hdf5
# Epoch 7/10
# 3181/3181 - 78s - loss: 0.0059 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4634 - Customers_mse: 0.0018 - Customers_rmspe: 0.4600 - val_loss: 0.0058 - val_Sales_loss: 0.0039 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0039 - val_Sales_rmspe: 0.4451 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4118
#
# Epoch 00007: val_Sales_mse did not improve from 0.00383
# Epoch 8/10
# 3181/3181 - 78s - loss: 0.0058 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4627 - Customers_mse: 0.0018 - Customers_rmspe: 0.4584 - val_loss: 0.0058 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4130 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4288
#
# Epoch 00008: val_Sales_mse did not improve from 0.00383
# Epoch 9/10
# 3181/3181 - 77s - loss: 0.0058 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4626 - Customers_mse: 0.0018 - Customers_rmspe: 0.4580 - val_loss: 0.0056 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4228 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4201
#
# Epoch 00009: val_Sales_mse improved from 0.00383 to 0.00379, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-6.hdf5
# Epoch 10/10
# 3181/3181 - 78s - loss: 0.0058 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4617 - Customers_mse: 0.0018 - Customers_rmspe: 0.4578 - val_loss: 0.0057 - val_Sales_loss: 0.0039 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0039 - val_Sales_rmspe: 0.4627 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4240
#
# Epoch 00010: val_Sales_mse did not improve from 0.00379
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0056 - Sales_loss: 0.0038 - Customers_loss: 0.0017 - Sales_mse: 0.0038 - Sales_rmspe: 0.4133 - Customers_mse: 0.0017 - Customers_rmspe: 0.4108
# Cont vars chosen: ['Max_Wind_SpeedKm_h', 'Max_TemperatureC', 'BeforeClose_bool', 'AfterPromo', 'BeforeSchoolHoliday', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'Mean_TemperatureC', 'AfterClose_bool', 'AfterSchoolHoliday', 'trend_DE', 'CloudCover', 'trend', 'Min_Humidity', 'Precipitationmm', 'BeforePromo', 'Max_Humidity', 'Mean_Humidity', 'CompetitionDistance', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer '
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-7.hdf5
# Epoch 6/10
# 3181/3181 - 79s - loss: 0.0059 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4606 - Customers_mse: 0.0018 - Customers_rmspe: 0.4580 - val_loss: 0.0057 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4369 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4818
#
# Epoch 00006: val_Sales_mse did not improve from 0.00374
# Epoch 7/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4600 - Customers_mse: 0.0018 - Customers_rmspe: 0.4574 - val_loss: 0.0058 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4421 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.5259
#
# Epoch 00007: val_Sales_mse did not improve from 0.00374
# Epoch 8/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4603 - Customers_mse: 0.0018 - Customers_rmspe: 0.4573 - val_loss: 0.0056 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4261 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4273
#
# Epoch 00008: val_Sales_mse did not improve from 0.00374
# Epoch 9/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4601 - Customers_mse: 0.0018 - Customers_rmspe: 0.4574 - val_loss: 0.0055 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.3934 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4437
#
# Epoch 00009: val_Sales_mse improved from 0.00374 to 0.00369, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-7.hdf5
# Epoch 10/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4602 - Customers_mse: 0.0018 - Customers_rmspe: 0.4574 - val_loss: 0.0057 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4302 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4660
#
# Epoch 00010: val_Sales_mse did not improve from 0.00369
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 0.0055 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.3845 - Customers_mse: 0.0016 - Customers_rmspe: 0.4340
# Cont vars chosen: ['Min_Humidity', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'Max_TemperatureC', 'AfterStateHoliday_bool', 'trend_DE', 'CompetitionDistance', 'BeforePromo', 'AfterPromo', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'BeforeClose_bool', 'Max_Humidity', 'AfterClose_bool', 'CloudCover', 'trend']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 8
# Epoch 1/10
# 3181/3181 - 82s - loss: 0.0217 - Sales_loss: 0.0043 - Customers_loss: 0.0021 - Sales_mse: 0.0043 - Sales_rmspe: 0.4731 - Customers_mse: 0.0021 - Customers_rmspe: 0.4750 - val_loss: 0.0058 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.3811 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.3891
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00378, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-8.hdf5
# Epoch 2/10
# 3181/3181 - 79s - loss: 0.0060 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4639 - Customers_mse: 0.0018 - Customers_rmspe: 0.4616 - val_loss: 0.0058 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4557 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4963
#
# Epoch 00002: val_Sales_mse did not improve from 0.00378
# Epoch 3/10
# 3181/3181 - 79s - loss: 0.0059 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4617 - Customers_mse: 0.0018 - Customers_rmspe: 0.4601 - val_loss: 0.0055 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4145 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4293
#
# Epoch 00003: val_Sales_mse improved from 0.00378 to 0.00366, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel6-8.hdf5
# Epoch 4/10
# 3181/3181 - 79s - loss: 0.0059 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4598 - Customers_mse: 0.0018 - Customers_rmspe: 0.4601 - val_loss: 0.0057 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4643 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4871
#
# Epoch 00004: val_Sales_mse did not improve from 0.00366
# Epoch 5/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4594 - Customers_mse: 0.0018 - Customers_rmspe: 0.4599 - val_loss: 0.0056 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4357 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4480
#
# Epoch 00005: val_Sales_mse did not improve from 0.00366
# Epoch 6/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4587 - Customers_mse: 0.0018 - Customers_rmspe: 0.4590 - val_loss: 0.0057 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4189 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4566
#
# Epoch 00006: val_Sales_mse did not improve from 0.00366
# Epoch 7/10
# 3181/3181 - 80s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4579 - Customers_mse: 0.0018 - Customers_rmspe: 0.4577 - val_loss: 0.0056 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0017 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4267 - val_Customers_mse: 0.0017 - val_Customers_rmspe: 0.4556
#
# Epoch 00007: val_Sales_mse did not improve from 0.00366
# Epoch 8/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4586 - Customers_mse: 0.0018 - Customers_rmspe: 0.4585 - val_loss: 0.0055 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.3827 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4135
#
# Epoch 00008: val_Sales_mse did not improve from 0.00366
# Epoch 9/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4577 - Customers_mse: 0.0018 - Customers_rmspe: 0.4574 - val_loss: 0.0055 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4234 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4361
#
# Epoch 00009: val_Sales_mse did not improve from 0.00366
# Epoch 10/10
# 3181/3181 - 79s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4573 - Customers_mse: 0.0018 - Customers_rmspe: 0.4569 - val_loss: 0.0055 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4293 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4363
#
# Epoch 00010: val_Sales_mse did not improve from 0.00366
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0055 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4042 - Customers_mse: 0.0016 - Customers_rmspe: 0.4197
