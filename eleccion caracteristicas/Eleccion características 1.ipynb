# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=8b1095c40bd86a2c1a35a83e8b5056a18e2c0b8a750ce7667bc1dce78b104706
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 114

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion1.csv")
# Out:
# Cat vars chosen: ['Week', 'Close_bool_fw', 'Promo2SinceYear', 'CompetitionOpenSinceYear', 'StateHoliday_bool_bw', 'StateHoliday', 'Promo2SinceWeek', 'SchoolHoliday', 'DayOfWeek', 'Assortment', 'Promo', 'PromoInterval', 'StateHoliday_bool_fw', 'Month', 'SchoolHoliday_fw', 'Promo2Weeks', 'Promo_fw', 'Promo_bw', 'Store', 'Events', 'Close_bool_bw', 'CompetitionMonthsOpen', 'StoreType']
# Cont vars chosen: ['trend', 'CloudCover', 'AfterStateHoliday_bool', 'BeforeClose_bool', 'trend_DE', 'Min_TemperatureC', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'AfterClose_bool', 'Mean_Humidity', 'AfterSchoolHoliday', 'Precipitationmm']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 102s - loss: 0.0112 - Sales_loss: 0.0014 - Customers_loss: 6.1556e-04 - Sales_mse: 0.0014 - Sales_rmspe: 0.2736 - Customers_mse: 6.1556e-04 - Customers_rmspe: 0.2732 - val_loss: 0.0015 - val_Sales_loss: 9.3069e-04 - val_Customers_loss: 3.1142e-04 - val_Sales_mse: 9.3069e-04 - val_Sales_rmspe: 0.1873 - val_Customers_mse: 3.1142e-04 - val_Customers_rmspe: 0.1795
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00093, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-0.hdf5
# Epoch 8/10
# 3181/3181 - 100s - loss: 9.4719e-04 - Sales_loss: 6.1084e-04 - Customers_loss: 2.0445e-04 - Sales_mse: 6.1084e-04 - Sales_rmspe: 0.1782 - Customers_mse: 2.0445e-04 - Customers_rmspe: 0.1578 - val_loss: 0.0012 - val_Sales_loss: 7.6294e-04 - val_Customers_loss: 2.6885e-04 - val_Sales_mse: 7.6294e-04 - val_Sales_rmspe: 0.1846 - val_Customers_mse: 2.6885e-04 - val_Customers_rmspe: 0.1663
#
# Epoch 00008: val_Sales_mse did not improve from 0.00065
# Epoch 9/10
# 3181/3181 - 100s - loss: 9.3707e-04 - Sales_loss: 6.0763e-04 - Customers_loss: 2.0355e-04 - Sales_mse: 6.0763e-04 - Sales_rmspe: 0.1778 - Customers_mse: 2.0355e-04 - Customers_rmspe: 0.1571 - val_loss: 0.0012 - val_Sales_loss: 7.9949e-04 - val_Customers_loss: 2.4643e-04 - val_Sales_mse: 7.9949e-04 - val_Sales_rmspe: 0.1813 - val_Customers_mse: 2.4643e-04 - val_Customers_rmspe: 0.1492
#
# Epoch 00009: val_Sales_mse did not improve from 0.00065
# Epoch 10/10
# 3181/3181 - 101s - loss: 9.2534e-04 - Sales_loss: 6.0094e-04 - Customers_loss: 2.0234e-04 - Sales_mse: 6.0094e-04 - Sales_rmspe: 0.1766 - Customers_mse: 2.0234e-04 - Customers_rmspe: 0.1565 - val_loss: 0.0011 - val_Sales_loss: 7.0743e-04 - val_Customers_loss: 2.4957e-04 - val_Sales_mse: 7.0743e-04 - val_Sales_rmspe: 0.1592 - val_Customers_mse: 2.4957e-04 - val_Customers_rmspe: 0.1518
#
# Epoch 00010: val_Sales_mse did not improve from 0.00065
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.9647e-04 - Sales_loss: 6.4960e-04 - Customers_loss: 2.1693e-04 - Sales_mse: 6.4960e-04 - Sales_rmspe: 0.1486 - Customers_mse: 2.1693e-04 - Customers_rmspe: 0.1332
# Cont vars chosen: ['Mean_Wind_SpeedKm_h', 'AfterStateHoliday_bool', 'CloudCover', 'Mean_Humidity', 'trend', 'Min_Humidity', 'StateHoliday_bool', 'Max_TemperatureC', 'Min_TemperatureC', 'BeforeStateHoliday_bool', 'AfterPromo', 'trend_DE', 'AfterClose_bool', 'AfterSchoolHoliday', 'BeforeClose_bool', 'BeforePromo']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 102s - loss: 0.0155 - Sales_loss: 8.2119e-04 - Customers_loss: 5.1292e-04 - Sales_mse: 8.2119e-04 - Sales_rmspe: 0.1944 - Customers_mse: 5.1292e-04 - Customers_rmspe: 0.1839 - val_loss: 0.0015 - val_Sales_loss: 8.6337e-04 - val_Customers_loss: 2.9001e-04 - val_Sales_mse: 8.6337e-04 - val_Sales_rmspe: 0.1763 - val_Customers_mse: 2.9001e-04 - val_Customers_rmspe: 0.1570
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
#
# Epoch 00006: val_Sales_mse did not improve from 0.00068
# Epoch 7/10
# 3181/3181 - 100s - loss: 9.0087e-04 - Sales_loss: 5.6540e-04 - Customers_loss: 1.9569e-04 - Sales_mse: 5.6540e-04 - Sales_rmspe: 0.1701 - Customers_mse: 1.9569e-04 - Customers_rmspe: 0.1522 - val_loss: 0.0012 - val_Sales_loss: 8.1482e-04 - val_Customers_loss: 2.7676e-04 - val_Sales_mse: 8.1482e-04 - val_Sales_rmspe: 0.1651 - val_Customers_mse: 2.7676e-04 - val_Customers_rmspe: 0.1461
#
# Epoch 00007: val_Sales_mse did not improve from 0.00068
# Epoch 8/10
# 3181/3181 - 97s - loss: 8.9077e-04 - Sales_loss: 5.6053e-04 - Customers_loss: 1.9398e-04 - Sales_mse: 5.6053e-04 - Sales_rmspe: 0.1691 - Customers_mse: 1.9398e-04 - Customers_rmspe: 0.1512 - val_loss: 0.0011 - val_Sales_loss: 7.3197e-04 - val_Customers_loss: 2.4594e-04 - val_Sales_mse: 7.3197e-04 - val_Sales_rmspe: 0.1673 - val_Customers_mse: 2.4594e-04 - val_Customers_rmspe: 0.1466
#
# Epoch 00008: val_Sales_mse did not improve from 0.00068
# Epoch 9/10
# 3181/3181 - 96s - loss: 8.8254e-04 - Sales_loss: 5.5709e-04 - Customers_loss: 1.9296e-04 - Sales_mse: 5.5709e-04 - Sales_rmspe: 0.1677 - Customers_mse: 1.9296e-04 - Customers_rmspe: 0.1504 - val_loss: 0.0012 - val_Sales_loss: 7.9474e-04 - val_Customers_loss: 2.9579e-04 - val_Sales_mse: 7.9474e-04 - val_Sales_rmspe: 0.1782 - val_Customers_mse: 2.9579e-04 - val_Customers_rmspe: 0.1700
#
# Epoch 00009: val_Sales_mse did not improve from 0.00068
# Epoch 10/10
# 3181/3181 - 96s - loss: 8.7688e-04 - Sales_loss: 5.5392e-04 - Customers_loss: 1.9281e-04 - Sales_mse: 5.5392e-04 - Sales_rmspe: 0.1679 - Customers_mse: 1.9281e-04 - Customers_rmspe: 0.1505 - val_loss: 0.0011 - val_Sales_loss: 7.0642e-04 - val_Customers_loss: 2.1948e-04 - val_Sales_mse: 7.0642e-04 - val_Sales_rmspe: 0.1614 - val_Customers_mse: 2.1948e-04 - val_Customers_rmspe: 0.1364
#
# Epoch 00010: val_Sales_mse did not improve from 0.00068
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 0.0011 - Sales_loss: 6.7980e-04 - Customers_loss: 2.2595e-04 - Sales_mse: 6.7980e-04 - Sales_rmspe: 0.1467 - Customers_mse: 2.2595e-04 - Customers_rmspe: 0.1405
# Cont vars chosen: ['Precipitationmm', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'AfterPromo', 'Min_TemperatureC', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'CompetitionDistance', 'trend', 'Min_Humidity', 'AfterSchoolHoliday', 'trend_DE', 'BeforeStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 
# Cat vars chosen: ['Promo2Weeks', 'StateHoliday_bool_fw', 'Close_bool_fw', 'StateHoliday_bool_bw', 'Day', 'Promo_fw', 'Store', 'Events', 'SchoolHoliday_fw', 'Year', 'DayOfWeek', 'SchoolHoliday', 'Promo2SinceWeek', 'Promo2', 'PromoInterval', 'StateHoliday', 'Week', 'StoreType', 'Close_bool_bw', 'Month', 'CompetitionOpenSinceYear', 'SchoolHoliday_bw', 'Promo_bw']
# Cont vars chosen: ['trend', 'CloudCover', 'AfterStateHoliday_bool', 'BeforeClose_bool', 'trend_DE', 'Min_TemperatureC', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'AfterClose_bool', 'Mean_Humidity', 'AfterSchoolHoliday', 'Precipitationmm']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 102s - loss: 0.0096 - Sales_loss: 0.0013 - Customers_loss: 5.8545e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2706 - Customers_mse: 5.8545e-04 - Customers_rmspe: 0.2670 - val_loss: 0.0014 - val_Sales_loss: 8.3528e-04 - val_Customers_loss: 2.9619e-04 - val_Sales_mse: 8.3528e-04 - val_Sales_rmspe: 0.1818 - val_Customers_mse: 2.9619e-04 - val_Customers_rmspe: 0.1840
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00084, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-3.hdf5
# Epoch 2/10
# 3181/3181 - 97s - loss: 0.0014 - Sales_loss: 8.3396e-04 - Customers_loss: 2.8983e-04 - Sales_mse: 8.3396e-04 - Sales_rmspe: 0.2247 - Customers_mse: 2.8983e-04 - Customers_rmspe: 0.2070 - val_loss: 0.0013 - val_Sales_loss: 7.7754e-04 - val_Customers_loss: 2.7283e-04 - val_Sales_mse: 7.7754e-04 - val_Sales_rmspe: 0.1738 - val_Customers_mse: 2.7283e-04 - val_Customers_rmspe: 0.1784
#
# Epoch 00002: val_Sales_mse improved from 0.00084 to 0.00078, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-3.hdf5
# Epoch 3/10
# 3181/3181 - 96s - loss: 0.0011 - Sales_loss: 6.6296e-04 - Customers_loss: 2.2808e-04 - Sales_mse: 6.6296e-04 - Sales_rmspe: 0.1885 - Customers_mse: 2.2808e-04 - Customers_rmspe: 0.1683 - val_loss: 0.0012 - val_Sales_loss: 7.3571e-04 - val_Customers_loss: 2.3839e-04 - val_Sales_mse: 7.3571e-04 - val_Sales_rmspe: 0.1572 - val_Customers_mse: 2.3839e-04 - val_Customers_rmspe: 0.1447
#
# Epoch 00003: val_Sales_mse improved from 0.00078 to 0.00074, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-3.hdf5
# Epoch 4/10
# 3181/3181 - 95s - loss: 0.0010 - Sales_loss: 6.1369e-04 - Customers_loss: 2.1112e-04 - Sales_mse: 6.1369e-04 - Sales_rmspe: 0.1819 - Customers_mse: 2.1112e-04 - Customers_rmspe: 0.1619 - val_loss: 0.0011 - val_Sales_loss: 6.7121e-04 - val_Customers_loss: 2.4206e-04 - val_Sales_mse: 6.7121e-04 - val_Sales_rmspe: 0.1582 - val_Customers_mse: 2.4206e-04 - val_Customers_rmspe: 0.1435
#
# Epoch 00004: val_Sales_mse improved from 0.00074 to 0.00067, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 97s - loss: 8.6668e-04 - Sales_loss: 5.4797e-04 - Customers_loss: 1.8654e-04 - Sales_mse: 5.4797e-04 - Sales_rmspe: 0.1720 - Customers_mse: 1.8654e-04 - Customers_rmspe: 0.1521 - val_loss: 0.0011 - val_Sales_loss: 6.9959e-04 - val_Customers_loss: 2.4458e-04 - val_Sales_mse: 6.9959e-04 - val_Sales_rmspe: 0.1767 - val_Customers_mse: 2.4458e-04 - val_Customers_rmspe: 0.1630
#
# Epoch 00010: val_Sales_mse did not improve from 0.00063
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0010 - Sales_loss: 6.2675e-04 - Customers_loss: 2.4014e-04 - Sales_mse: 6.2675e-04 - Sales_rmspe: 0.1484 - Customers_mse: 2.4014e-04 - Customers_rmspe: 0.1461
# Cont vars chosen: ['Mean_Wind_SpeedKm_h', 'AfterStateHoliday_bool', 'CloudCover', 'Mean_Humidity', 'trend', 'Min_Humidity', 'StateHoliday_bool', 'Max_TemperatureC', 'Min_TemperatureC', 'BeforeStateHoliday_bool', 'AfterPromo', 'trend_DE', 'AfterClose_bool', 'AfterSchoolHoliday', 'BeforeClose_bool', 'BeforePromo']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 4
# Epoch 1/10
# 3181/3181 - 104s - loss: 0.0140 - Sales_loss: 8.5394e-04 - Customers_loss: 3.3629e-04 - Sales_mse: 8.5394e-04 - Sales_rmspe: 0.1873 - Customers_mse: 3.3629e-04 - Customers_rmspe: 0.1745 - val_loss: 0.0011 - val_Sales_loss: 6.3020e-04 - val_Customers_loss: 2.0541e-04 - val_Sales_mse: 6.3020e-04 - val_Sales_rmspe: 0.1440 - val_Customers_mse: 2.0541e-04 - val_Customers_rmspe: 0.1305
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00063, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-4.hdf5
# Epoch 2/10
# 3181/3181 - 99s - loss: 0.0010 - Sales_loss: 5.7876e-04 - Customers_loss: 2.0180e-04 - Sales_mse: 5.7876e-04 - Sales_rmspe: 0.1725 - Customers_mse: 2.0180e-04 - Customers_rmspe: 0.1574 - val_loss: 0.0011 - val_Sales_loss: 6.9803e-04 - val_Customers_loss: 2.3501e-04 - val_Sales_mse: 6.9803e-04 - val_Sales_rmspe: 0.1477 - val_Customers_mse: 2.3501e-04 - val_Customers_rmspe: 0.1414
#
# Epoch 00002: val_Sales_mse did not improve from 0.00063
# Epoch 3/10
# 3181/3181 - 98s - loss: 9.6060e-04 - Sales_loss: 5.6300e-04 - Customers_loss: 1.9476e-04 - Sales_mse: 5.6300e-04 - Sales_rmspe: 0.1710 - Customers_mse: 1.9476e-04 - Customers_rmspe: 0.1566 - val_loss: 0.0012 - val_Sales_loss: 7.4145e-04 - val_Customers_loss: 2.9436e-04 - val_Sales_mse: 7.4145e-04 - val_Sales_rmspe: 0.1661 - val_Customers_mse: 2.9436e-04 - val_Customers_rmspe: 0.1577
#
# Epoch 00003: val_Sales_mse did not improve from 0.00063
# Epoch 4/10
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-4.hdf5
# Epoch 9/10
# 3181/3181 - 98s - loss: 8.3205e-04 - Sales_loss: 5.1829e-04 - Customers_loss: 1.7201e-04 - Sales_mse: 5.1829e-04 - Sales_rmspe: 0.1611 - Customers_mse: 1.7201e-04 - Customers_rmspe: 0.1437 - val_loss: 9.9449e-04 - val_Sales_loss: 6.2131e-04 - val_Customers_loss: 2.3073e-04 - val_Sales_mse: 6.2131e-04 - val_Sales_rmspe: 0.1541 - val_Customers_mse: 2.3073e-04 - val_Customers_rmspe: 0.1543
#
# Epoch 00009: val_Sales_mse did not improve from 0.00059
# Epoch 10/10
# 3181/3181 - 98s - loss: 8.2664e-04 - Sales_loss: 5.1576e-04 - Customers_loss: 1.7171e-04 - Sales_mse: 5.1576e-04 - Sales_rmspe: 0.1605 - Customers_mse: 1.7171e-04 - Customers_rmspe: 0.1433 - val_loss: 9.4554e-04 - val_Sales_loss: 6.1189e-04 - val_Customers_loss: 1.9360e-04 - val_Sales_mse: 6.1189e-04 - val_Sales_rmspe: 0.1471 - val_Customers_mse: 1.9360e-04 - val_Customers_rmspe: 0.1320
#
# Epoch 00010: val_Sales_mse did not improve from 0.00059
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 9.7792e-04 - Sales_loss: 5.9010e-04 - Customers_loss: 2.3951e-04 - Sales_mse: 5.9010e-04 - Sales_rmspe: 0.1377 - Customers_mse: 2.3951e-04 - Customers_rmspe: 0.1424
# Cont vars chosen: ['Precipitationmm', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'AfterPromo', 'Min_TemperatureC', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'CompetitionDistance', 'trend', 'Min_Humidity', 'AfterSchoolHoliday', 'trend_DE', 'BeforeStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 100s - loss: 0.0206 - Sales_loss: 0.0010 - Customers_loss: 4.4029e-04 - Sales_mse: 0.0010 - Sales_rmspe: 0.1856 - Customers_mse: 4.4029e-04 - Customers_rmspe: 0.1754 - val_loss: 0.0012 - val_Sales_loss: 7.0062e-04 - val_Customers_loss: 2.2940e-04 - val_Sales_mse: 7.0062e-04 - val_Sales_rmspe: 0.1718 - val_Customers_mse: 2.2940e-04 - val_Customers_rmspe: 0.1529
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00070, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-5.hdf5
# Epoch 2/10
# 3181/3181 - 98s - loss: 9.8839e-04 - Sales_loss: 5.6213e-04 - Customers_loss: 1.8818e-04 - Sales_mse: 5.6213e-04 - Sales_rmspe: 0.1699 - Customers_mse: 1.8818e-04 - Customers_rmspe: 0.1526 - val_loss: 0.0012 - val_Sales_loss: 6.6057e-04 - val_Customers_loss: 2.7733e-04 - val_Sales_mse: 6.6057e-04 - val_Sales_rmspe: 0.1601 - val_Customers_mse: 2.7733e-04 - val_Customers_rmspe: 0.1638
#
# Epoch 00002: val_Sales_mse improved from 0.00070 to 0.00066, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-5.hdf5
# Epoch 9/10
# 3181/3181 - 98s - loss: 8.1304e-04 - Sales_loss: 5.1086e-04 - Customers_loss: 1.6813e-04 - Sales_mse: 5.1086e-04 - Sales_rmspe: 0.1587 - Customers_mse: 1.6813e-04 - Customers_rmspe: 0.1394 - val_loss: 9.7250e-04 - val_Sales_loss: 6.2560e-04 - val_Customers_loss: 2.0967e-04 - val_Sales_mse: 6.2560e-04 - val_Sales_rmspe: 0.1423 - val_Customers_mse: 2.0967e-04 - val_Customers_rmspe: 0.1373
#
# Epoch 00009: val_Sales_mse did not improve from 0.00062
# Epoch 10/10
# 3181/3181 - 96s - loss: 8.0484e-04 - Sales_loss: 5.0607e-04 - Customers_loss: 1.6690e-04 - Sales_mse: 5.0607e-04 - Sales_rmspe: 0.1582 - Customers_mse: 1.6690e-04 - Customers_rmspe: 0.1391 - val_loss: 9.4932e-04 - val_Sales_loss: 6.0362e-04 - val_Customers_loss: 2.1144e-04 - val_Sales_mse: 6.0362e-04 - val_Sales_rmspe: 0.1405 - val_Customers_mse: 2.1144e-04 - val_Customers_rmspe: 0.1355
#
# Epoch 00010: val_Sales_mse improved from 0.00062 to 0.00060, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-5.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.4932e-04 - Sales_loss: 6.0362e-04 - Customers_loss: 2.1144e-04 - Sales_mse: 6.0362e-04 - Sales_rmspe: 0.1375 - Customers_mse: 2.1144e-04 - Customers_rmspe: 0.1329
# Cat vars chosen: ['Events', 'SchoolHoliday_fw', 'Promo_fw', 'Week', 'Month', 'Close_bool_fw', 'State', 'Promo2Weeks', 'Promo2SinceWeek', 'SchoolHoliday_bw', 'PromoInterval']
# Cont vars chosen: ['trend', 'CloudCover', 'AfterStateHoliday_bool', 'BeforeClose_bool', 'trend_DE', 'Min_TemperatureC', 'AfterPromo', 'Max_Wind_SpeedKm_h', 'BeforeSchoolHoliday', 'AfterClose_bool', 'Mean_Humidity', 'AfterSchoolHoliday', 'Precipitationmm']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# ...
#
# Epoch 00002: val_Sales_mse improved from 0.00604 to 0.00489, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-6.hdf5
# Epoch 3/10
# 3181/3181 - 81s - loss: 0.0060 - Sales_loss: 0.0039 - Customers_loss: 0.0019 - Sales_mse: 0.0039 - Sales_rmspe: 0.4899 - Customers_mse: 0.0019 - Customers_rmspe: 0.4858 - val_loss: 0.0155 - val_Sales_loss: 0.0063 - val_Customers_loss: 0.0090 - val_Sales_mse: 0.0063 - val_Sales_rmspe: 0.5146 - val_Customers_mse: 0.0090 - val_Customers_rmspe: 0.8316
#
# Epoch 00003: val_Sales_mse did not improve from 0.00489
# Epoch 4/10
# 3181/3181 - 81s - loss: 0.0059 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4842 - Customers_mse: 0.0018 - Customers_rmspe: 0.4815 - val_loss: 0.0140 - val_Sales_loss: 0.0055 - val_Customers_loss: 0.0083 - val_Sales_mse: 0.0055 - val_Sales_rmspe: 0.4950 - val_Customers_mse: 0.0083 - val_Customers_rmspe: 0.7710
#
# Epoch 00010: val_Sales_mse did not improve from 0.00489
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0117 - Sales_loss: 0.0049 - Customers_loss: 0.0065 - Sales_mse: 0.0049 - Sales_rmspe: 0.4447 - Customers_mse: 0.0065 - Customers_rmspe: 0.7204
# Cont vars chosen: ['Mean_Wind_SpeedKm_h', 'AfterStateHoliday_bool', 'CloudCover', 'Mean_Humidity', 'trend', 'Min_Humidity', 'StateHoliday_bool', 'Max_TemperatureC', 'Min_TemperatureC', 'BeforeStateHoliday_bool', 'AfterPromo', 'trend_DE', 'AfterClose_bool', 'AfterSchoolHoliday', 'BeforeClose_bool', 'BeforePromo']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 86s - loss: 0.0177 - Sales_loss: 0.0041 - Customers_loss: 0.0022 - Sales_mse: 0.0041 - Sales_rmspe: 0.4995 - Customers_mse: 0.0022 - Customers_rmspe: 0.5032 - val_loss: 0.0133 - val_Sales_loss: 0.0056 - val_Customers_loss: 0.0075 - val_Sales_mse: 0.0056 - val_Sales_rmspe: 0.5228 - val_Customers_mse: 0.0075 - val_Customers_rmspe: 0.7826
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00555, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-7.hdf5
# Epoch 2/10
# 3181/3181 - 86s - loss: 0.0060 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4855 - Customers_mse: 0.0018 - Customers_rmspe: 0.4813 - val_loss: 0.0137 - val_Sales_loss: 0.0054 - val_Customers_loss: 0.0081 - val_Sales_mse: 0.0054 - val_Sales_rmspe: 0.4821 - val_Customers_mse: 0.0081 - val_Customers_rmspe: 0.7790
#
# Epoch 00002: val_Sales_mse improved from 0.00555 to 0.00536, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-7.hdf5
# Epoch 3/10
# 3181/3181 - 85s - loss: 0.0059 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4805 - Customers_mse: 0.0018 - Customers_rmspe: 0.4761 - val_loss: 0.0169 - val_Sales_loss: 0.0059 - val_Customers_loss: 0.0108 - val_Sales_mse: 0.0059 - val_Sales_rmspe: 0.5153 - val_Customers_mse: 0.0108 - val_Customers_rmspe: 0.9127
#
# Epoch 00003: val_Sales_mse did not improve from 0.00536
# Epoch 4/10
# 3181/3181 - 85s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4780 - Customers_mse: 0.0018 - Customers_rmspe: 0.4718 - val_loss: 0.0163 - val_Sales_loss: 0.0069 - val_Customers_loss: 0.0092 - val_Sales_mse: 0.0069 - val_Sales_rmspe: 0.5617 - val_Customers_mse: 0.0092 - val_Customers_rmspe: 0.8159
#
# Epoch 00004: val_Sales_mse did not improve from 0.00536
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0137 - Sales_loss: 0.0054 - Customers_loss: 0.0081 - Sales_mse: 0.0054 - Sales_rmspe: 0.4704 - Customers_mse: 0.0081 - Customers_rmspe: 0.7682
# Cont vars chosen: ['Precipitationmm', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'AfterPromo', 'Min_TemperatureC', 'Mean_TemperatureC', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'CompetitionDistance', 'trend', 'Min_Humidity', 'AfterSchoolHoliday', 'trend_DE', 'BeforeStateHoliday_bool']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 8
# Epoch 1/10
# 3181/3181 - 86s - loss: 0.0161 - Sales_loss: 0.0041 - Customers_loss: 0.0019 - Sales_mse: 0.0041 - Sales_rmspe: 0.5008 - Customers_mse: 0.0019 - Customers_rmspe: 0.4883 - val_loss: 0.0127 - val_Sales_loss: 0.0053 - val_Customers_loss: 0.0070 - val_Sales_mse: 0.0053 - val_Sales_rmspe: 0.4978 - val_Customers_mse: 0.0070 - val_Customers_rmspe: 0.7472
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00530, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-8.hdf5
# Epoch 2/10
# 3181/3181 - 83s - loss: 0.0059 - Sales_loss: 0.0038 - Customers_loss: 0.0017 - Sales_mse: 0.0038 - Sales_rmspe: 0.4848 - Customers_mse: 0.0017 - Customers_rmspe: 0.4745 - val_loss: 0.0118 - val_Sales_loss: 0.0051 - val_Customers_loss: 0.0064 - val_Sales_mse: 0.0051 - val_Sales_rmspe: 0.4711 - val_Customers_mse: 0.0064 - val_Customers_rmspe: 0.6882
#
# Epoch 00002: val_Sales_mse improved from 0.00530 to 0.00512, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel1-8.hdf5
# Epoch 3/10
# 3181/3181 - 84s - loss: 0.0057 - Sales_loss: 0.0038 - Customers_loss: 0.0017 - Sales_mse: 0.0038 - Sales_rmspe: 0.4818 - Customers_mse: 0.0017 - Customers_rmspe: 0.4722 - val_loss: 0.0150 - val_Sales_loss: 0.0066 - val_Customers_loss: 0.0082 - val_Sales_mse: 0.0066 - val_Sales_rmspe: 0.5258 - val_Customers_mse: 0.0082 - val_Customers_rmspe: 0.7870
#
# Epoch 00003: val_Sales_mse did not improve from 0.00512
# Epoch 4/10
# 3181/3181 - 83s - loss: 0.0057 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4792 - Customers_mse: 0.0017 - Customers_rmspe: 0.4703 - val_loss: 0.0141 - val_Sales_loss: 0.0059 - val_Customers_loss: 0.0079 - val_Sales_mse: 0.0059 - val_Sales_rmspe: 0.5402 - val_Customers_mse: 0.0079 - val_Customers_rmspe: 0.8051
#
# Epoch 00004: val_Sales_mse did not improve from 0.00512
# Epoch 5/10
# 3181/3181 - 83s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4777 - Customers_mse: 0.0016 - Customers_rmspe: 0.4673 - val_loss: 0.0144 - val_Sales_loss: 0.0060 - val_Customers_loss: 0.0081 - val_Sales_mse: 0.0060 - val_Sales_rmspe: 0.5096 - val_Customers_mse: 0.0081 - val_Customers_rmspe: 0.7808
#
# Epoch 00005: val_Sales_mse did not improve from 0.00512
# Epoch 6/10
# 3181/3181 - 82s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4754 - Customers_mse: 0.0016 - Customers_rmspe: 0.4653 - val_loss: 0.0125 - val_Sales_loss: 0.0057 - val_Customers_loss: 0.0065 - val_Sales_mse: 0.0057 - val_Sales_rmspe: 0.5106 - val_Customers_mse: 0.0065 - val_Customers_rmspe: 0.7328
#
# Epoch 00006: val_Sales_mse did not improve from 0.00512
# Epoch 7/10
# 3181/3181 - 81s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4744 - Customers_mse: 0.0016 - Customers_rmspe: 0.4640 - val_loss: 0.0178 - val_Sales_loss: 0.0084 - val_Customers_loss: 0.0091 - val_Sales_mse: 0.0084 - val_Sales_rmspe: 0.5854 - val_Customers_mse: 0.0091 - val_Customers_rmspe: 0.8204
#
# Epoch 00007: val_Sales_mse did not improve from 0.00512
# Epoch 8/10
# 3181/3181 - 83s - loss: 0.0055 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4737 - Customers_mse: 0.0016 - Customers_rmspe: 0.4643 - val_loss: 0.0138 - val_Sales_loss: 0.0064 - val_Customers_loss: 0.0072 - val_Sales_mse: 0.0064 - val_Sales_rmspe: 0.5149 - val_Customers_mse: 0.0072 - val_Customers_rmspe: 0.7344
#
# Epoch 00008: val_Sales_mse did not improve from 0.00512
# Epoch 9/10
# 3181/3181 - 82s - loss: 0.0055 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4730 - Customers_mse: 0.0016 - Customers_rmspe: 0.4639 - val_loss: 0.0166 - val_Sales_loss: 0.0076 - val_Customers_loss: 0.0088 - val_Sales_mse: 0.0076 - val_Sales_rmspe: 0.5649 - val_Customers_mse: 0.0088 - val_Customers_rmspe: 0.8493
#
# Epoch 00009: val_Sales_mse did not improve from 0.00512
# Epoch 10/10
# 3181/3181 - 83s - loss: 0.0055 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4725 - Customers_mse: 0.0016 - Customers_rmspe: 0.4635 - val_loss: 0.0131 - val_Sales_loss: 0.0056 - val_Customers_loss: 0.0073 - val_Sales_mse: 0.0056 - val_Sales_rmspe: 0.4780 - val_Customers_mse: 0.0073 - val_Customers_rmspe: 0.7833
#
# Epoch 00010: val_Sales_mse did not improve from 0.00512
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0118 - Sales_loss: 0.0051 - Customers_loss: 0.0064 - Sales_mse: 0.0051 - Sales_rmspe: 0.4585 - Customers_mse: 0.0064 - Customers_rmspe: 0.6749
