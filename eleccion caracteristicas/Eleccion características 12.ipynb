# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=44f4ce34b30a776840f3cbf57fcd34be44972afec9535ce8d875eb268f7d4b30
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 1103

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion12.csv")
# Out:
# Cat vars chosen: ['Promo_bw', 'Day', 'SchoolHoliday', 'Events', 'State', 'StoreType', 'Promo2Weeks', 'Close_bool_bw', 'PromoInterval', 'SchoolHoliday_fw', 'Promo2SinceWeek', 'SchoolHoliday_bw', 'Promo2', 'Week', 'CompetitionMonthsOpen', 'StateHoliday', 'Promo_fw', 'Month', 'Promo', 'CompetitionOpenSinceYear', 'StateHoliday_bool_fw']
# Cont vars chosen: ['CloudCover', 'AfterClose_bool', 'BeforeClose_bool', 'BeforeSchoolHoliday', 'AfterStateHoliday_bool', 'Precipitationmm', 'Mean_TemperatureC', 'BeforePromo', 'Mean_Humidity', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 87s - loss: 0.0124 - Sales_loss: 0.0041 - Customers_loss: 0.0020 - Sales_mse: 0.0041 - Sales_rmspe: 0.4987 - Customers_mse: 0.0020 - Customers_rmspe: 0.4990 - val_loss: 0.0056 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0016 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.3980 - val_Customers_mse: 0.0016 - val_Customers_rmspe: 0.4213
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00372, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 85s - loss: 0.0053 - Sales_loss: 0.0035 - Customers_loss: 0.0016 - Sales_mse: 0.0035 - Sales_rmspe: 0.4561 - Customers_mse: 0.0016 - Customers_rmspe: 0.4582 - val_loss: 0.0050 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.4108 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4543
#
# Epoch 00008: val_Sales_mse improved from 0.00340 to 0.00335, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-0.hdf5
# Epoch 9/10
# 3181/3181 - 84s - loss: 0.0052 - Sales_loss: 0.0035 - Customers_loss: 0.0016 - Sales_mse: 0.0035 - Sales_rmspe: 0.4546 - Customers_mse: 0.0016 - Customers_rmspe: 0.4582 - val_loss: 0.0050 - val_Sales_loss: 0.0033 - val_Customers_loss: 0.0015 - val_Sales_mse: 0.0033 - val_Sales_rmspe: 0.4049 - val_Customers_mse: 0.0015 - val_Customers_rmspe: 0.4589
#
# Epoch 00009: val_Sales_mse improved from 0.00335 to 0.00334, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-0.hdf5
# Epoch 10/10
# 3181/3181 - 84s - loss: 0.0052 - Sales_loss: 0.0034 - Customers_loss: 0.0016 - Sales_mse: 0.0034 - Sales_rmspe: 0.4525 - Customers_mse: 0.0016 - Customers_rmspe: 0.4573 - val_loss: 0.0050 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.3857 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4073
#
# Epoch 00010: val_Sales_mse did not improve from 0.00334
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0050 - Sales_loss: 0.0033 - Customers_loss: 0.0015 - Sales_mse: 0.0033 - Sales_rmspe: 0.3925 - Customers_mse: 0.0015 - Customers_rmspe: 0.4466
# Cont vars chosen: ['Mean_TemperatureC', 'BeforeSchoolHoliday', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'Precipitationmm', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'trend_DE', 'Min_Humidity', 'CloudCover', 'CompetitionDistance', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 1
# Epoch 1/10
# 3181/3181 - 87s - loss: 0.0212 - Sales_loss: 0.0038 - Customers_loss: 0.0017 - Sales_mse: 0.0038 - Sales_rmspe: 0.4505 - Customers_mse: 0.0017 - Customers_rmspe: 0.4540 - val_loss: 0.0053 - val_Sales_loss: 0.0034 - val_Customers_loss: 0.0014 - val_Sales_mse: 0.0034 - val_Sales_rmspe: 0.4488 - val_Customers_mse: 0.0014 - val_Customers_rmspe: 0.4520
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00339, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
# 3181/3181 - 83s - loss: 0.0044 - Sales_loss: 0.0027 - Customers_loss: 0.0012 - Sales_mse: 0.0027 - Sales_rmspe: 0.3798 - Customers_mse: 0.0012 - Customers_rmspe: 0.3758 - val_loss: 0.0043 - val_Sales_loss: 0.0027 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0027 - val_Sales_rmspe: 0.3163 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3339
#
# Epoch 00008: val_Sales_mse did not improve from 0.00269
# Epoch 9/10
# 3181/3181 - 83s - loss: 0.0043 - Sales_loss: 0.0027 - Customers_loss: 0.0012 - Sales_mse: 0.0027 - Sales_rmspe: 0.3782 - Customers_mse: 0.0012 - Customers_rmspe: 0.3741 - val_loss: 0.0041 - val_Sales_loss: 0.0025 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0025 - val_Sales_rmspe: 0.3586 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.4022
#
# Epoch 00009: val_Sales_mse improved from 0.00269 to 0.00253, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-1.hdf5
# Epoch 10/10
# 3181/3181 - 83s - loss: 0.0043 - Sales_loss: 0.0027 - Customers_loss: 0.0012 - Sales_mse: 0.0027 - Sales_rmspe: 0.3766 - Customers_mse: 0.0012 - Customers_rmspe: 0.3719 - val_loss: 0.0043 - val_Sales_loss: 0.0027 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0027 - val_Sales_rmspe: 0.3085 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3332
#
# Epoch 00010: val_Sales_mse did not improve from 0.00253
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0041 - Sales_loss: 0.0025 - Customers_loss: 0.0011 - Sales_mse: 0.0025 - Sales_rmspe: 0.3476 - Customers_mse: 0.0011 - Customers_rmspe: 0.3910
# Cont vars chosen: ['Max_Humidity', 'AfterPromo', 'BeforeSchoolHoliday', 'CompetitionDistance', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'trend', 'Mean_Humidity', 'Max_TemperatureC', 'Precipitationmm', 'AfterClose_bool', 'BeforePromo', 'trend_DE', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Creamos el modelo 2
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 2
# Epoch 1/10
# 3181/3181 - 88s - loss: 0.0179 - Sales_loss: 0.0032 - Customers_loss: 0.0016 - Sales_mse: 0.0032 - Sales_rmspe: 0.4172 - Customers_mse: 0.0016 - Customers_rmspe: 0.4208 - val_loss: 0.0047 - val_Sales_loss: 0.0028 - val_Customers_loss: 0.0013 - val_Sales_mse: 0.0028 - val_Sales_rmspe: 0.3611 - val_Customers_mse: 0.0013 - val_Customers_rmspe: 0.4374
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00282, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-2.hdf5
# Epoch 8/10
# 3181/3181 - 85s - loss: 0.0042 - Sales_loss: 0.0025 - Customers_loss: 0.0011 - Sales_mse: 0.0025 - Sales_rmspe: 0.3658 - Customers_mse: 0.0011 - Customers_rmspe: 0.3643 - val_loss: 0.0041 - val_Sales_loss: 0.0025 - val_Customers_loss: 0.0011 - val_Sales_mse: 0.0025 - val_Sales_rmspe: 0.3536 - val_Customers_mse: 0.0011 - val_Customers_rmspe: 0.3945
#
# Epoch 00008: val_Sales_mse did not improve from 0.00246
# Epoch 9/10
# 3181/3181 - 85s - loss: 0.0042 - Sales_loss: 0.0025 - Customers_loss: 0.0011 - Sales_mse: 0.0025 - Sales_rmspe: 0.3641 - Customers_mse: 0.0011 - Customers_rmspe: 0.3625 - val_loss: 0.0040 - val_Sales_loss: 0.0025 - val_Customers_loss: 0.0010 - val_Sales_mse: 0.0025 - val_Sales_rmspe: 0.3047 - val_Customers_mse: 0.0010 - val_Customers_rmspe: 0.3337
#
# Epoch 00009: val_Sales_mse did not improve from 0.00246
# Epoch 10/10
# 3181/3181 - 85s - loss: 0.0041 - Sales_loss: 0.0025 - Customers_loss: 0.0011 - Sales_mse: 0.0025 - Sales_rmspe: 0.3636 - Customers_mse: 0.0011 - Customers_rmspe: 0.3624 - val_loss: 0.0040 - val_Sales_loss: 0.0025 - val_Customers_loss: 0.0010 - val_Sales_mse: 0.0025 - val_Sales_rmspe: 0.3109 - val_Customers_mse: 0.0010 - val_Customers_rmspe: 0.3371
#
# Epoch 00010: val_Sales_mse improved from 0.00246 to 0.00245, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-2.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0040 - Sales_loss: 0.0025 - Customers_loss: 0.0010 - Sales_mse: 0.0025 - Sales_rmspe: 0.3007 - Customers_mse: 0.0010 - Customers_rmspe: 0.3259
# Cat vars chosen: ['CompetitionMonthsOpen', 'CompetitionOpenSinceYear', 'Assortment', 'DayOfWeek', 'Year', 'SchoolHoliday', 'Week', 'StateHoliday_bool_bw', 'Promo', 'Month', 'Promo2SinceWeek', 'SchoolHoliday_bw', 'Store', 'StateHoliday', 'Promo2', 'Events', 'Day', 'StateHoliday_bool_fw', 'State', 'Promo2Weeks']
# Cont vars chosen: ['CloudCover', 'AfterClose_bool', 'BeforeClose_bool', 'BeforeSchoolHoliday', 'AfterStateHoliday_bool', 'Precipitationmm', 'Mean_TemperatureC', 'BeforePromo', 'Mean_Humidity', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 94s - loss: 0.0091 - Sales_loss: 0.0013 - Customers_loss: 6.6072e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2712 - Customers_mse: 6.6072e-04 - Customers_rmspe: 0.2762 - val_loss: 0.0015 - val_Sales_loss: 9.2477e-04 - val_Customers_loss: 2.9127e-04 - val_Sales_mse: 9.2477e-04 - val_Sales_rmspe: 0.1809 - val_Customers_mse: 2.9127e-04 - val_Customers_rmspe: 0.1751
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
# 3181/3181 - 91s - loss: 9.0075e-04 - Sales_loss: 5.6847e-04 - Customers_loss: 1.9155e-04 - Sales_mse: 5.6847e-04 - Sales_rmspe: 0.1742 - Customers_mse: 1.9155e-04 - Customers_rmspe: 0.1551 - val_loss: 0.0010 - val_Sales_loss: 6.8170e-04 - val_Customers_loss: 2.0160e-04 - val_Sales_mse: 6.8170e-04 - val_Sales_rmspe: 0.1551 - val_Customers_mse: 2.0160e-04 - val_Customers_rmspe: 0.1304
#
# Epoch 00007: val_Sales_mse did not improve from 0.00067
# Epoch 8/10
# 3181/3181 - 90s - loss: 8.8234e-04 - Sales_loss: 5.5963e-04 - Customers_loss: 1.8880e-04 - Sales_mse: 5.5963e-04 - Sales_rmspe: 0.1731 - Customers_mse: 1.8880e-04 - Customers_rmspe: 0.1542 - val_loss: 9.5500e-04 - val_Sales_loss: 6.1448e-04 - val_Customers_loss: 2.0987e-04 - val_Sales_mse: 6.1448e-04 - val_Sales_rmspe: 0.1465 - val_Customers_mse: 2.0987e-04 - val_Customers_rmspe: 0.1334
#
# Epoch 00008: val_Sales_mse improved from 0.00067 to 0.00061, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-3.hdf5
# Epoch 9/10
# 3181/3181 - 90s - loss: 8.7103e-04 - Sales_loss: 5.5397e-04 - Customers_loss: 1.8708e-04 - Sales_mse: 5.5397e-04 - Sales_rmspe: 0.1733 - Customers_mse: 1.8708e-04 - Customers_rmspe: 0.1546 - val_loss: 0.0010 - val_Sales_loss: 6.7222e-04 - val_Customers_loss: 2.1560e-04 - val_Sales_mse: 6.7222e-04 - val_Sales_rmspe: 0.1570 - val_Customers_mse: 2.1560e-04 - val_Customers_rmspe: 0.1388
#
# Epoch 00009: val_Sales_mse did not improve from 0.00061
# Epoch 10/10
# 3181/3181 - 90s - loss: 8.6125e-04 - Sales_loss: 5.4967e-04 - Customers_loss: 1.8603e-04 - Sales_mse: 5.4967e-04 - Sales_rmspe: 0.1724 - Customers_mse: 1.8603e-04 - Customers_rmspe: 0.1540 - val_loss: 0.0010 - val_Sales_loss: 6.5712e-04 - val_Customers_loss: 2.2543e-04 - val_Sales_mse: 6.5712e-04 - val_Sales_rmspe: 0.1512 - val_Customers_mse: 2.2543e-04 - val_Customers_rmspe: 0.1408
#
# Epoch 00010: val_Sales_mse did not improve from 0.00061
# Obtenemos las métricas
# 944/944 [==============================] - 6s 5ms/step - loss: 9.5500e-04 - Sales_loss: 6.1448e-04 - Customers_loss: 2.0987e-04 - Sales_mse: 6.1448e-04 - Sales_rmspe: 0.1419 - Customers_mse: 2.0987e-04 - Customers_rmspe: 0.1297
# Cont vars chosen: ['Mean_TemperatureC', 'BeforeSchoolHoliday', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'Precipitationmm', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'trend_DE', 'Min_Humidity', 'CloudCover', 'CompetitionDistance', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionMonthsOpen_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
#
# Epoch 00010: val_Sales_mse did not improve from 0.00056
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 9.4535e-04 - Sales_loss: 5.6160e-04 - Customers_loss: 2.0300e-04 - Sales_mse: 5.6160e-04 - Sales_rmspe: 0.1363 - Customers_mse: 2.0300e-04 - Customers_rmspe: 0.1354
# Cat vars chosen: ['StateHoliday_bool_bw', 'Promo2SinceYear', 'Promo', 'State', 'SchoolHoliday_fw', 'Store', 'SchoolHoliday_bw', 'Week', 'DayOfWeek', 'StoreType', 'Month']
# Cont vars chosen: ['CloudCover', 'AfterClose_bool', 'BeforeClose_bool', 'BeforeSchoolHoliday', 'AfterStateHoliday_bool', 'Precipitationmm', 'Mean_TemperatureC', 'BeforePromo', 'Mean_Humidity', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 6
# Epoch 1/10
# 3181/3181 - 85s - loss: 0.0086 - Sales_loss: 0.0013 - Customers_loss: 5.5943e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2712 - Customers_mse: 5.5943e-04 - Customers_rmspe: 0.2671 - val_loss: 0.0016 - val_Sales_loss: 9.8633e-04 - val_Customers_loss: 3.8970e-04 - val_Sales_mse: 9.8633e-04 - val_Sales_rmspe: 0.2037 - val_Customers_mse: 3.8970e-04 - val_Customers_rmspe: 0.2293
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00099, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-6.hdf5
# Epoch 2/10
# 3181/3181 - 83s - loss: 0.0014 - Sales_loss: 8.8304e-04 - Customers_loss: 2.9736e-04 - Sales_mse: 8.8304e-04 - Sales_rmspe: 0.2241 - Customers_mse: 2.9736e-04 - Customers_rmspe: 0.2070 - val_loss: 0.0013 - val_Sales_loss: 7.2633e-04 - val_Customers_loss: 2.8228e-04 - val_Sales_mse: 7.2633e-04 - val_Sales_rmspe: 0.1614 - val_Customers_mse: 2.8228e-04 - val_Customers_rmspe: 0.1647
#
# Epoch 00002: val_Sales_mse improved from 0.00099 to 0.00073, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-6.hdf5
# Epoch 3/10
# ...
# Epoch 6/10
# 3181/3181 - 83s - loss: 9.9826e-04 - Sales_loss: 6.3238e-04 - Customers_loss: 2.0904e-04 - Sales_mse: 6.3238e-04 - Sales_rmspe: 0.1820 - Customers_mse: 2.0904e-04 - Customers_rmspe: 0.1623 - val_loss: 0.0011 - val_Sales_loss: 7.0905e-04 - val_Customers_loss: 2.4962e-04 - val_Sales_mse: 7.0905e-04 - val_Sales_rmspe: 0.1537 - val_Customers_mse: 2.4962e-04 - val_Customers_rmspe: 0.1596
#
# Epoch 00006: val_Sales_mse did not improve from 0.00070
# Epoch 7/10
# 3181/3181 - 82s - loss: 9.7819e-04 - Sales_loss: 6.2526e-04 - Customers_loss: 2.0681e-04 - Sales_mse: 6.2526e-04 - Sales_rmspe: 0.1804 - Customers_mse: 2.0681e-04 - Customers_rmspe: 0.1608 - val_loss: 0.0011 - val_Sales_loss: 6.8949e-04 - val_Customers_loss: 2.2890e-04 - val_Sales_mse: 6.8949e-04 - val_Sales_rmspe: 0.1526 - val_Customers_mse: 2.2890e-04 - val_Customers_rmspe: 0.1460
#
# Epoch 00007: val_Sales_mse improved from 0.00070 to 0.00069, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-6.hdf5
# Epoch 8/10
# 3181/3181 - 83s - loss: 9.6326e-04 - Sales_loss: 6.1871e-04 - Customers_loss: 2.0408e-04 - Sales_mse: 6.1871e-04 - Sales_rmspe: 0.1776 - Customers_mse: 2.0408e-04 - Customers_rmspe: 0.1583 - val_loss: 0.0012 - val_Sales_loss: 7.6878e-04 - val_Customers_loss: 2.8558e-04 - val_Sales_mse: 7.6878e-04 - val_Sales_rmspe: 0.1583 - val_Customers_mse: 2.8558e-04 - val_Customers_rmspe: 0.1639
#
# Epoch 00008: val_Sales_mse did not improve from 0.00069
# Epoch 9/10
# 3181/3181 - 83s - loss: 9.4502e-04 - Sales_loss: 6.0830e-04 - Customers_loss: 2.0138e-04 - Sales_mse: 6.0830e-04 - Sales_rmspe: 0.1755 - Customers_mse: 2.0138e-04 - Customers_rmspe: 0.1560 - val_loss: 0.0012 - val_Sales_loss: 7.2273e-04 - val_Customers_loss: 3.1614e-04 - val_Sales_mse: 7.2273e-04 - val_Sales_rmspe: 0.1589 - val_Customers_mse: 3.1614e-04 - val_Customers_rmspe: 0.1790
#
# Epoch 00009: val_Sales_mse did not improve from 0.00069
# Epoch 10/10
# 3181/3181 - 83s - loss: 9.3249e-04 - Sales_loss: 6.0188e-04 - Customers_loss: 1.9805e-04 - Sales_mse: 6.0188e-04 - Sales_rmspe: 0.1735 - Customers_mse: 1.9805e-04 - Customers_rmspe: 0.1539 - val_loss: 0.0011 - val_Sales_loss: 6.8048e-04 - val_Customers_loss: 3.0130e-04 - val_Sales_mse: 6.8048e-04 - val_Sales_rmspe: 0.1516 - val_Customers_mse: 3.0130e-04 - val_Customers_rmspe: 0.1724
#
# Epoch 00010: val_Sales_mse improved from 0.00069 to 0.00068, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel12-6.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0011 - Sales_loss: 6.8048e-04 - Customers_loss: 3.0130e-04 - Sales_mse: 6.8048e-04 - Sales_rmspe: 0.1478 - Customers_mse: 3.0130e-04 - Customers_rmspe: 0.1694
# Cont vars chosen: ['Mean_TemperatureC', 'BeforeSchoolHoliday', 'AfterSchoolHoliday', 'BeforeStateHoliday_bool', 'Precipitationmm', 'AfterStateHoliday_bool', 'Max_TemperatureC', 'trend_DE', 'Min_Humidity', 'CloudCover', 'CompetitionDistance', 'Mean_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 85s - loss: 0.0158 - Sales_loss: 0.0010 - Customers_loss: 2.8642e-04 - Sales_mse: 0.0010 - Sales_rmspe: 0.1944 - Customers_mse: 2.8642e-04 - Customers_rmspe: 0.1762 - val_loss: 0.0016 - val_Sales_loss: 8.6474e-04 - val_Customers_loss: 3.8921e-04 - val_Sales_mse: 8.6474e-04 - val_Sales_rmspe: 0.1685 - val_Customers_mse: 3.8921e-04 - val_Customers_rmspe: 0.1708
#
# Epoch 00001: val_Sales_mse improved from inf to 0.
#
# Epoch 00006: val_Sales_mse did not improve from 0.00066
# Epoch 7/10
# 3181/3181 - 83s - loss: 9.0712e-04 - Sales_loss: 5.7466e-04 - Customers_loss: 1.9275e-04 - Sales_mse: 5.7466e-04 - Sales_rmspe: 0.1689 - Customers_mse: 1.9275e-04 - Customers_rmspe: 0.1490 - val_loss: 0.0011 - val_Sales_loss: 7.0646e-04 - val_Customers_loss: 2.2258e-04 - val_Sales_mse: 7.0646e-04 - val_Sales_rmspe: 0.1483 - val_Customers_mse: 2.2258e-04 - val_Customers_rmspe: 0.1312
#
# Epoch 00007: val_Sales_mse did not improve from 0.00066
# Epoch 8/10
# 3181/3181 - 82s - loss: 9.0282e-04 - Sales_loss: 5.7407e-04 - Customers_loss: 1.9347e-04 - Sales_mse: 5.7407e-04 - Sales_rmspe: 0.1688 - Customers_mse: 1.9347e-04 - Customers_rmspe: 0.1495 - val_loss: 0.0010 - val_Sales_loss: 6.8275e-04 - val_Customers_loss: 2.2130e-04 - val_Sales_mse: 6.8275e-04 - val_Sales_rmspe: 0.1450 - val_Customers_mse: 2.2130e-04 - val_Customers_rmspe: 0.1274
#
# Epoch 00008: val_Sales_mse did not improve from 0.00066
# Epoch 9/10
# 3181/3181 - 83s - loss: 8.9384e-04 - Sales_loss: 5.6997e-04 - Customers_loss: 1.9180e-04 - Sales_mse: 5.6997e-04 - Sales_rmspe: 0.1677 - Customers_mse: 1.9180e-04 - Customers_rmspe: 0.1488 - val_loss: 0.0012 - val_Sales_loss: 7.9565e-04 - val_Customers_loss: 2.4102e-04 - val_Sales_mse: 7.9565e-04 - val_Sales_rmspe: 0.1579 - val_Customers_mse: 2.4102e-04 - val_Customers_rmspe: 0.1354
#
# Epoch 00009: val_Sales_mse did not improve from 0.00066
# Epoch 10/10
# 3181/3181 - 83s - loss: 8.8885e-04 - Sales_loss: 5.6891e-04 - Customers_loss: 1.9200e-04 - Sales_mse: 5.6891e-04 - Sales_rmspe: 0.1674 - Customers_mse: 1.9200e-04 - Customers_rmspe: 0.1485 - val_loss: 0.0012 - val_Sales_loss: 7.8726e-04 - val_Customers_loss: 2.6829e-04 - val_Sales_mse: 7.8726e-04 - val_Sales_rmspe: 0.1731 - val_Customers_mse: 2.6829e-04 - val_Customers_rmspe: 0.1401
#
# Epoch 00010: val_Sales_mse did not improve from 0.00066
# Obtenemos las métricas
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0010 - Sales_loss: 6.6317e-04 - Customers_loss: 2.1547e-04 - Sales_mse: 6.6317e-04 - Sales_rmspe: 0.1430 - Customers_mse: 2.1547e-04 - Customers_rmspe: 0.1291
# Cont vars chosen: ['Max_Humidity', 'AfterPromo', 'BeforeSchoolHoliday', 'CompetitionDistance', 'StateHoliday_bool', 'Mean_Wind_SpeedKm_h', 'trend', 'Mean_Humidity', 'Max_TemperatureC', 'Precipitationmm', 'AfterClose_bool', 'BeforePromo', 'trend_DE', 'Max_Wind_SpeedKm_h']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 