# %% [markdown]
# #Conectamos a google drive e importamos librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from random import sample

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.models import load_model

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes neuronales/TP2"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)
# /gdrive/Shareddrives/Redes neuronales/TP2
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=96a29fd7d0218bb9ff64d0711fdc454896a246d4b5245d3af66ab136944de371
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# importing Jupyter notebook from Helper.ipynb
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.19.5)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.0.1)

# %% [markdown]
# # Se cargan los archivos preprocesados

# %%
df = pd.read_feather('data preprecesada/train_normalized_data_!sales0.fth')
df_test = pd.read_feather('data preprecesada/test_normalized_data.fth')

# %%
len(df.columns)
# Out:
# 89

# %%
df.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'Close_bool', 'AfterSchoolHoliday',
#        'BeforeSchoolHoliday', 'AfterStateHoliday_bool',
#        'BeforeStateHoliday_bool', 'AfterPromo', 'BeforePromo',
#        'AfterClose_bool', 'BeforeClose_bool', 'SchoolHoliday_bw',
#        'StateHoliday_bool_bw', 'Promo_bw', 'Close_bool_bw', 'SchoolHoliday_fw',
#        'StateHoliday_bool_fw', 'Promo_fw', 'Close_bool_fw', 'mean_by_store',
#        'Sales_store'],
#       dtype='object')

# %% [markdown]
# # Listamos las variables

# %% [markdown]
# ##Variables categóricas

# %%
 cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day',
             'StateHoliday', 'SchoolHoliday', 'Promo2SinceWeek',
             'CompetitionMonthsOpen', 'Promo2Weeks', 'Promo2',
             'StoreType', 'Assortment', 'PromoInterval', 
             'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 'Week',
              'Promo', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw',
             'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw',
             'Close_bool_bw','Close_bool_fw']

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %% [markdown]
# ## Variables continuas

# %%
contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 
               'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool',
    'AfterPromo','BeforePromo',
   'StateHoliday_bool','AfterSchoolHoliday','BeforeSchoolHoliday',
   'AfterClose_bool','BeforeClose_bool']

# %%
len(contin_vars)+len(cat_vars)
# Out:
# 50

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques
# Out:
#         Store DayOfWeek Year  ... SchoolHoliday_bw Close_bool_bw Close_bool_fw
# uniques  1115         7    3  ...                8             7             7
#
# [1 rows x 28 columns]

# %% [markdown]
# # Corremos los modelos

# %% [markdown]
# ##Asignación de embeddings

# %%
np.unique(df['Promo'])
# Out:
# array([0, 1])

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 3,'Promo':2, 'Year': 3, 'Month': 4,
'Day': 10, 'StateHoliday': 3,'SchoolHoliday':2, 'Promo2SinceWeek': 3,
'CompetitionMonthsOpen': 4, 'Promo2Weeks': 3,  'Promo2':2, 'StoreType': 2,
 'Assortment': 3, 'PromoInterval': 3,'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 
 'State': 4, 'Events': 7, 'Promo_fw': 4,'Promo_bw': 4, 'Week':10,
 'StateHoliday_bool_fw': 2, 'StateHoliday_bool_bw': 2, 'SchoolHoliday_fw': 2,
'SchoolHoliday_bw': 2,'Close_bool_bw':3,'Close_bool_fw':3}

# %%
chosen =['Store','Day']
values_chosen = [cat_var_dict[i] for i in chosen]
dictionary = dict(zip(chosen,values_chosen))
dictionary
# Out:
# {'Day': 10, 'Store': 50}

# %%
len(np.unique(df['Store']))
# Out:
# 1115

# %%
np.random.randint(1,2)
# Out:
# 1

# %%
np.random.randint(1,len(np.unique(df['Store'])))
# Out:
# 566

# %% [markdown]
# ##Modelo

# %%
# Parametros de entrada para creación de las capas ocultas:
cant_capas_ocultas = 2
cantidad_neuronas = [1000, 500]
l2_lambda = 1e-3
activation_function = ["relu","relu"]
alpha = [0, 0] # Se puede cambiar el valor de alpha en caso de usar función LeakyRelu.
# Recordar que el alpha tiene que ser un vector
kernel_initializer = "uniform"

# Parametros de entrada para creación modelo entero:
add_customers = True
output_activation = 'linear'

all_vars = cat_vars + contin_vars #variables elegidas

log_output = False

lr=0.001

metrics=['mse', rmspe]
loss='mse'
epochs = 10
batch_size = 256
verbose=2

df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]

# %% [markdown]
# Hacemos que le entren 10 características categóricas y 10 características continuas por lo menos.

# %%
cat_vars_random = [sample(cat_vars,np.random.randint(10,len(cat_vars))) for i in range(3)]

# %%
contin_vars_random = [sample(contin_vars,np.random.randint(10,len(contin_vars))) for i in range(3)]

# %%
res_metrics = pd.DataFrame(columns=['Cantidad de características','Caracteristicas modelo','Puntaje (Sales_rmspe)'])
for i in cat_vars_random:

  cat_vars_chosen = i

  print(f'Cat vars chosen: {cat_vars_chosen}')
  cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model2(cat_vars_chosen, uniques, cat_var_dict)

  for j in contin_vars_random:

    contin_vars_chosen = j 

    print(f'Cont vars chosen: {contin_vars_chosen}')
    cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars_chosen)

    print("Creamos los embeddings y layers")
    concatenate_layer = MLP_layers(cat_vars_embed_outs, cont_vars_inputs, l2_lambda, kernel_initializer, cant_capas_ocultas, cant_neuronas= cantidad_neuronas, activation_func= activation_function)
    print(concatenate_layer)

    print(f'Creamos el modelo {len(res_metrics)}')
    print(cat_var_inputs)
    model = crear_MLP(add_customers, cat_var_inputs, cont_vars_inputs, concatenate_layer, output_activation)

    all_vars = cat_vars_chosen + contin_vars_chosen

    print("Normalizamos el dataset")
    X_train,X_val,X_test,y_train,y_val,y_norm = obtener_x_y(df_train,df_val,df_test,all_vars,add_customers=add_customers,log_output=log_output)  

    model_chosen=f'modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-{len(res_metrics)}.hdf5'

    print(f'Entrenamos el modelo {len(res_metrics)}')
    history,model = entrenar_MLP(X_train,X_val,y_train,y_val,all_vars,model=model,add_customers=add_customers,log_output=log_output,lr=lr,metrics=metrics,loss=loss,model_chosen=model_chosen,epochs = epochs,batch_size = batch_size,verbose=verbose)  

    print("Obtenemos las métricas")
    metric_cross = metricas_MLP(X_val,y_val,model,model_chosen=model_chosen)    
    puntaje = metric_cross['Sales_rmspe']

    data_columns_df = dict(zip(res_metrics.columns,[len(all_vars),all_vars,puntaje]))
    res_metrics = res_metrics.append(data_columns_df,ignore_index=True)

res_metrics.to_csv("/gdrive/Shareddrives/Redes neuronales/TP2/eleccion caracteristicas/resultados/results_eleccion9.csv")
# Out:
# Cat vars chosen: ['Year', 'Store', 'Promo_fw', 'Assortment', 'StateHoliday', 'Close_bool_bw', 'Promo2SinceWeek', 'StateHoliday_bool_bw', 'Promo_bw', 'PromoInterval', 'Promo2SinceYear', 'State', 'Month', 'StateHoliday_bool_fw', 'SchoolHoliday', 'SchoolHoliday_fw', 'CompetitionOpenSinceYear', 'Close_bool_fw', 'DayOfWeek']
# Cont vars chosen: ['BeforePromo', 'Max_TemperatureC', 'Mean_TemperatureC', 'BeforeClose_bool', 'Mean_Humidity', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'AfterStateHoliday_bool', 'CloudCover', 'AfterPromo', 'CompetitionDistance', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Creamos el modelo 0
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 0
# Epoch 1/10
# 3181/3181 - 95s - loss: 0.0095 - Sales_loss: 0.0014 - Customers_loss: 5.6515e-04 - Sales_mse: 0.0014 - Sales_rmspe: 0.2787 - Customers_mse: 5.6515e-04 - Customers_rmspe: 0.2701 - val_loss: 0.0016 - val_Sales_loss: 9.3008e-04 - val_Customers_loss: 3.5701e-04 - val_Sales_mse: 9.3008e-04 - val_Sales_rmspe: 0.2138 - val_Customers_mse: 3.5701e-04 - val_Customers_rmspe: 0.2136
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00093, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmod
#
# Epoch 00007: val_Sales_mse did not improve from 0.00067
# Epoch 8/10
# 3181/3181 - 92s - loss: 0.0010 - Sales_loss: 6.7970e-04 - Customers_loss: 2.1361e-04 - Sales_mse: 6.7970e-04 - Sales_rmspe: 0.1804 - Customers_mse: 2.1361e-04 - Customers_rmspe: 0.1585 - val_loss: 0.0012 - val_Sales_loss: 6.8238e-04 - val_Customers_loss: 3.2127e-04 - val_Sales_mse: 6.8238e-04 - val_Sales_rmspe: 0.1497 - val_Customers_mse: 3.2127e-04 - val_Customers_rmspe: 0.1735
#
# Epoch 00008: val_Sales_mse did not improve from 0.00067
# Epoch 9/10
# 3181/3181 - 93s - loss: 0.0010 - Sales_loss: 6.7743e-04 - Customers_loss: 2.1284e-04 - Sales_mse: 6.7743e-04 - Sales_rmspe: 0.1796 - Customers_mse: 2.1284e-04 - Customers_rmspe: 0.1579 - val_loss: 0.0012 - val_Sales_loss: 7.8918e-04 - val_Customers_loss: 2.9101e-04 - val_Sales_mse: 7.8918e-04 - val_Sales_rmspe: 0.1753 - val_Customers_mse: 2.9101e-04 - val_Customers_rmspe: 0.1529
#
# Epoch 00009: val_Sales_mse did not improve from 0.00067
# Epoch 10/10
# 3181/3181 - 92s - loss: 0.0010 - Sales_loss: 6.7192e-04 - Customers_loss: 2.1201e-04 - Sales_mse: 6.7192e-04 - Sales_rmspe: 0.1787 - Customers_mse: 2.1201e-04 - Customers_rmspe: 0.1569 - val_loss: 0.0011 - val_Sales_loss: 6.7277e-04 - val_Customers_loss: 3.1526e-04 - val_Sales_mse: 6.7277e-04 - val_Sales_rmspe: 0.1516 - val_Customers_mse: 3.1526e-04 - val_Customers_rmspe: 0.1652
#
# Epoch 00010: val_Sales_mse did not improve from 0.00067
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0011 - Sales_loss: 6.6723e-04 - Customers_loss: 2.2070e-04 - Sales_mse: 6.6723e-04 - Sales_rmspe: 0.1458 - Customers_mse: 2.2070e-04 - Customers_rmspe: 0.1293
# Cont vars chosen: ['Min_TemperatureC', 'Precipitationmm', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'AfterClose_bool', 'CloudCover', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'trend', 'Mean_Humidity', 'Mean_TemperatureC', 'BeforeSchoolHoliday', 'Max_Humidity', 'CompetitionDistance', 'AfterPromo', 'trend_DE', 'BeforeClose_bool', 'Max_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Creamos el modelo 1
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Store_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Assortment_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Month_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>]
# Normalizamos el dataset
# Entrenamos el modelo
#
# Epoch 00006: val_Sales_mse did not improve from 0.00068
# Epoch 7/10
# 3181/3181 - 99s - loss: 0.0010 - Sales_loss: 6.6352e-04 - Customers_loss: 2.1095e-04 - Sales_mse: 6.6352e-04 - Sales_rmspe: 0.1798 - Customers_mse: 2.1095e-04 - Customers_rmspe: 0.1576 - val_loss: 0.0011 - val_Sales_loss: 6.6747e-04 - val_Customers_loss: 2.3535e-04 - val_Sales_mse: 6.6747e-04 - val_Sales_rmspe: 0.1485 - val_Customers_mse: 2.3535e-04 - val_Customers_rmspe: 0.1414
#
# Epoch 00007: val_Sales_mse improved from 0.00068 to 0.00067, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-1.hdf5
# Epoch 8/10
# 3181/3181 - 99s - loss: 0.0010 - Sales_loss: 6.5687e-04 - Customers_loss: 2.0903e-04 - Sales_mse: 6.5687e-04 - Sales_rmspe: 0.1793 - Customers_mse: 2.0903e-04 - Customers_rmspe: 0.1566 - val_loss: 0.0010 - val_Sales_loss: 6.7076e-04 - val_Customers_loss: 1.9546e-04 - val_Sales_mse: 6.7076e-04 - val_Sales_rmspe: 0.1496 - val_Customers_mse: 1.9546e-04 - val_Customers_rmspe: 0.1318
#
# Epoch 00008: val_Sales_mse did not improve from 0.00067
# Epoch 9/10
# 3181/3181 - 100s - loss: 0.0010 - Sales_loss: 6.5237e-04 - Customers_loss: 2.0773e-04 - Sales_mse: 6.5237e-04 - Sales_rmspe: 0.1783 - Customers_mse: 2.0773e-04 - Customers_rmspe: 0.1557 - val_loss: 0.0010 - val_Sales_loss: 6.8402e-04 - val_Customers_loss: 1.9795e-04 - val_Sales_mse: 6.8402e-04 - val_Sales_rmspe: 0.1426 - val_Customers_mse: 1.9795e-04 - val_Customers_rmspe: 0.1297
#
# Epoch 00009: val_Sales_mse did not improve from 0.00067
# Epoch 10/10
# 3181/3181 - 99s - loss: 0.0010 - Sales_loss: 6.4890e-04 - Customers_loss: 2.0633e-04 - Sales_mse: 6.4890e-04 - Sales_rmspe: 0.1777 - Customers_mse: 2.0633e-04 - Customers_rmspe: 0.1551 - val_loss: 0.0010 - val_Sales_loss: 6.7346e-04 - val_Customers_loss: 2.1855e-04 - val_Sales_mse: 6.7346e-04 - val_Sales_rmspe: 0.1463 - val_Customers_mse: 2.1855e-04 - val_Customers_rmspe: 0.1375
#
# Epoch 00010: val_Sales_mse did not improve from 0.00067
# Obtenemos las métricas
# 944/944 [==============================] - 7s 6ms/step - loss: 0.0011 - Sales_loss: 6.6747e-04 - Customers_loss: 2.3535e-04 - Sales_mse: 6.6747e-04 - Sales_rmspe: 0.1454 - Customers_mse: 2.3535e-04 - Customers_rmspe: 0.1389
# Cont vars chosen: ['trend_DE', 'Precipitationmm', 'CloudCover', 'AfterSchoolHoliday', 'BeforeSchoolHoliday', 'trend', 'AfterStateHoliday_bool', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'Mean_Humidity', 'Max_TemperatureC', 'BeforePromo', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'BeforeStateHoliday_bool', 'StateHoliday_bool', 'CompetitionDistance', 'AfterPromo', 'BeforeClose_bool', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation
# 944/944 [==============================] - 7s 6ms/step - loss: 9.5764e-04 - Sales_loss: 6.0859e-04 - Customers_loss: 2.0654e-04 - Sales_mse: 6.0859e-04 - Sales_rmspe: 0.1383 - Customers_mse: 2.0654e-04 - Customers_rmspe: 0.1254
# Cat vars chosen: ['Promo2SinceWeek', 'Close_bool_fw', 'State', 'StoreType', 'Week', 'DayOfWeek', 'StateHoliday_bool_bw', 'Promo_bw', 'SchoolHoliday_bw', 'Promo_fw', 'Events', 'StateHoliday']
# Cont vars chosen: ['BeforePromo', 'Max_TemperatureC', 'Mean_TemperatureC', 'BeforeClose_bool', 'Mean_Humidity', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'AfterStateHoliday_bool', 'CloudCover', 'AfterPromo', 'CompetitionDistance', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Creamos el modelo 3
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 3
# Epoch 1/10
# 3181/3181 - 88s - loss: 0.0130 - Sales_loss: 0.0042 - Customers_loss: 0.0020 - Sales_mse: 0.0042 - Sales_rmspe: 0.5020 - Customers_mse: 0.0020 - Customers_rmspe: 0.4940 - val_loss: 0.0066 - val_Sales_loss: 0.0042 - val_Customers_loss: 0.0021 - val_Sales_mse: 0.0042 - val_Sales_rmspe: 0.4501 - val_Customers_mse: 0.0021 - val_Customers_rmspe: 0.5104
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00418, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-3.hdf5
# Epoch 2/10
# 3181/3181 - 85s - loss: 0.0059 - Sales_loss: 0.0039 - Customers_loss: 0.0017 - Sales_mse: 0.0039 - Sales_rmspe: 0.4810 - Customers_mse: 0.0017 - Customers_rmspe: 0.4703 - val_loss: 0.0059 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4083 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4791
#
# Epoch 00002: val_Sales_mse improved from 0.00418 to 0.00377, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-3.hdf5
# Epoch 3/10
# 3181/3181 - 86s - loss: 0.0057 - Sales_loss: 0.0038 - Customers_loss: 0.0016 - Sales_mse: 0.0038 - Sales_rmspe: 0.4653 - Customers_mse: 0.0016 - Customers_rmspe: 0.4570 - val_loss: 0.0058 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.3978 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4950
#
# Epoch 00003: val_Sales_mse improved from 0.00377 to 0.00367, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-3.hdf5
# Epoch 4/10
# 3181/3181 - 86s - loss: 0.0055 - Sales_loss: 0.0037 - Customers_loss: 0.0016 - Sales_mse: 0.0037 - Sales_rmspe: 0.4474 - Customers_mse: 0.0016 - Customers_rmspe: 0.4383 - val_loss: 0.0058 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0018 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.3829 - val_Customers_mse: 0.0018 - val_Customers_rmspe: 0.4297
#
# Epoch 00004: val_Sales_mse did not improve from 0.00367
# Epoch 5/10
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0057 - Sales_loss: 0.0036 - Customers_loss: 0.0018 - Sales_mse: 0.0036 - Sales_rmspe: 0.3939 - Customers_mse: 0.0018 - Customers_rmspe: 0.4588
# Cont vars chosen: ['Min_TemperatureC', 'Precipitationmm', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'AfterClose_bool', 'CloudCover', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'trend', 'Mean_Humidity', 'Mean_TemperatureC', 'BeforeSchoolHoliday', 'Max_Humidity', 'CompetitionDistance', 'AfterPromo', 'trend_DE', 'BeforeClose_bool', 'Max_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_9/Relu:0', description="created by layer 'activation_9'")
# Creamos el modelo 4
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 4
# Epoch 1/10
# 3181/3181 - 91s - loss: 0.0182 - Sales_loss: 0.0040 - Customers_loss: 0.0018 - Sales_mse: 0.0040 - Sales_rmspe: 0.4625 - Customers_mse: 0.0018 - Customers_rmspe: 0.4553 - val_loss: 0.0068 - val_Sales_loss: 0.0040 - val_Customers_loss: 0.0024 - val_Sales_mse: 0.0040 - val_Sales_rmspe: 0.4638 - val_Customers_mse: 0.0024 - val_Customers_rmspe: 0.5568
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00403, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-4.hdf5
# Epoch 2/10
# 3181/3181 - 88s - loss: 0.0056 - Sales_loss: 0.0036 - Customers_loss: 0.0016 - Sales_mse: 0.0036 - Sales_rmspe: 0.4429 - Customers_mse: 0.0016 - Customers_rmspe: 0.4333 - val_loss: 0.0061 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0020 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4306 - val_Customers_mse: 0.0020 - val_Customers_rmspe: 0.4941
#
# Epoch 00002: val_Sales_mse improved from 0.00403 to 0.00374, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-4.hdf5
# Epoch 3/10
# 3181/3181 - 88s - loss: 0.0055 - Sales_loss: 0.0036 - Customers_loss: 0.0015 - Sales_mse: 0.0036 - Sales_rmspe: 0.4384 - Customers_mse: 0.0015 - Customers_rmspe: 0.4300 - val_loss: 0.0060 - val_Sales_loss: 0.0037 - val_Customers_loss: 0.0020 - val_Sales_mse: 0.0037 - val_Sales_rmspe: 0.4147 - val_Customers_mse: 0.0020 - val_Customers_rmspe: 0.5201
#
# Epoch 00003: val_Sales_mse improved from 0.00374 to 0.00370, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-4.hdf5
# Epoch 4/10
# 3181/3181 - 88s - loss: 0.0054 - Sales_loss: 0.0036 - Customers_loss: 0.0015 - Sales_mse: 0.0036 - Sales_rmspe: 0.4354 - Customers_mse: 0.0015 - Customers_rmspe: 0.4277 - val_loss: 0.0063 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0023 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4096 - val_Customers_mse: 0.0023 - val_Customers_rmspe: 0.5161
#
# Epoch 00004: val_Sales_mse did not improve from 0.00370
# Epoch 5/10
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0057 - Sales_loss: 0.0036 - Customers_loss: 0.0018 - Sales_mse: 0.0036 - Sales_rmspe: 0.3914 - Customers_mse: 0.0018 - Customers_rmspe: 0.4558
# Cont vars chosen: ['trend_DE', 'Precipitationmm', 'CloudCover', 'AfterSchoolHoliday', 'BeforeSchoolHoliday', 'trend', 'AfterStateHoliday_bool', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'Mean_Humidity', 'Max_TemperatureC', 'BeforePromo', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'BeforeStateHoliday_bool', 'StateHoliday_bool', 'CompetitionDistance', 'AfterPromo', 'BeforeClose_bool', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Creamos el modelo 5
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'State_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StoreType_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'DayOfWeek_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_bw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 5
# Epoch 1/10
# 3181/3181 - 91s - loss: 0.0214 - Sales_loss: 0.0040 - Customers_loss: 0.0018 - Sales_mse: 0.0040 - Sales_rmspe: 0.4511 - Customers_mse: 0.0018 - Customers_rmspe: 0.4520 - val_loss: 0.0070 - val_Sales_loss: 0.0041 - val_Customers_loss: 0.0025 - val_Sales_mse: 0.0041 - val_Sales_rmspe: 0.4549 - val_Customers_mse: 0.0025 - val_Customers_rmspe: 0.5278
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00411, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-5.hdf5
# Epoch 2/10
# 3181/3181 - 88s - loss: 0.0055 - Sales_loss: 0.0036 - Customers_loss: 0.0016 - Sales_mse: 0.0036 - Sales_rmspe: 0.4369 - Customers_mse: 0.0016 - Customers_rmspe: 0.4292 - val_loss: 0.0067 - val_Sales_loss: 0.0040 - val_Customers_loss: 0.0024 - val_Sales_mse: 0.0040 - val_Sales_rmspe: 0.4449 - val_Customers_mse: 0.0024 - val_Customers_rmspe: 0.5428
#
# Epoch 00002: val_Sales_mse improved from 0.00411 to 0.00397, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-5.hdf5
# Epoch 3/10
# 3181/3181 - 89s - loss: 0.0054 - Sales_loss: 0.0036 - Customers_loss: 0.0015 - Sales_mse: 0.0036 - Sales_rmspe: 0.4336 - Customers_mse: 0.0015 - Customers_rmspe: 0.4261 - val_loss: 0.0063 - val_Sales_loss: 0.0038 - val_Customers_loss: 0.0022 - val_Sales_mse: 0.0038 - val_Sales_rmspe: 0.4280 - val_Customers_mse: 0.0022 - val_Customers_rmspe: 0.4930
#
# Epoch 00003: val_Sales_mse improved from 0.00397 to 0.00384, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-5.hdf5
# Epoch 4/10
# 3181/3181 - 88s - loss: 0.0054 - Sales_loss: 0.0035 - Customers_loss: 0.0015 - Sales_mse: 0.0035 - Sales_rmspe: 0.4315 - Customers_mse: 0.0015 - Customers_rmspe: 0.4232 - val_loss: 0.0063 - val_Sales_loss: 0.0039 - val_Customers_loss: 0.0021 - val_Sales_mse: 0.0039 - val_Sales_rmspe: 0.4482 - val_Customers_mse: 0.0021 - val_Customers_rmspe: 0.5287
#
# Epoch 00004: val_Sales_mse did not improve from 0.00384
# Epoch 5/10
saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-5.hdf5
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0056 - Sales_loss: 0.0035 - Customers_loss: 0.0018 - Sales_mse: 0.0035 - Sales_rmspe: 0.4105 - Customers_mse: 0.0018 - Customers_rmspe: 0.4833
# Cat vars chosen: ['CompetitionOpenSinceYear', 'Promo_fw', 'Day', 'Year', 'StateHoliday_bool_fw', 'Week', 'Close_bool_fw', 'Promo2SinceYear', 'PromoInterval', 'Promo2Weeks', 'SchoolHoliday_fw', 'Events', 'Promo']
# Cont vars chosen: ['BeforePromo', 'Max_TemperatureC', 'Mean_TemperatureC', 'BeforeClose_bool', 'Mean_Humidity', 'Max_Wind_SpeedKm_h', 'Max_Humidity', 'AfterStateHoliday_bool', 'CloudCover', 'AfterPromo', 'CompetitionDistance', 'AfterSchoolHoliday']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Creamos el modelo 6
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 6
# Epoch 1/10
# 3181/3181 - 93s - loss: 0.0147 - Sales_loss: 0.0044 - Customers_loss: 0.0021 - Sales_mse: 0.0044 - Sales_rmspe: 0.5130 - Customers_mse: 0.0021 - Customers_rmspe: 0.5130 - val_loss: 0.0095 - val_Sales_loss: 0.0045 - val_Customers_loss: 0.0047 - val_Sales_mse: 0.0045 - val_Sales_rmspe: 0.4725 - val_Customers_mse: 0.0047 - val_Customers_rmspe: 0.6802
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00447, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-6.hdf5
# Epoch 2/10
# 3181/3181 - 91s - loss: 0.0061 - Sales_loss: 0.0040 - Customers_loss: 0.0019 - Sales_mse: 0.0040 - Sales_rmspe: 0.4864 - Customers_mse: 0.0019 - Customers_rmspe: 0.4871 - val_loss: 0.0110 - val_Sales_loss: 0.0049 - val_Customers_loss: 0.0058 - val_Sales_mse: 0.0049 - val_Sales_rmspe: 0.4970 - val_Customers_mse: 0.0058 - val_Customers_rmspe: 0.7531
#
# Epoch 00002: val_Sales_mse did not improve from 0.00447
# Epoch 3/10
# 3181/3181 - 90s - loss: 0.0060 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4783 - Customers_mse: 0.0018 - Customers_rmspe: 0.4831 - val_loss: 0.0096 - val_Sales_loss: 0.0049 - val_Customers_loss: 0.0045 - val_Sales_mse: 0.0049 - val_Sales_rmspe: 0.5105 - val_Customers_mse: 0.0045 - val_Customers_rmspe: 0.6671
#
# Epoch 00003: val_Sales_mse did not improve from 0.00447
# Epoch 4/10
# 3181/3181 - 90s - loss: 0.0059 - Sales_loss: 0.0038 - Customers_loss: 0.0018 - Sales_mse: 0.0038 - Sales_rmspe: 0.4717 - Customers_mse: 0.0018 - Customers_rmspe: 0.4748 - val_loss: 0.0125 - val_Sales_loss: 0.0054 - val_Customers_loss: 0.0069 - val_Sales_mse: 0.0054 - val_Sales_rmspe: 0.4558 - val_Customers_mse: 0.0069 - val_Customers_rmspe: 0.6831
#
# Epoch 00004: val_Sales_mse did not improve from 0.00447
# Epoch 5/10
# 3181/3181 - 91s - loss: 0.0057 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4680 - Customers_mse: 0.0017 - Customers_rmspe: 0.4685 - val_loss: 0.0100 - val_Sales_loss: 0.0046 - val_Customers_loss: 0.0050 - val_Sales_mse: 0.0046 - val_Sales_rmspe: 0.4751 - val_Customers_mse: 0.0050 - val_Customers_rmspe: 0.6807
#
# Epoch 00005: val_Sales_mse did not improve from 0.00447
# Epoch 6/10
# 3181/3181 - 90s - loss: 0.0057 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4656 - Customers_mse: 0.0017 - Customers_rmspe: 0.4671 - val_loss: 0.0182 - val_Sales_loss: 0.0065 - val_Customers_loss: 0.0114 - val_Sales_mse: 0.0065 - val_Sales_rmspe: 0.5268 - val_Customers_mse: 0.0114 - val_Customers_rmspe: 0.8642
#
# Epoch 00006: val_Sales_mse did not improve from 0.00447
# Epoch 7/10
# 3181/3181 - 89s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4647 - Customers_mse: 0.0017 - Customers_rmspe: 0.4655 - val_loss: 0.0110 - val_Sales_loss: 0.0049 - val_Customers_loss: 0.0058 - val_Sales_mse: 0.0049 - val_Sales_rmspe: 0.4887 - val_Customers_mse: 0.0058 - val_Customers_rmspe: 0.7350
#
# Epoch 00007: val_Sales_mse did not improve from 0.00447
# Epoch 8/10
# 3181/3181 - 89s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4651 - Customers_mse: 0.0017 - Customers_rmspe: 0.4664 - val_loss: 0.0124 - val_Sales_loss: 0.0053 - val_Customers_loss: 0.0069 - val_Sales_mse: 0.0053 - val_Sales_rmspe: 0.4928 - val_Customers_mse: 0.0069 - val_Customers_rmspe: 0.7439
#
# Epoch 00008: val_Sales_mse did not improve from 0.00447
# Epoch 9/10
# 3181/3181 - 89s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4643 - Customers_mse: 0.0017 - Customers_rmspe: 0.4655 - val_loss: 0.0098 - val_Sales_loss: 0.0047 - val_Customers_loss: 0.0049 - val_Sales_mse: 0.0047 - val_Sales_rmspe: 0.4783 - val_Customers_mse: 0.0049 - val_Customers_rmspe: 0.6718
#
# Epoch 00009: val_Sales_mse did not improve from 0.00447
# Epoch 10/10
# 3181/3181 - 88s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4640 - Customers_mse: 0.0017 - Customers_rmspe: 0.4652 - val_loss: 0.0101 - val_Sales_loss: 0.0047 - val_Customers_loss: 0.0052 - val_Sales_mse: 0.0047 - val_Sales_rmspe: 0.4464 - val_Customers_mse: 0.0052 - val_Customers_rmspe: 0.6613
#
# Epoch 00010: val_Sales_mse did not improve from 0.00447
# Obtenemos las métricas
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0095 - Sales_loss: 0.0045 - Customers_loss: 0.0047 - Sales_mse: 0.0045 - Sales_rmspe: 0.4604 - Customers_mse: 0.0047 - Customers_rmspe: 0.6673
# Cont vars chosen: ['Min_TemperatureC', 'Precipitationmm', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'AfterSchoolHoliday', 'AfterClose_bool', 'CloudCover', 'AfterStateHoliday_bool', 'Max_Wind_SpeedKm_h', 'trend', 'Mean_Humidity', 'Mean_TemperatureC', 'BeforeSchoolHoliday', 'Max_Humidity', 'CompetitionDistance', 'AfterPromo', 'trend_DE', 'BeforeClose_bool', 'Max_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Creamos el modelo 7
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 7
# Epoch 1/10
# 3181/3181 - 90s - loss: 0.0165 - Sales_loss: 0.0042 - Customers_loss: 0.0020 - Sales_mse: 0.0042 - Sales_rmspe: 0.4978 - Customers_mse: 0.0020 - Customers_rmspe: 0.4982 - val_loss: 0.0122 - val_Sales_loss: 0.0050 - val_Customers_loss: 0.0068 - val_Sales_mse: 0.0050 - val_Sales_rmspe: 0.4474 - val_Customers_mse: 0.0068 - val_Customers_rmspe: 0.7010
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00500, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-7.hdf5
# Epoch 2/10
# 3181/3181 - 87s - loss: 0.0060 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4784 - Customers_mse: 0.0018 - Customers_rmspe: 0.4761 - val_loss: 0.0154 - val_Sales_loss: 0.0064 - val_Customers_loss: 0.0087 - val_Sales_mse: 0.0064 - val_Sales_rmspe: 0.5558 - val_Customers_mse: 0.0087 - val_Customers_rmspe: 0.8701
#
# Epoch 00002: val_Sales_mse did not improve from 0.00500
# Epoch 3/10
# 3181/3181 - 87s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0017 - Sales_mse: 0.0038 - Sales_rmspe: 0.4707 - Customers_mse: 0.0017 - Customers_rmspe: 0.4689 - val_loss: 0.0148 - val_Sales_loss: 0.0062 - val_Customers_loss: 0.0084 - val_Sales_mse: 0.0062 - val_Sales_rmspe: 0.5116 - val_Customers_mse: 0.0084 - val_Customers_rmspe: 0.7820
#
# Epoch 00003: val_Sales_mse did not improve from 0.00500
# Epoch 4/10
# 3181/3181 - 87s - loss: 0.0057 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4675 - Customers_mse: 0.0017 - Customers_rmspe: 0.4679 - val_loss: 0.0164 - val_Sales_loss: 0.0066 - val_Customers_loss: 0.0094 - val_Sales_mse: 0.0066 - val_Sales_rmspe: 0.5376 - val_Customers_mse: 0.0094 - val_Customers_rmspe: 0.8603
#
# Epoch 00004: val_Sales_mse did not improve from 0.00500
# Epoch 5/10
# Cont vars chosen: ['trend_DE', 'Precipitationmm', 'CloudCover', 'AfterSchoolHoliday', 'BeforeSchoolHoliday', 'trend', 'AfterStateHoliday_bool', 'AfterClose_bool', 'Max_Wind_SpeedKm_h', 'Mean_Humidity', 'Max_TemperatureC', 'BeforePromo', 'Min_Humidity', 'Mean_Wind_SpeedKm_h', 'BeforeStateHoliday_bool', 'StateHoliday_bool', 'CompetitionDistance', 'AfterPromo', 'BeforeClose_bool', 'Min_TemperatureC']
# Creamos los embeddings y layers
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Creamos el modelo 8
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'CompetitionOpenSinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Day_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Year_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'StateHoliday_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Week_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Close_bool_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2SinceYear_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'PromoInterval_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo2Weeks_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'SchoolHoliday_fw_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Events_input')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Promo_input')>]
# Normalizamos el dataset
# Entrenamos el modelo 8
# Epoch 1/10
# 3181/3181 - 92s - loss: 0.0168 - Sales_loss: 0.0042 - Customers_loss: 0.0020 - Sales_mse: 0.0042 - Sales_rmspe: 0.4929 - Customers_mse: 0.0020 - Customers_rmspe: 0.4964 - val_loss: 0.0168 - val_Sales_loss: 0.0058 - val_Customers_loss: 0.0106 - val_Sales_mse: 0.0058 - val_Sales_rmspe: 0.5436 - val_Customers_mse: 0.0106 - val_Customers_rmspe: 0.9400
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00580, saving model to modelos generados/eleccion caracteristicas/modelos entrenados/bestmodel9-8.hdf5
# Epoch 2/10
# 3181/3181 - 89s - loss: 0.0060 - Sales_loss: 0.0039 - Customers_loss: 0.0018 - Sales_mse: 0.0039 - Sales_rmspe: 0.4779 - Customers_mse: 0.0018 - Customers_rmspe: 0.4797 - val_loss: 0.0154 - val_Sales_loss: 0.0061 - val_Customers_loss: 0.0090 - val_Sales_mse: 0.0061 - val_Sales_rmspe: 0.5563 - val_Customers_mse: 0.0090 - val_Customers_rmspe: 0.8784
#
# Epoch 00002: val_Sales_mse did not improve from 0.00580
# Epoch 3/10
# 3181/3181 - 89s - loss: 0.0058 - Sales_loss: 0.0038 - Customers_loss: 0.0017 - Sales_mse: 0.0038 - Sales_rmspe: 0.4715 - Customers_mse: 0.0017 - Customers_rmspe: 0.4715 - val_loss: 0.0178 - val_Sales_loss: 0.0072 - val_Customers_loss: 0.0103 - val_Sales_mse: 0.0072 - val_Sales_rmspe: 0.5865 - val_Customers_mse: 0.0103 - val_Customers_rmspe: 0.8822
#
# Epoch 00003: val_Sales_mse did not improve from 0.00580
# Epoch 4/10
# 3181/3181 - 89s - loss: 0.0057 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4669 - Customers_mse: 0.0017 - Customers_rmspe: 0.4682 - val_loss: 0.0187 - val_Sales_loss: 0.0078 - val_Customers_loss: 0.0106 - val_Sales_mse: 0.0078 - val_Sales_rmspe: 0.5780 - val_Customers_mse: 0.0106 - val_Customers_rmspe: 0.8862
#
# Epoch 00004: val_Sales_mse did not improve from 0.00580
# Epoch 5/10
# 3181/3181 - 89s - loss: 0.0056 - Sales_loss: 0.0037 - Customers_loss: 0.0017 - Sales_mse: 0.0037 - Sales_rmspe: 0.4645 - Customers_mse: 0.0017 - Customers_rmspe: 0.4675 - val_loss: 0.0164 - val_Sales_loss: 0.0065 - val_Customers_loss: 0.0097 - val_Sales_mse: 0.0065 - val_Sales_rmspe: 0.4954 - val_Customers_mse: 0.0097 - val_Customers_rmspe: 0.7782
